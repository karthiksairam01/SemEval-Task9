# %% [markdown]
# # Pre-processing and Importing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/karthiksairam01/SemEval-Task9.git
# !git clone https://github.com/food-hazard-detection-semeval-2025/food-hazard-detection-semeval-2025.github.io.git
# Out:
# fatal: destination path 'SemEval-Task9' already exists and is not an empty directory.
# fatal: destination path 'food-hazard-detection-semeval-2025.github.io' already exists and is not an empty directory.

# %%
with open('/content/drive/My Drive/conceptnet-lite.csv', 'r') as f:
  file_contents = f.read()

# %%
# Install necessary libraries
# !pip install networkx pandas tqdm

# !pip install -U pip setuptools wheel

# %%
import numpy as np
import networkx as nx
import pandas as pd
from tqdm import tqdm
import json

# %% [markdown]
# # Functions

# %%
def get_titles_dict(incidents: pd.DataFrame, column: str) -> dict:
    try:
        values = np.unique(np.concatenate(incidents[column].values))
    except ValueError:
        values = np.unique(incidents[column].values)

    counts = np.array([sum([v in label for label in incidents[column].values]) for v in values])
    result = {}

    for v, n in zip(values, counts):
        doc = nlp(v)
        words = []
        for token in doc:
            if token.pos_ in {"NOUN","ADJ"}:
                words.append(token.text)
        result[v] = {"words": words}

    return result

def get_nodes_dict(incidents: pd.DataFrame, column: str) -> dict:
    try:
        values = np.unique(np.concatenate(incidents[column].values))
    except ValueError:
        values = np.unique(incidents[column].values)

    counts = np.array([sum([v in label for label in incidents[column].values]) for v in values])
    result = {}

    for v, n in zip(values, counts):
        doc = nlp(v)
        words = []
        for token in doc:
            if token.pos_ in {"NOUN", "PROPN", "VERB", "ADJ"}:
                words.append(token.text)
        result[v] = {"words": words}

    return result

def print_nodes(incidents: pd.DataFrame, column: str):
    try:
        values = np.unique(np.concatenate(incidents[column].values))
    except ValueError:
        values = np.unique(incidents[column].values)
    counts = np.array([sum([v in label for label in incidents[column].values]) for v in values])

    for v, n in zip(values, counts):
        # print(v)
        doc = nlp(v)
        words = []
        for token in doc:
            if token.pos_ in {"NOUN", "PROPN", "VERB", "ADJ"}:
                words.append(token.text)
        print(f'  {v}: {words}')

# %% [markdown]
# # Functions (A)

# %%
def canonicalize_node(uri):
    """
    Canonicalizes a ConceptNet URI by removing parts after the lemma.
    For example:
    "/c/en/condiment/n" -> "/c/en/condiment"
    "/c/en/condiments/n" -> "/c/en/condiments"
    "/c/en/apple" stays "/c/en/apple"
    """
    parts = uri.strip('/').split('/')
    # We expect something like ["c", "en", "condiment", "n"]
    # Keep only the first three segments: c, language code, and the lemma
    if len(parts) >= 3:
        return "/" + "/".join(parts[:3])
    else:
        # If the URI doesn't follow the expected pattern, just return it as is.
        return uri

def load_conceptnet_lite_csv(file_path):
    """
    Loads the filtered ConceptNet Lite CSV into a NetworkX graph.

    Parameters:
    - file_path (str): Path to the filtered CSV file.

    Returns:
    - G (networkx.Graph): The constructed undirected graph with canonicalized nodes.
    """
    print("Loading ConceptNet Lite into NetworkX...")
    G = nx.Graph()

    try:
        # Read the CSV using pandas
        df = pd.read_csv(file_path, sep=',', encoding='utf-8')
    except Exception as e:
        print(f"Error reading filtered CSV: {e}")
        return G

    # Iterate through the DataFrame and add edges
    print("Adding edges to NetworkX...")
    for index, row in tqdm(df.iterrows(), total=df.shape[0], desc="Adding edges"):
        start = canonicalize_node(row['start'])
        end = canonicalize_node(row['end'])
        rel = row['rel']
        G.add_edge(start, end, relation=rel)

    print(f"Graph has {G.number_of_nodes()} nodes and {G.number_of_edges()} edges.")
    return G

# %% [markdown]
# # Loading ConceptNet with NetworkX

# %%
# Define the path to the filtered CSV
FILTERED_CSV_FILE = "/content/drive/MyDrive/conceptnet-lite[RelatedTo,FormOf,Synonym].csv"

# Load the graph
G = load_conceptnet_lite_csv(FILTERED_CSV_FILE)
# Out:
# Loading ConceptNet Lite into NetworkX...
# Adding edges to NetworkX...
# Adding edges: 100%|██████████| 2304597/2304597 [03:28<00:00, 11067.08it/s]
# Graph has 948526 nodes and 2052758 edges.

# %% [markdown]
# # Output Labels (hazard/prod categories)

# %%
json_file_path = 'SemEval-Task9/extracted_keywords_hazard_category.json'
with open(json_file_path, 'r') as file:
    data = json.load(file)

df_1 = pd.DataFrame(list(data.items()), columns=['hazard_category', 'extracted_terms'])
hazards = dict(zip(df_1['hazard_category'], df_1['extracted_terms']))

print(hazards)

json_file_path = 'SemEval-Task9/extracted_keywords_product_category.json'
with open(json_file_path, 'r') as file:
    data = json.load(file)

df_2 = pd.DataFrame(list(data.items()), columns=['product_category', 'extracted_terms'])
products = dict(zip(df_2['product_category'], df_2['extracted_terms']))
print(products)
# Out:
# {'allergens': ['allergens'], 'chemical': ['chemical'], 'food additives and flavourings': ['food additives', 'flavourings'], 'foreign bodies': ['foreign bodies', 'bodies'], 'fraud': ['fraud'], 'migration': ['migration'], 'organoleptic aspects': ['organoleptic', 'aspects'], 'other hazard': ['hazard'], 'packaging defect': ['defect']}
# {'alcoholic beverages': ['alcoholic beverage', 'beverage', 'alcoholic', 'beverages'], 'cereals and bakery products': ['cereals', 'bakery', 'products'], 'cocoa and cocoa preparations, coffee and tea': ['cocoa', 'coffee', 'tea'], 'dietetic foods, food supplements, fortified foods': ['dietetic', 'fortified', 'food', 'supplements'], 'fats and oils': ['fats', 'oils'], 'feed materials': ['materials'], 'food additives and flavourings': ['additive', 'flavourings', 'food additives'], 'food contact materials': ['food', 'contact', 'materials'], 'fruits and vegetables': ['fruits', 'vegetables'], 'herbs and spices': ['herbs', 'spices'], 'honey and royal jelly': ['honey', 'royal jelly'], 'ices and desserts': ['desserts', 'ices'], 'meat, egg and dairy products': ['meat', 'egg', 'dairy products'], 'non-alcoholic beverages': ['beverage', 'beverages'], 'nuts, nut products and seeds': ['nut', 'nuts', 'products', 'seeds'], 'other food product / mixed': ['food', 'mixed'], 'pet feed': ['pet'], 'prepared dishes and snacks': ['dishes', 'snacks', 'prepared'], 'seafood': ['seafood'], 'soups, broths, sauces and condiments': ['broth', 'broths', 'soups', 'soup', 'sauces', 'sauce', 'condiments', 'condiment'], 'sugars and syrups': ['sugars', 'syrups']}

# %% [markdown]
# # Input Labels (title keywords)

# %%
json_file_path = 'SemEval-Task9/extracted_keywords.json'
with open(json_file_path, 'r') as file:
    data = json.load(file)

df = pd.DataFrame(list(data.items()), columns=['title', 'extracted_terms'])

# %% [markdown]
# # Experimentation

# %% [markdown]
# ## Removing ban words

# %%
def clean_categories(categories, remove_strings):
    """
    Remove any keywords containing specified strings from both category keys and their associated keywords.

    Parameters:
    - categories (dict): Dictionary mapping category labels to their associated keywords.
    - remove_strings (list): List of strings to be removed from both category keys and their associated keywords.

    Returns:
    - cleaned_categories (dict): Modified dictionary with specified strings removed from each category.
    """
    cleaned_categories = {}

    for label, keywords in categories.items():

        # Filter out keywords containing any of the specified strings
        filtered_keywords = [kw for kw in keywords if all(remove_string != kw for remove_string in remove_strings)]

        # Only add to the dictionary if there are any keywords left after filtering
        if filtered_keywords:
            cleaned_categories[label] = filtered_keywords

    return cleaned_categories

# %%
def remove_terms_from_extracted_terms(df, terms_to_remove):
    """Removes specified terms from the 'extracted_terms' column of a DataFrame.

    Args:
        df: The input DataFrame.
        terms_to_remove: A list of terms to remove.

    Returns:
        A new DataFrame with the specified terms removed from the 'extracted_terms' column.
    """

    # Create a copy of the input DataFrame to avoid modifying the original DataFrame.
    df_cleaned = df.copy()

    # Remove the terms from the 'extracted_terms' column using a list comprehension.
    df_cleaned['extracted_terms'] = df_cleaned['extracted_terms'].apply(
        lambda terms: [term for term in terms if term not in terms_to_remove]
    )

    return df_cleaned

# %%
to_remove = ['good', 'white', 'recall', 'selected', 'stores', 'sold', 'food', 'materials', 'beverage', 'beverages', 'products', 'mixed', 'issues', 'mix', 'alert', 'health', 'product']
print(hazards)
hazards = clean_categories(hazards, to_remove)


print(products)
products = clean_categories(products, to_remove)

print(df.head())

df_cleaned = remove_terms_from_extracted_terms(df, to_remove)

df = df_cleaned
df.head()
# Out:
# {'allergens': ['allergens'], 'chemical': ['chemical'], 'food additives and flavourings': ['food additives', 'flavourings'], 'foreign bodies': ['foreign bodies', 'bodies'], 'fraud': ['fraud'], 'migration': ['migration'], 'organoleptic aspects': ['organoleptic', 'aspects'], 'other hazard': ['hazard'], 'packaging defect': ['defect']}
# {'alcoholic beverages': ['alcoholic beverage', 'alcoholic'], 'cereals and bakery products': ['cereals', 'bakery'], 'cocoa and cocoa preparations, coffee and tea': ['cocoa', 'coffee', 'tea'], 'dietetic foods, food supplements, fortified foods': ['dietetic', 'fortified', 'supplements'], 'fats and oils': ['fats', 'oils'], 'food additives and flavourings': ['additive', 'flavourings', 'food additives'], 'food contact materials': ['contact'], 'fruits and vegetables': ['fruits', 'vegetables'], 'herbs and spices': ['herbs', 'spices'], 'honey and royal jelly': ['honey', 'royal jelly'], 'ices and desserts': ['desserts', 'ices'], 'meat, egg and dairy products': ['meat', 'egg', 'dairy products'], 'nuts, nut products and seeds': ['nut', 'nuts', 'seeds'], 'pet feed': ['pet'], 'prepared dishes and snacks': ['dishes', 'snacks', 'prepared'], 'seafood': ['seafood'], 'soups, broths, sauces and condiments': ['broth', 'broths', 'soups', 'soup', 'sauces', 'sauce', 'condiments', 'condiment'], 'sugars and syrups': ['sugars', 'syrups']}
#                                                title  \
# 0  2006 - Consumer Alert: Listeria Contamination ...
# 1  2006 - Pinnacle Foods Corporation Issues Aller...
# 2  2006 - Pinnacle Foods Group Inc. Issues Allerg...
# 3  2006 - pinnacle foods group inc. issues allerg...
# 4  2007 - Agriculture Department Warns Consumers ...
#
#                                      extracted_terms
# 0          [listeria, milk, contamination, raw milk]
# 1  [corporation, allergy, pinnacle, foods, muffin...
# 2                 [egg, allergy, frozen, undeclared]
# 3                                 [allergy, brownie]
# 4  [butler, dairy, county, tainted, raw, milk, wa...
#                                                title  \
# 0  2006 - Consumer Alert: Listeria Contamination ...
# 1  2006 - Pinnacle Foods Corporation Issues Aller...
# 2  2006 - Pinnacle Foods Group Inc. Issues Allerg...
# 3  2006 - pinnacle foods group inc. issues allerg...
# 4  2007 - Agriculture Department Warns Consumers ...
#
#                                      extracted_terms
# 0          [listeria, milk, contamination, raw milk]
# 1  [corporation, allergy, pinnacle, foods, muffin...
# 2                 [egg, allergy, frozen, undeclared]
# 3                                 [allergy, brownie]
# 4  [butler, dairy, county, tainted, raw, milk, wa...

# %% [markdown]
# # BFS

# %%
from collections import deque

def multi_source_bfs(G, start_nodes, max_distance=3):
    """
    Perform BFS from multiple start nodes up to max_distance.

    Parameters:
    - G (networkx.Graph): The graph to traverse.
    - start_nodes (list): List of node identifiers to start BFS from.
    - max_distance (int): Maximum distance to traverse.

    Returns:
    - distance (dict): Dictionary mapping nodes to their shortest distance from any start node.
    """
    distance = {}
    queue = deque()

    # Initialize the queue and distance dictionary with start nodes
    for node in start_nodes:
        if node in G:
            distance[node] = 0
            queue.append((node, 0))
        else:
            print(f"Warning: Start node {node} not in graph.")

    while queue:
        current_node, current_distance = queue.popleft()

        if current_distance >= max_distance:
            continue

        for neighbor in G.neighbors(current_node):
            if neighbor not in distance:
                distance[neighbor] = current_distance + 1
                queue.append((neighbor, current_distance + 1))

    return distance

# %% [markdown]
# # Testing

# %%
# Define start concepts
start_concepts = ["alcohol"]  # Modify this list as needed

# Convert start concepts to ConceptNet URIs
start_uris = [f"/c/en/{concept.lower()}" for concept in start_concepts]

print(start_uris)
# Out:
# ['/c/en/alcohol']

# %%
# Define the maximum distance for BFS
max_distance = 5  # Adjust as needed

# Perform BFS
dist_map = multi_source_bfs(G, start_uris, max_distance)

# %%
print(len(dist_map))
# Out:
# 825502

# %% [markdown]
# # Verify if node in ConceptNet

# %%
def verify_nodes(G, nodes):
    """
    Verifies if the given nodes exist in the graph.

    Parameters:
    - G (networkx.Graph or networkx.DiGraph): The graph.
    - nodes (list): List of ConceptNet URIs to verify.

    Returns:
    - existing_nodes (list): Nodes that exist in the graph.
    - missing_nodes (list): Nodes that do not exist in the graph.
    """
    existing_nodes = []
    missing_nodes = []
    for node in nodes:
        if node in G:
            existing_nodes.append(node)
        else:
            missing_nodes.append(node)
    return existing_nodes, missing_nodes

# %%
# Define start concepts
start_concepts = ["dietetical"]  # Modify this list as needed

# Convert start concepts to ConceptNet URIs
start_uris = [f"/c/en/{concept.lower()}" for concept in start_concepts]

print(start_uris)

# Verify if start URIs are in the graph
existing, missing = verify_nodes(G, start_uris)

print("\n=== Node Verification ===")
for node in existing:
    print(f"{node} exists in the graph.")
for node in missing:
    print(f"{node} does NOT exist in the graph.")
# Out:
# ['/c/en/dietetical']
#
# === Node Verification ===
# /c/en/dietetical exists in the graph.

# %% [markdown]
# # Subgraph generation

# %%
print(products)

# Convert product and hazard keywords to ConceptNet URIs
product_uris = {cat: [f"/c/en/{kw.replace(' ', '_').lower()}" for kw in kws] for cat, kws in products.items()}
hazard_uris = {cat: [f"/c/en/{kw.replace(' ', '_').lower()}" for kw in kws] for cat, kws in hazards.items()}

# Generate subgraphs for products and hazards
product_subgraphs = {cat: multi_source_bfs(G, uris, max_distance) for cat, uris in product_uris.items()}
hazard_subgraphs = {cat: multi_source_bfs(G, uris, max_distance) for cat, uris in hazard_uris.items()}
# Out:
# {'alcoholic beverages': ['alcoholic beverage', 'alcoholic'], 'cereals and bakery products': ['cereals', 'bakery'], 'cocoa and cocoa preparations, coffee and tea': ['cocoa', 'coffee', 'tea'], 'dietetic foods, food supplements, fortified foods': ['dietetic', 'fortified', 'supplements'], 'fats and oils': ['fats', 'oils'], 'food additives and flavourings': ['additive', 'flavourings', 'food additives'], 'food contact materials': ['contact'], 'fruits and vegetables': ['fruits', 'vegetables'], 'herbs and spices': ['herbs', 'spices'], 'honey and royal jelly': ['honey', 'royal jelly'], 'ices and desserts': ['desserts', 'ices'], 'meat, egg and dairy products': ['meat', 'egg', 'dairy products'], 'nuts, nut products and seeds': ['nut', 'nuts', 'seeds'], 'pet feed': ['pet'], 'prepared dishes and snacks': ['dishes', 'snacks', 'prepared'], 'seafood': ['seafood'], 'soups, broths, sauces and condiments': ['broth', 'broths', 'soups', 'soup', 'sauces', 'sauce', 'condiments', 'condiment'], 'sugars and syrups': ['sugars', 'syrups']}

# %% [markdown]
# # Classification

# %%
def classify_title_keywords(df, categories, max_distance=5):
    """
    Classify titles into categories based on the minimum distance between title keywords and pre-generated category subgraphs.

    Parameters:
    - df (pd.DataFrame): DataFrame containing 'title' and 'extracted_terms' columns.
    - categories (dict): Dictionary mapping category labels to their distance dictionaries (pre-generated subgraphs).
    - max_distance (int): Maximum BFS distance to consider.

    Returns:
    - classifications (dict): Dictionary mapping titles to their classified category.
    """
    classifications = {}

    # Iterate over each title in the DataFrame and classify
    for _, row in df.iterrows():
        title = row['title']
        keywords = row['extracted_terms']
        #print(keywords)
        #print(f"Processing title: {title}, Keywords: {keywords}")

        min_distance = float('inf')
        assigned_category = None

        # Compute the minimum distance for each category to the title's keywords
        for category, distances in categories.items():

            # MIN CODE
            # category_min_distance = float('inf')

            # Get the minimum distance to any keyword in the title
            # for keyword in keywords:
            #     keyword_uri = f"/c/en/{keyword.replace(' ', '_').lower()}"
            #     distance = distances.get(keyword_uri, float('inf'))
            #     if distance < category_min_distance:
            #         category_min_distance = distance
            #         #print(f"Category: {category}, Keyword: {keyword}, Distance: {distance}")

            # AVG CODE

            # Calculate the average distance to all keywords in the title for each category
            category_average_distance = float('inf')

            if keywords:
                distances_sum = 0
                valid_distances = 0

                for keyword in keywords:
                    #print(keyword)
                    keyword_uri = f"/c/en/{keyword.replace(' ', '_').lower()}"
                    distance = distances.get(keyword_uri, float('inf'))

                    # Only consider valid distances
                    if distance != float('inf'):
                        #print(f"Category: {category}, Keyword: {keyword}, Distance: {distance}")
                        distances_sum += distance
                        valid_distances += 1


                # Compute average distance if there are valid distances
                if valid_distances > 0:
                    category_average_distance = distances_sum
                    #print(f"Category: {category}, Average Distance: {category_average_distance}")


            # Check if this category has a smaller average distance than previously found categories
            if category_average_distance < min_distance:
                min_distance = category_average_distance
                assigned_category = category

            # # Check if this category is closer than previously found categories
            # if category_min_distance < min_distance:
            #     min_distance = category_min_distance
            #     assigned_category = category

        # Assign the category with the overall shortest distance
        classifications[title] = assigned_category

    return classifications

# %%
categories = product_subgraphs

classifications = classify_title_keywords(df, categories, G)

classifications
# Out:
# {'2006 - Consumer Alert: Listeria Contamination in Raw Milk': 'meat, egg and dairy products',
#  '2006 - Pinnacle Foods Corporation Issues Allergy Alert on Bakery-Style Chocolate Chip Muffin Mix': 'cocoa and cocoa preparations, coffee and tea',
#  '2006 - Pinnacle Foods Group Inc. Issues Allergy Alert on Undeclared Egg in Frozen': 'meat, egg and dairy products',
#  '2006 - pinnacle foods group inc. issues allergy alert on brownie mix': 'nuts, nut products and seeds',
#  '2007 - Agriculture Department Warns Consumers of Tainted Raw Milk Sold by Butler County Dairy': 'meat, egg and dairy products',
#  '2007 - WholeSoy & Co. Expands National Allergy Alert on Undeclared Dairy in Blueberry and Mixed Berry Yogurt': 'meat, egg and dairy products',
#  '2007 - Winn-Dixie Stores, Inc. Issues Allergy Alert on Mislabeled Prestige Chocolate Ice Cream': 'cocoa and cocoa preparations, coffee and tea',
#  '2007 - private selectionÂ® ice cream recalled from ralphs and food 4 less stores in california': 'meat, egg and dairy products',
#  '2008 - Barry Callebaut USA LLC Issues Allergen Alert on Undeclared Milk Protein in Kroger Value Semi Sweet Chocolate Chips': 'meat, egg and dairy products',
#  "2008 - dreyer's issues voluntary recall of slow churnedÂ® light caramel delight and butter pecan ice cream flavors for undeclared pecans": 'soups, broths, sauces and condiments',
#  '2008 - limited number of aunt jemima pancake & waffle mix products recalled for possible health risk': 'meat, egg and dairy products',
#  "2008 - pierre's ice cream company issues allergy alert on its homestyle brand of dutch chocolate ice cream for undeclared peanut butter cup candies": 'cocoa and cocoa preparations, coffee and tea',
#  '2008 - private selection ice cream recalled from kroger stores in twelve southeastern states': 'cocoa and cocoa preparations, coffee and tea',
#  '2009 - A Manufacturer From England, Cropwell Bishop Creamery Limited, is Conducting a Nationwide Recall on the Cheese Products Blue Stilton and Shropshire Blue Cheese Because of Possible Health Risk': 'food contact materials',
#  '2009 - BIC Acquisition, LLC Recalls World Classic Trading Company Ultimate Chunk Ice Cream': 'cocoa and cocoa preparations, coffee and tea',
#  '2009 - Bliss Bros. Dairy, Inc. Recalls Ice Cream Products Because of Possible Health Risk': 'meat, egg and dairy products',
#  "2009 - Braum's Ice Cream and Dairy Stores Announces Voluntary Recall of its Premium Ice Cream Flavor": 'meat, egg and dairy products',
#  '2009 - Bucks Ice Cream Recalls Ice Cream Nut Roll Because of Possible Health Risk': 'nuts, nut products and seeds',
#  '2009 - Fieldbrook Foods Corp. Announces Nationwide Voluntary Recall of Select Ice Cream Novelty Products Due to Possible Health Risk': 'meat, egg and dairy products',
#  '2009 - Fieldbrook Foods Corporation Adds Four Products to Nationwide Voluntary Recall of Select Ice Cream Novelty Products Due to Possible Health Risk': 'meat, egg and dairy products',
#  '2009 - Garden-Fresh Foods Issues Allergy Alert On Undeclared Milk in 16-Ounce Archer Farms Potato Salad': 'meat, egg and dairy products',
#  '2009 - Glutenfreeda Foods, Inc. Recalls Peanut Envy Frozen Cookie Dough Because of Possible Health Risk': 'meat, egg and dairy products',
#  '2009 - Hershey Creamery Announces Voluntary Recall of Goo Goo Peanut Butter Ice Cream Because of Possible Health Risk': 'nuts, nut products and seeds',
#  '2009 - Ice Cream Specialties Announces Nationwide Recall of Ice Cream Novelties Because of Possible Health Risk': 'meat, egg and dairy products',
#  '2009 - Kroger Recalls Additional Select Ice Cream Product Due to Possible Health Risk': 'meat, egg and dairy products',
#  '2009 - Kroger Recalls Select Ice Cream Products Due to Possible Health Risk': 'meat, egg and dairy products',
#  "2009 - Mooresville Ice Cream Co. Conducts Carolinas Recall of Half Gallon and Three Gallon containers of 'Chocolate Peanut Butter Delight' flavor of DeLuxe Ice Cream Because Of Possible Health Risk": 'meat, egg and dairy products',
#  "2009 - Perry's Ice Cream Company Adds Products to Voluntary Recall of Select Peanut Butter Ice Cream Products as a result of PCA Expanded Recall": 'cocoa and cocoa preparations, coffee and tea',
#  '2009 - Rich Products Corporation announces nationwide voluntary recall of Peanut Butter Blast Pie and Red Robin 10': 'meat, egg and dairy products',
#  '2009 - Shamrock Foods Company Issues Voluntary Recall on Nutty Sundae Cones': 'cocoa and cocoa preparations, coffee and tea',
#  '2009 - Turner Holdings Recalls Peanut Butter Bars Because of Possible Health Risk': 'nuts, nut products and seeds',
#  '2009 - Unilever Issues Allergy Alert on Wheat in a Limited Number of Tubs of Breyers Ice Cream': 'nuts, nut products and seeds',
#  '2009 - Unilever United States, Inc. Conducts Nationwide Voluntary Recall Of Breyers Tin Roof Sundae Ice Cream Products with Peanuts Due to Possible Health Risk': 'cocoa and cocoa preparations, coffee and tea',
#  '2009 - Velvet Ice Cream Pulling Cone Products': 'ices and desserts',
#  '2009 - arya ice cream dist. co., inc. recalls california dream nut sundae because of possible health risk': 'soups, broths, sauces and condiments',
#  '2009 - austinuts wholesale, inc. announces voluntary recall of organic peanuts': 'honey and royal jelly',
#  '2009 - belfonte ice cream and dairy foods co. announces voluntary recall of ice cream due to possible health risk': 'meat, egg and dairy products',
#  "2009 - casper's ice cream, inc. voluntarily recalls fat boyÂ® cascoÂ® nut sundae on a stick and fat boyÂ® cascoÂ® cherry cordial nut sundae on a stick products because of possible health risk": 'nuts, nut products and seeds',
#  '2009 - deluxe ice cream co. expands recall to include additional codes of tin roof sundae, goo goo cluster, and candy bar half gallon packaged ice cream product, 3 gallon tin roof sundae and qc 24 pack sundae cone because of possible health risk': 'soups, broths, sauces and condiments',
#  '2009 - edaleen dairy recalls tin roof sundae ice cream and chocolate peanut butter nut ice cream because of possible health risk': 'nuts, nut products and seeds',
#  "2009 - garber's ice cream company issues voluntary recall on half gallon tin roof sundae ice cream and nutty cones due to expanded peanut recall by peanut corporation of america (pca)": 'cocoa and cocoa preparations, coffee and tea',
#  '2009 - h-e-b issues precautionary and voluntary recall for creamy creations peanut brittle ice cream': 'nuts, nut products and seeds',
#  '2009 - hiland dairy foods company, llc announces recallof ice cream because of possible health risk': 'meat, egg and dairy products',
#  '2009 - hiland-roberts ice cream announces voluntary nationwide recall of specific lot numbers of espo brand and natures promise brand sorbettos due to containing undeclared milk': 'meat, egg and dairy products',
#  '2009 - house of flavors expands voluntary recall of ice creamdue to possible health risk': 'soups, broths, sauces and condiments',
#  '2009 - house of flavors issues voluntary recall in eastern united states due to possible health risk': 'soups, broths, sauces and condiments',
#  '2009 - hp hood llc recalls ice cream products': 'cocoa and cocoa preparations, coffee and tea',
#  '2009 - kroger expands recall of shelled pistachios due to possible health risk': 'nuts, nut products and seeds',
#  '2009 - multiple brands of tin roof sundae ice cream recalled as part of nationwide peanut corporation of america recall': 'cocoa and cocoa preparations, coffee and tea',
#  '2009 - peanut corporation of america expands nationwide recall of peanut butter': 'meat, egg and dairy products',
#  '2009 - peanut corporation of america expands nationwide recall of peanut products': 'nuts, nut products and seeds',
#  "2009 - pierre's ice cream company issues voluntary recall on its pierre's brand sundae-cone style products due to expanded peanut recall by peanut corporation of america (pca)": 'meat, egg and dairy products',
#  '2009 - prairie farms dairy announces voluntary nationwide recall because of possible health risk': 'meat, egg and dairy products',
#  "2009 - rich ice cream company expands precautionary voluntary multi-state recall to include rich's candy bar avalanche": 'cocoa and cocoa preparations, coffee and tea',
#  "2009 - rich ice cream company, inc. issues multi-state voluntary recall of rich's nutty sundae cone because of possible health risk": 'soups, broths, sauces and condiments',
#  '2009 - roman meal company initiates nationwide recall of whole grain & fruit dark chocolate peanut butter snack bars because of possible health risk': 'cocoa and cocoa preparations, coffee and tea',
#  '2009 - safeway recalls selected peanut products sold at 66 stores with nut kiosks': 'nuts, nut products and seeds',
#  '2009 - super store industries announces voluntary recall of select ice cream products due to possible health risk': 'soups, broths, sauces and condiments',
#  '2009 - turkey hill dairy expands voluntary ice cream recall to include': 'soups, broths, sauces and condiments',
#  '2009 - umpqua dairy issues voluntary recall on its tin roof sundae ice cream products due to expanded peanut recall by peanut corporation of america (pca)': 'cocoa and cocoa preparations, coffee and tea',
#  '2009 - update: schwan expands voluntary recall of ice cream, citing possible health risk': 'soups, broths, sauces and condiments',
#  '2009 - wonder ice cream company announces nationwide voluntary recall of candy blast 10oz cups because of possible health risk': 'soups, broths, sauces and condiments',
#  '2010 - Azteca Linda Corp. Recalls QUESO FRESCO and QUESO HEBRA Because of Possible Risk of Health': 'soups, broths, sauces and condiments',
#  '2010 - Del Bueno Recalls Queso Fresco Because of Possible Health Risk': 'meat, egg and dairy products',
#  '2010 - Quaker Snack Mix Baked Cheddar Voluntarily Recalled Due to Possible Health Risk': 'food contact materials',
#  '2010 - Sirob Imports Issues Alert on Undeclared Sulfites in Strawberry Farms Sun Dried Tomatoes': 'meat, egg and dairy products',
#  '2010 - del bueno amends recall of queso fresco cheese because of possible health risk': 'soups, broths, sauces and condiments',
#  '2010 - golden pacific foods, inc. issues allergy alert for undeclared milk and soy in marco polo brand shrimp snacks': 'meat, egg and dairy products',
#  '2010 - harry london candies, inc. announces a voluntary and limited recall of harry london chocolate pecan caramel stars due to an undeclared allergen': 'nuts, nut products and seeds',
#  "2010 - kellogg company voluntarily recalls select packages of kellogg'sÂ® corn popsÂ®, kellogg'sÂ® honey smacksÂ®, kellogg'sÂ® froot loopsÂ® and kellogg'sÂ® apple jacksÂ®": 'honey and royal jelly',
#  '2010 - kroger amends code date on recalled seasoning blend garlic powder': 'soups, broths, sauces and condiments',
#  '2010 - minnesota firm issues recall due to undeclared dairy allergen in certain sunflower seeds': 'meat, egg and dairy products',
#  '2010 - olde westport spice announces a voluntary recall of garden harvest special blend seasoning': 'soups, broths, sauces and condiments',
#  '2010 - p&g joins industry ingredient recall by voluntarily recalling two flavors of pringlesÂ® in the united states in response to fda industry guidance': 'cocoa and cocoa preparations, coffee and tea',
#  '2010 - queseria bendita recalls queso fresco, panela, and requeson because of possible health risk': 'cocoa and cocoa preparations, coffee and tea',
#  '2010 - so shing hing (usa) trading co ltd issues an alert on undeclared sulfites in dried melon': 'cocoa and cocoa preparations, coffee and tea',
#  '2010 - spice barn, inc. voluntarily recalls two lots of black pepper': 'alcoholic beverages',
#  '2010 - turkey hill dairy issues recall on chocolate marshmallow ice cream that may contain undeclared treenuts (almonds)': 'meat, egg and dairy products',
#  '2010 - whole foods market voluntarily recalls frozen whole catch yellow fin tuna steaks due to possible health risks': 'cocoa and cocoa preparations, coffee and tea',
#  '2010 - wholesome spice recalls 25 lb. boxes of crushed red pepper because of possible health risk': 'soups, broths, sauces and condiments',
#  'A. Clouet Pty Ltdâ€”Ayam Thai Massaman Curry, Cooking Sauce': 'soups, broths, sauces and condiments',
#  "Acquilla Bulk Tradingâ€”Sasso Pasta D'acciughe Linea Mare anchovies paste": 'soups, broths, sauces and condiments',
#  'Alba Cheeseâ€”Shredded Mozzarella': 'meat, egg and dairy products',
#  'Alba Gelati': 'cereals and bakery products',
#  'Allfect Ltdâ€”Ghost Drop Lollies': 'cocoa and cocoa preparations, coffee and tea',
#  'American Foods Group is voluntarily recalling approximately 95,927 pounds of various coarse and fine ground beef products because they may be contaminated with E. coli O157:H7.': 'meat, egg and dairy products',
#  'Angelakis Brothersâ€”Pacific Redâ€”Frozen Whole Cooked Vannamei Prawn': 'meat, egg and dairy products',
#  'Apr 4': 'cocoa and cocoa preparations, coffee and tea',
#  'Aqua Marine Marketing Pty Ltdâ€”Cooked Medium Tiger Prawns (sold loosely)': 'soups, broths, sauces and condiments',
#  'Archive - ALLERGY ALERT - UNDECLARED PECAN AND WALNUT IN ICE CREAM AND ICE MILK MANUFACTURED BY LAITERIE DE COATICOOK LT&#201 E': 'nuts, nut products and seeds',
#  'Archive - ALLERGY ALERT - UNDECLARED SOY PROTEIN AND SOY LECITHIN IN DUNCAN HINES WHITE CAKE MIX': 'meat, egg and dairy products',
#  'Archive - PRODUCT ALERT - POSSIBLE BOTULISM TOXIN IN ULIVETO DEL SAPORE BRAND GIANT OLIVES TUSCAN STYLE': 'meat, egg and dairy products',
#  'Aristocrat Gourmet Foodsâ€”Aristocrat and Melton Pork Pies': 'meat, egg and dairy products',
#  'Aug 7': 'soups, broths, sauces and condiments',
#  'Aus Soya Productsâ€”Tofu (5 products)': 'meat, egg and dairy products',
#  "Australian Discount Retailâ€”Ricky's BBQ flavoured Rice Crackers": 'soups, broths, sauces and condiments',
#  'Australian Eatwell Pty Ltdâ€”Australian Eatwell Garden Fresh Vegie Burgers â€“ Red Lentil': 'soups, broths, sauces and condiments',
#  'Australian International Foods Pty Ltdâ€”Darshan Savoury Rolls': 'soups, broths, sauces and condiments',
#  'Australian Seafood Producersâ€”Daruma Tuna Steaks and Tuna Steaks (Product of Indonesia purchased from Foodland stores in South Australia only)': 'meat, egg and dairy products',
#  'Azurra Gelatiâ€”Azurra Sorbet Strawberry, Mango, Lemon and Blueberry Flavours 1.5ltr': 'meat, egg and dairy products',
#  'Azzura Gelatiâ€”Azzura Kisses': 'pet feed',
#  'B.-d. Farm Paris Creek Pty Ltdâ€”Paris Creek Cheese Comâ€™n Bear French Style Camembert & Brie French Style Brie': 'cocoa and cocoa preparations, coffee and tea',
#  'Balfour Wauchopeâ€”Cake with Icing': 'cereals and bakery products',
#  'Barillaâ€”Arrabbiata Pasta Sauce & Barilla Pesto Calabrese': 'soups, broths, sauces and condiments',
#  'Begaâ€”So Extra Light 50% Less Fat Tasty Grated Cheese': 'meat, egg and dairy products',
#  'Bella Fantasiaâ€”240mL Hazelnut Gelato and 3-pack Bacio Romantico Gelato': 'cocoa and cocoa preparations, coffee and tea',
#  'Better Choiceâ€”Frozen Cooked and Peeled Prawns': 'soups, broths, sauces and condiments',
#  'Bi-Loâ€”Apricot and Raisin Cake': 'meat, egg and dairy products',
#  'Big Mâ€”Chocolate flavoured Milk': 'cocoa and cocoa preparations, coffee and tea',
#  'Black & Goldâ€”Sliced Shoulder Ham': 'meat, egg and dairy products',
#  'Blue Lotus Foodsâ€”Tofu Cutlets': 'meat, egg and dairy products',
#  'Blue Lotusâ€”Organic tofu hakea & smoked tofu': 'meat, egg and dairy products',
#  'Bluebirdâ€”Incredibites Choc/Hazelnut Snack': 'prepared dishes and snacks',
#  'Borgo Smallgoods Coâ€”Friulano Salame, Lismore Salame and Casalingo Salame': 'cocoa and cocoa preparations, coffee and tea',
#  'Boustani Enterprises Pty Ltdâ€”Tahini Sauce': 'soups, broths, sauces and condiments',
#  'Bruny Island Cheese Coâ€”Soft cheeses': 'meat, egg and dairy products',
#  'Buderim Ginger Ltdâ€”Ginger Lemon & Lime Marmalade': 'meat, egg and dairy products',
#  'Bulla Dairy Foodsâ€”Bulla , Farmland & Homebrand Brand Namesâ€”Low Fat Cottage Cheese, all flavours': 'meat, egg and dairy products',
#  'Byrnes Quality Meatsâ€”Sliced Cooked Meat Products': 'meat, egg and dairy products',
#  'Byrnes Quality Meatsâ€”Sliced Roast Beef and Pepperoni': 'meat, egg and dairy products',
#  'Cadbury Pty Ltdâ€”Cadbury Old Gold Dark Chocolate 70% Cocoa 200g block only': 'cocoa and cocoa preparations, coffee and tea',
#  'Cadbury Pty Ltdâ€”Cadbury Old Gold Dark Chocolate 70% Cocoa 200g block': 'cocoa and cocoa preparations, coffee and tea',
#  'Cadbury Schweppes Pty Ltdâ€”Boost Totally Nuts 60g bar': 'nuts, nut products and seeds',
#  'Cadbury Schweppesâ€”Cottees Hazelnut Spread': 'cocoa and cocoa preparations, coffee and tea',
#  'Cadburyâ€”250g Hazelnut Block Chocolate': 'cocoa and cocoa preparations, coffee and tea',
#  'Cadburyâ€”Teeny Freddo Ice Cream and Party Cake': 'cereals and bakery products',
#  'California Firm Recalls Chicken Product For Undeclared Allergen': 'meat, egg and dairy products',
#  'California Firm Recalls Ground Beef Products Due to Possible Salmonella Contamination': 'meat, egg and dairy products',
#  'Canon Foodsâ€”Chicken and Cheese Schnitzel': 'meat, egg and dairy products',
#  'Casa Dairy Productsâ€”Marinated Feta': 'meat, egg and dairy products',
#  'Cerenâ€”Halva (Middle Eastern Sweet)': 'honey and royal jelly',
#  'Challenge Meats Pty Ltdâ€”Country Lite Ham Steaks': 'meat, egg and dairy products',
#  'Charkas Middle East Foodsâ€”Al-Rabih Brand Tahineh': 'cocoa and cocoa preparations, coffee and tea',
#  'Charkas Middle Eastern Foodsâ€”Al-Ribah Halawa Plain and Pistachio': 'cocoa and cocoa preparations, coffee and tea',
#  'Coca Cola Hellenic Bottling Co withdraws certain batches of 500ml PET bottles of Dr Pepper due to high levels of benzoic acid (Northern Ireland)': 'meat, egg and dairy products',
#  'Coca-Cola Amatil Limitedâ€”Winnie the Pooh Juice Drink 250ml PET Bottles': 'pet feed',
#  'Coles Group Ltdâ€”Coles Smart Buy Frozen Hamburger Patties': 'soups, broths, sauces and condiments',
#  "Coles Group Ltdâ€”You'll Love Coles branded thin BBQ Sausages, Bi-Lo branded BBQ thin BBQ sausages, Coles Smart-Buy branded BBQ Pack and Bi-Lo branded BBQ pack": 'soups, broths, sauces and condiments',
#  "Coles Group Ltdâ€”You'll Love Colesâ€”Basil Pesto Dip": 'soups, broths, sauces and condiments',
#  'Coles Myer Limitedâ€”Farmland Tropical Muesli': 'cocoa and cocoa preparations, coffee and tea',
#  'Coles Myer Ltdâ€”Bi-Lo Shredded Lite Tasty Cheese': 'soups, broths, sauces and condiments',
#  'Coles Myer Ltdâ€”Bilo & Savingsâ€”Choc Coated Ice Cream': 'cocoa and cocoa preparations, coffee and tea',
#  'Coles Myer Ltdâ€”Farmland Apple Oven Baked Fruit Bars': 'nuts, nut products and seeds',
#  'Coles Myer Ltdâ€”Peppermint Choc Coated Muesli Bars': 'cocoa and cocoa preparations, coffee and tea',
#  'Coles Myer Supermarketsâ€”Chocolate Sultanas 400gm': 'cocoa and cocoa preparations, coffee and tea',
#  'Coles Myer Supermarketsâ€”Value Bag Choc Sultanas': 'cocoa and cocoa preparations, coffee and tea',
#  'Coles Myers Pty Ltdâ€”Savings Luncheon Ham and Chicken Meat': 'meat, egg and dairy products',
#  'Coles Supermarketsâ€”Farmland sausage meat': 'meat, egg and dairy products',
#  'Colesâ€”Candy Lane Chocolate Coated Sultanas': 'cocoa and cocoa preparations, coffee and tea',
#  'Colesâ€”Chewy Oat and Raisin and Anzac Cookies': 'meat, egg and dairy products',
#  'Colesâ€”Eucalyptus & Honey Tea Recipe': 'honey and royal jelly',
#  'Colesâ€”Farmland & BI-LOâ€”Fruit juice cordial orange crush 2L': 'nuts, nut products and seeds',
#  'Colesâ€”Farmland Natural Spring Water': 'food additives and flavourings',
#  'Colesâ€”Farmland Tropical Muesli (750g)': 'meat, egg and dairy products',
#  'Colesâ€”Garden Vegetable Pasta Sauce': 'soups, broths, sauces and condiments',
#  'Colesâ€”Parmagiana Beef Rissoles': 'meat, egg and dairy products',
#  'Colesâ€”Premium Fruit Mince Pie 4 Pack': 'nuts, nut products and seeds',
#  'Colesâ€”Savings Brand Frozen Fish Fingers': 'cocoa and cocoa preparations, coffee and tea',
#  'Colesâ€”and Bi-Lo thin BBQ sausages (random weight and assorted pack sizes)': 'soups, broths, sauces and condiments',
#  'Colorado Firm Recalls Ground Beef Products For Possible E. coli O157:H7': 'meat, egg and dairy products',
#  'Confectionery Trading Companyâ€”IGAâ€”Fabulously Fun Lolly Pops': 'nuts, nut products and seeds',
#  'Conga Foods Pty Ltdâ€”Spanish Black Pitted Olives, Green Valley, 350g, Glass Jar': 'meat, egg and dairy products',
#  "Conroy's Smallgoods Pty Ltdâ€”Ham Steaks": 'meat, egg and dairy products',
#  "Conroy's Smallgoods, MQF, Foodland, Drakeâ€”Ready-to-eat meats and smallgoods (excluding bacon)": 'meat, egg and dairy products',
#  "Conroy'sâ€”Polish Sausage": 'soups, broths, sauces and condiments',
#  'Country Cuisine Pty Ltdâ€”Maloufâ€™s Spice Mezza': 'cocoa and cocoa preparations, coffee and tea',
#  'Country Valleyâ€”Classic Cream (minimum 35% fat)': 'cocoa and cocoa preparations, coffee and tea',
#  'Curlwaa Orange Juiceâ€”Various Products': 'nuts, nut products and seeds',
#  "D'Orsognaâ€”Pressed Chicken": 'soups, broths, sauces and condiments',
#  'Darling Downs Baconâ€”Boneless Champagne Leg Ham': 'soups, broths, sauces and condiments',
#  'Darling Downs Foods Pty Ltdâ€”Selected KR Castlemaine products': 'honey and royal jelly',
#  "Darragh's Plaza Butcheryâ€”Sliced Roast Beef": 'meat, egg and dairy products',
#  'Dawn Farm Foods Ltd withdraws cooked bacon used in three own-brand chicken and bacon sandwich fillers due to possible salmonella contamination': 'meat, egg and dairy products',
#  "Day In Import & Export Co Ltd recalls one batch of Guilin Rice Flour Noodles due to the presence of unauthorised 'BT63' genetically modified rice": 'fruits and vegetables',
#  'Dec 11': 'meat, egg and dairy products',
#  'Dec 1': 'cocoa and cocoa preparations, coffee and tea',
#  'Delight Dim Sumâ€”Siu Mai': 'cocoa and cocoa preparations, coffee and tea',
#  "Dick Smith'sâ€”Shortbread Vanilla Creams": 'cocoa and cocoa preparations, coffee and tea',
#  'Dons Smallgoodsâ€”Deli Supreme Premium Smoked Leg Ham': 'meat, egg and dairy products',
#  'Duncan Mannâ€”Black & Gold Choc sultanas': 'cocoa and cocoa preparations, coffee and tea',
#  'Eggs and products thereof in ice cream by Island Farms Dairy from Canada': 'meat, egg and dairy products',
#  'Emerging incident involving distribution of Moubon Yoghurt Dessert from an unapproved establishment': 'cocoa and cocoa preparations, coffee and tea',
#  'Ettason Pty Ltdâ€”Punchun Sesame Sauce, 290g jar': 'alcoholic beverages',
#  'Exquisineâ€”Traditional Chocolate Mousse & Hazelnut Chocolate Mousse': 'cocoa and cocoa preparations, coffee and tea',
#  'F Mayer Imports Pty Ltdâ€”Smoked Salmon (All Natural - Sliced - Ready to Serve), Royal Line, 100gram': 'cocoa and cocoa preparations, coffee and tea',
#  'Fantastic Snacksâ€”Fortune Brand and Jade Brand Instant Cup Noodles': 'soups, broths, sauces and condiments',
#  'Farmwood Delicatessenâ€”Smoked Chicken Breast': 'meat, egg and dairy products',
#  'Favourite Foods Pty Ltdâ€”Mexigos Nacho Cheese & Salso and Mexigos Bean Dip & Nacho Cheese': 'cocoa and cocoa preparations, coffee and tea',
#  'Feb 12': 'cocoa and cocoa preparations, coffee and tea',
#  'Fidlers Choiceâ€”Tasty Cheese': 'alcoholic beverages',
#  'Fishboy Pty Ltdâ€”Salty Chicken, Fuligi Chicken, Sliced Ham and Boneless Pork Hoof': 'meat, egg and dairy products',
#  'Foodland Associated Limitedâ€”Signature Range Classic Caesar Salad Dressing': 'alcoholic beverages',
#  'Foodland Associated Ltdâ€”Basics Brand Frozen Lasagne': 'meat, egg and dairy products',
#  'Foodland Associated Ltdâ€”Signature Range BBQ Flavoured Rice Crackers': 'soups, broths, sauces and condiments',
#  'Foodland Associated Ltdâ€”Signature Range Cereal Bars': 'meat, egg and dairy products',
#  'Foodland Associated Ltdâ€”Signature Range Plain, Seaweed & Tomato Salso Flavoured Rice Crackers': 'soups, broths, sauces and condiments',
#  'Four Bee Meatsâ€”Smoked Premium Leg Ham and Silverside Eye Corn Beef': 'meat, egg and dairy products',
#  'Franklins Limitedâ€”Frozen Chicken Nuggets': 'fruits and vegetables',
#  'Franklins Ltdâ€”Big Fresh & Franklins Fresh Labelled Cakes': 'meat, egg and dairy products',
#  'Franklins Ltdâ€”First Choice Young Corn Cuts': 'meat, egg and dairy products',
#  'Franklins Ltdâ€”No Frillsâ€”Chocolate mint slice biscuits': 'cocoa and cocoa preparations, coffee and tea',
#  'Franklins Pty Ltdâ€”No Frillsâ€”Potato Salad in Mayonnaise': 'meat, egg and dairy products',
#  'Franklinsâ€”No Frills Pizzaâ€”Ham and Pineapple and Supreme varieties': 'meat, egg and dairy products',
#  'Fresco Cheese Company Pty Ltdâ€”Baked Ricotta Cheese': 'meat, egg and dairy products',
#  'Fromagent Australiaâ€”Mauri brand cheese Bon Taleggio Valsassina': 'alcoholic beverages',
#  'Game Farm Enterprises (Qld) Pty Ltdâ€”Top of the Range brand free range eggs': 'meat, egg and dairy products',
#  'George Weston Foods Ltdâ€”Watsonia Salami Slims Original': 'meat, egg and dairy products',
#  'George Weston Foodsâ€”DonÂ® Pre Packaged Kabana': 'cocoa and cocoa preparations, coffee and tea',
#  'George Weston Foodsâ€”Kitchen Collection Brand Bread Mixes': 'meat, egg and dairy products',
#  'Gold Coast Bakery Queensland Pty Ltdâ€”Vogelsâ€”Fruit and Nut Bread': 'nuts, nut products and seeds',
#  'Gold Medal Snacksâ€”Prawn Crackersâ€”Crispy Prawn Snacks': 'meat, egg and dairy products',
#  'Golden Circleâ€”Fruit Salad': 'fruits and vegetables',
#  'Golden Circleâ€”Meal Variety 4 and 8 Pack Baby Food': 'meat, egg and dairy products',
#  'Golden Mountainâ€”Soya Bean Sauce': 'soups, broths, sauces and condiments',
#  'Goodman Fielder Bakingâ€”Pampas Family Chicken and Vegetable Pie': 'soups, broths, sauces and condiments',
#  'Goodman Fielder Consumer Foods Ltdâ€”Figurines included in White Wings Learn to Bake Chocolate Cup Cakes with Chocolate Icing': 'cocoa and cocoa preparations, coffee and tea',
#  'Grand Continental Food Company Pty Ltdâ€”Dried Whole Anchovies': 'soups, broths, sauces and condiments',
#  "Green Valley Dairyâ€”Cheese 100% Pure Cow's milk": 'cocoa and cocoa preparations, coffee and tea',
#  'Green Valleyâ€”Fresh Cheese': 'cocoa and cocoa preparations, coffee and tea',
#  "Green'sâ€”Pastry Mix": 'cocoa and cocoa preparations, coffee and tea',
#  'Gulsanâ€”Halva (Middle eastern sweet also known as Helva or Halwa)': 'honey and royal jelly',
#  'Haberfieldsâ€”Country Fresh Thickened Cream': 'fruits and vegetables',
#  "Haigh's Chocolate and Almond Cookies": 'nuts, nut products and seeds',
#  'Hans Continental Smallgoodsâ€”German Salami (Mettwurst Style)': 'meat, egg and dairy products',
#  'Hans Continental Smallgoodsâ€”Latvian Liverwurst': 'dietetic foods, food supplements, fortified foods',
#  'Harkola Pty Ltdâ€”Halawa with Pistachios (Middle Eastern Sweet also known as helva or halwa)': 'cocoa and cocoa preparations, coffee and tea',
#  'Harvey Fresh Ltdâ€”All White Milk': 'cocoa and cocoa preparations, coffee and tea',
#  'Health Brands Australiaâ€”Healtheries Kidscare Rice Roundsâ€”Cheese and Bacon Flavour': 'meat, egg and dairy products',
#  'Heinzâ€”Baked Beans in Tomato Sauce': 'soups, broths, sauces and condiments',
#  'Heinzâ€”Dijon Mustard Sauce With a Hint of Orange': 'soups, broths, sauces and condiments',
#  'Heinzâ€”Dijon Mustard Sauce with Orange': 'soups, broths, sauces and condiments',
#  'Heinzâ€”Spaghetti In Tomato Sauce, Spaghetti Bolognese & Spaghetti Oops.': 'soups, broths, sauces and condiments',
#  'Heng Fai Trading Co Pty Ltdâ€”Heng Fai Dried Seaweed Brand (Sargassum fusiforme)': 'meat, egg and dairy products',
#  'Heng Heng Tradingâ€”A1 Salted Mackerel': 'meat, egg and dairy products',
#  'Henry Jones Foodsâ€”Allowrie Fruit Of The Forest Jam': 'nuts, nut products and seeds',
#  'Home Brandâ€”Sultanas Milk Chocolate': 'meat, egg and dairy products',
#  'Hong Australia Corp Pty Ltdâ€”Pun Chen Lye Water': 'meat, egg and dairy products',
#  "Hormel Foods Australia Pty Ltdâ€”Kid's Kitchenâ€”Mini Beef Ravioli in Tomato Sauce, 213g": 'meat, egg and dairy products',
#  'Hungs Trading Company Pty Ltdâ€”Seawoods Soft Flour Cake (FSANZ 2005/01)': 'cocoa and cocoa preparations, coffee and tea',
#  'Hunts Foodsâ€”Frozen Hunts Beef Savoury Rice & Chicken Savoury Rice': 'soups, broths, sauces and condiments',
#  'IGAâ€”Christmas Kisses (Cream filled sponge cakes)': 'meat, egg and dairy products',
#  'IXLâ€”Raspberry Conserve': 'nuts, nut products and seeds',
#  'Indiana Firm Recalls Duckling Products': 'cereals and bakery products',
#  'Italian Foodsâ€”Prosciutto Parma whole legs & Serrano ham slices and whole legs': 'soups, broths, sauces and condiments',
#  'J Sainsbury recall Dry Cured York Ham sold from their in-store delicatessen counters': 'meat, egg and dairy products',
#  'J&F Corbo Pty Ltdâ€”Buona Pasta Beef Ravioli and Ravioli Da Brodo': 'meat, egg and dairy products',
#  'Jacobs Well Egg Farmâ€”Jacobs Well Egg Farm Cage Eggs': 'meat, egg and dairy products',
#  'Jalong Goat Dairyâ€”Frozen Goat Milk, Soft Cheese & Fetta': 'meat, egg and dairy products',
#  'Jalong Goat Dairyâ€”Plain Gormet Fetta, Fetta with Chives and Fetta with Sun-dried Tomato and Olives': 'meat, egg and dairy products',
#  'John Westâ€”Scottish sardines In vegetable oil': 'meat, egg and dairy products',
#  'Jun 15': 'food contact materials',
#  'Jun 26': 'meat, egg and dairy products',
#  'Jun 8': 'cocoa and cocoa preparations, coffee and tea',
#  'KR Darling Downâ€”Boneless Champagne Leg Ham Portions': 'soups, broths, sauces and condiments',
#  'Kadac Pty Ltdâ€”Ancient Harvest Brand Quinoa Supergrain Pasta': 'meat, egg and dairy products',
#  'Kadac Pty Ltdâ€”Whole Earth Brand Organic Cornflakes': 'cocoa and cocoa preparations, coffee and tea',
#  'Kaisi Australia Pty Ltdâ€”Kirin Milk Tea': 'cocoa and cocoa preparations, coffee and tea',
#  'Kinnerton Confectionary Australia Pty Ltdâ€”Spiderman 3â€”Ceramic Mug and Egg': 'meat, egg and dairy products',
#  'Kmartâ€”Boxed Chocolates And Easter Chocolate Items': 'cocoa and cocoa preparations, coffee and tea',
#  'Koh-kaeâ€”Peanuts coconut cream flavour': 'cocoa and cocoa preparations, coffee and tea',
#  "Kooka's Country Cookiesâ€”Choc Coated Assorted": 'cocoa and cocoa preparations, coffee and tea',
#  'Koz Worldwide Importsâ€”Ttangkong Kangjung (Peanut Snack)': 'nuts, nut products and seeds',
#  'Kyana Farmsâ€”IGA Deli Roast Beef': 'meat, egg and dairy products',
#  'La Toscaâ€”Sugodoro bolognese Sauce with beef': 'meat, egg and dairy products',
#  'Liquorlandâ€”Scotch Whiskyâ€”Hankey Bannister': 'alcoholic beverages',
#  'Lismore Country Meatsâ€”Sliced Leg Ham': 'meat, egg and dairy products',
#  'Lolliland Pty Ltdâ€”Quanta Armadaâ€”Soft nougat caramel and peanuts in milk chocolate': 'cocoa and cocoa preparations, coffee and tea',
#  'Lucas Quality Meatsâ€”Sliced Virginia Leg Ham': 'meat, egg and dairy products',
#  'Madelaine Confectionery Pty Ltdâ€”Madelaine Gummy Baby Crocodiles, Madelaine Gummy Day Old Chicks and Madelaine Gummy Coral Fish.': 'meat, egg and dairy products',
#  'Manassen Foods Australia Pty Ltdâ€”Atkins Advantage Chocolate Decadence Bar': 'nuts, nut products and seeds',
#  'Manassen Foods Australia Pty Ltdâ€”Globus Dill Cucumbers (Polski Ogorki)': 'nuts, nut products and seeds',
#  'Manassen Foods Australia Pty Ltdâ€”Trident Multigrain Rice Cakes': 'cereals and bakery products',
#  'Manassen Foods Australia Pty Ltdâ€”Trident Oriental Favouritesâ€”Pad Thai Noodles': 'meat, egg and dairy products',
#  "Manassen Foods Pty Ltdâ€”McVitie's The Original Digestive": 'cocoa and cocoa preparations, coffee and tea',
#  'Manassen Foodsâ€”Trident Rice Crackers (Teriyaki Flavour)': 'soups, broths, sauces and condiments',
#  'Manifold Food Trading Pty Ltdâ€”Chinese Gingili Paste (Sesame Paste)': 'cocoa and cocoa preparations, coffee and tea',
#  'Marco Polo Foods Pty Ltdâ€”Trata Brand Anchovy Fillets in Sunflower Oil': 'meat, egg and dairy products',
#  'Marks & Spencer plc withdraws batches of its own brand Strawberry & Almond Crunch due to incorrect allergy labelling': 'nuts, nut products and seeds',
#  'Marks & Spencer recalls own-brand 3 Bean & Spinach Salad with Chive Dressing due to incorrect labelling information': 'cocoa and cocoa preparations, coffee and tea',
#  'Marks & Spencer withdraws cheesecake desserts due to possible metal contamination': 'cocoa and cocoa preparations, coffee and tea',
#  'Mars Confectioneryâ€”Starburst Lollipops': 'honey and royal jelly',
#  "Mary's Pasta Productsâ€”various pasta products": 'meat, egg and dairy products',
#  'Masterfoodsâ€”Dolmio Tomato Sauces': 'soups, broths, sauces and condiments',
#  'Masterfoodsâ€”Mars and Snickers Bars': 'alcoholic beverages',
#  'Masterfoodsâ€”Marsâ€”Fundraising speckled eggs boxes': 'meat, egg and dairy products',
#  'May 25': 'cocoa and cocoa preparations, coffee and tea',
#  'McCainâ€”Stir Fry Vegetables Pasta Alfredo with Sauce': 'soups, broths, sauces and condiments',
#  'Menora Foods Pty Ltdâ€”Jindi Cheese, Top Paddock, Wattle Valley and Willow Grove Cheese': 'nuts, nut products and seeds',
#  'Montefiore Cheese (Aust) P/Lâ€”Montefiore Cheese Mozzarella Fiorello': 'cocoa and cocoa preparations, coffee and tea',
#  'Mountain Creek Meatsâ€”Silverside and Boneless Ham': 'meat, egg and dairy products',
#  "Mrs Mac'sâ€”All products, individually wrapped only. All Bakewell and Bakewell Classic Products. All Mrs Mac's Good Eating products, individually wrapped only. Red Embers Chicken Leek & Mushroom Pies, Greek Souvlaki Pies and Premium Sausage Roll": 'soups, broths, sauces and condiments',
#  "Mum's Choice Pty Ltdâ€”Baba-Ghannouje": 'meat, egg and dairy products',
#  'Mur Thai Food Co Pty Ltdâ€”Vinawang Pumpkin Seed Cake 100g Cellophone pack': 'meat, egg and dairy products',
#  'National Foods Limitedâ€”Baby Yoplait and Yoplait ElivaÃ© Yoghurt': 'cocoa and cocoa preparations, coffee and tea',
#  'National Foods Ltdâ€”Fruche': 'cocoa and cocoa preparations, coffee and tea',
#  "National Foods Ltdâ€”Yo-Split Vanilla Yogurt with Muesli 'n Fruit": 'fruits and vegetables',
#  'National Foods Pty Ltdâ€”Tilba Cheese': 'cocoa and cocoa preparations, coffee and tea',
#  'National Foodsâ€”Milk Products': 'cocoa and cocoa preparations, coffee and tea',
#  'Naturally Good Products Pty Ltdâ€”Soy Carob Products': 'soups, broths, sauces and condiments',
#  'Naturally Good, Deliciously Freeâ€”Moist Chocolate Mudcake mix': 'cocoa and cocoa preparations, coffee and tea',
#  'Nebraska Firm Recalls Beef Tongues That Contain Prohibited Materials': 'meat, egg and dairy products',
#  'Nestleâ€”Billabong chocolate ice cream 8 pack': 'nuts, nut products and seeds',
#  'NestlÃ©â€”Kit Kat Caramel & Kit Kat Cookie Dough': 'cocoa and cocoa preparations, coffee and tea',
#  'NestlÃ©â€”Maggi Liquid Cooking Sauce': 'soups, broths, sauces and condiments',
#  'NestlÃ©â€”Maggiâ€”Frozen Macaroni Cheese': 'cocoa and cocoa preparations, coffee and tea',
#  'NestlÃ©â€”Nan 2 H.A. Gold Infant Formula': 'meat, egg and dairy products',
#  'New World Trading Company Pty Ltdâ€”Preserved Bean Curd â€“ Sakura, Fermented Bean Curd - in dressing with Chili and Liu Ma Bao Kee â€“ Preserved Bean Sauce': 'soups, broths, sauces and condiments',
#  'New York Firm Recalls Fresh Ground Beef Products Due To Possible E. coli O157:H7 Contamination': 'meat, egg and dairy products',
#  'Nocelle Foodsâ€”Various Pistachio Products': 'cocoa and cocoa preparations, coffee and tea',
#  'Norco Co-Operativeâ€”Richmond Vanilla Icecream': 'cocoa and cocoa preparations, coffee and tea',
#  'North Dakota Firm Recalls Whole Beef Head Products That Contain Prohibited Materials': 'meat, egg and dairy products',
#  'Nut Producers Australiaâ€”Value Pack Dry Roasted and Salted Pistachios': 'nuts, nut products and seeds',
#  'Nutellaâ€”Hazelnut Spread in Collectable Glasses': 'cocoa and cocoa preparations, coffee and tea',
#  'Oceanic Foodâ€”Sichuan Spicy Noodle': 'soups, broths, sauces and condiments',
#  'Oct 11': 'cocoa and cocoa preparations, coffee and tea',
#  'Oct 6': 'meat, egg and dairy products',
#  'Oriental Merchant Pty Ltdâ€”Shandong Peanuts (Peanuts in Shells)': 'cocoa and cocoa preparations, coffee and tea',
#  'Oriental Merchantâ€”Koh-kae peanuts coconut cream flavour': 'cocoa and cocoa preparations, coffee and tea',
#  'P & M Quality Smallgoods Pty Ltdâ€”Courtway Continental Double Smoked Leg Ham, Deli Style Slices': 'meat, egg and dairy products',
#  'P & M Quality Smallgoods Pty Ltdâ€”Primo Cocktail Frankfurts': 'alcoholic beverages',
#  'PRESENCE OF UNDECLARED PEANUT BUTTER IN CHOCOLATE ICE CREAM CAKE MANUFACTURED BY ICE CREAM UNLIMITED INC.': 'meat, egg and dairy products',
#  'Paesanella Cheese Manufacturersâ€”Stracchino Cheese & Fresh Peccornio Cheese': 'alcoholic beverages',
#  'Paesanella Cheeseâ€”Bocconcini cheese': 'soups, broths, sauces and condiments',
#  'Parilla Freshâ€”Woolworths brand, Action brand Alfalfa sprouts': 'fruits and vegetables',
#  'Parillaâ€”Fresh and Woolworths brand Alfalfa Sprouts': 'fruits and vegetables',
#  'Parmalat Australia Limitedâ€”PhysiCAL No Fat Milk': 'meat, egg and dairy products',
#  'Parmalat Australia Ltdâ€”Chocolate flavoured milk UHT Longlife': 'cocoa and cocoa preparations, coffee and tea',
#  'Parmalat Australia Ltdâ€”Pauls Vanilla Custard': 'meat, egg and dairy products',
#  'Parmalat Foods Australia Pty Ltdâ€”Fresh Milk packed in 2 litre plastic bottles': 'meat, egg and dairy products',
#  'Parmalat Foods Australia Pty Ltdâ€”Skinny Milk': 'cocoa and cocoa preparations, coffee and tea',
#  "Patak's Foods Limitedâ€”Rogan Josh Simmer Sauce": 'soups, broths, sauces and condiments',
#  'Paulsâ€”Breaka chocolate UHT milk': 'cocoa and cocoa preparations, coffee and tea',
#  'Pavlova Pantryâ€”Lamingtons': None,
#  'Pernod Ricard Pacific Pty Ltdâ€”Maison Supreme, White, Rose and Lambrusco': 'alcoholic beverages',
#  'Pixie Ice Creamâ€”Berry Koolick flavour Ice Blocks': 'meat, egg and dairy products',
#  'Polycyclic aromatic hydrocarbons in olive pomace oil by Aris Calamata from Greece': 'cocoa and cocoa preparations, coffee and tea',
#  'Polycyclic aromatic hydrocarbons in olive pomace oil by Grifo, San Remo, La Molisana from Italy': 'cocoa and cocoa preparations, coffee and tea',
#  'Primo Smallgoodsâ€”Corned Silverside': 'pet feed',
#  'Primo Smallgoodsâ€”Shaved Chicken Breast': 'meat, egg and dairy products',
#  'Princi Smallgoodsâ€”Fermented Dry Italian sausage cacciatore': 'soups, broths, sauces and condiments',
#  "Product recall of Marks & Spencer Cheesy Spirals 'Loved by Kids' meal": 'cocoa and cocoa preparations, coffee and tea',
#  "Product recall of Unilever Bestfoods Ltd Bertolli brand 'Pesto Rosso' sauce 185g jar": 'soups, broths, sauces and condiments',
#  'Product recall of various brands of frozen ready-to-eat meals with rice due to possible glass contamination': 'cocoa and cocoa preparations, coffee and tea',
#  'Product withdrawal of Pork Farms, Bowyers, Marks and Spencer and Somerfield brand Scotch eggs, picnic eggs and Savoury Bites': 'meat, egg and dairy products',
#  'Pronasindo Australia Pty Ltd trading as Simply The Best Smallgoodsâ€”Leg Ham Portion â€“ Simply The Best and Leg Ham Portion â€“ Harris Farm': 'meat, egg and dairy products',
#  'Pura And Woolworthsâ€”Whole Milk': 'cocoa and cocoa preparations, coffee and tea',
#  'Puraâ€”UHT (Long Life) Whole Milk': 'cereals and bakery products',
#  'Puraâ€”UHT (long life) Whole Milk': 'cereals and bakery products',
#  'Quaker Oats Ltd withdraws a batch of Quaker Oats due to the presence of moth pupae and larvae within the product': 'soups, broths, sauces and condiments',
#  'Recall Notification Report 006-2001': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification Report 075-2000, Expanded': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-001-94': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-002-95': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-003-95': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-005-94': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-006-95': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-006-97': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-009-94': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-009-96': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-010-97': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-011-98': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-014-94': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-014-97': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-015-97': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-016-97': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-017-96': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-017-97': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-017-98': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-018-94': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-018-97': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-020-98': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-021-95': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-021-97': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-022-97': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-023-96': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-023-97': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-023-98': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-024-94': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-024-96': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-025-95': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-026-94': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-033-94': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-035-98': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-037-98': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-038-95': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-041-95': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-044-94': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall Notification: FSIS-045-94': 'cocoa and cocoa preparations, coffee and tea',
#  'Recall of Certain Bottled Mineral Water in the United States and Canada (Updated on 12 March 2007)': 'alcoholic beverages',
#  'Recall of Certain Bottled Mineral Water in the United States and Canada (Updated on 26 March 2007)': 'alcoholic beverages',
#  'Red Dragon Foods Pty Ltdâ€”Glory Brand Rice Cookies': 'meat, egg and dairy products',
#  "Ricegrowers' Co-operativeâ€”Long Grain Jasmine Rice": 'prepared dishes and snacks',
#  'Riviana Foods Pty Ltdâ€”Always Fresh Baby Clams - Tin Can 200g': 'meat, egg and dairy products',
#  "Roger's Select Meatsâ€”Roast Beefâ€”Ready-to-Eat meat": 'meat, egg and dairy products',
#  'Rosemount Estateâ€”Semillon Sauvignon Blanc Wine': 'alcoholic beverages',
#  'Safcolâ€”95g Premium Selection Tuna Range with Gold Foil Top Packaging and 95g Sandwich Delite Tuna Range with Gold Foil Top Packaging': 'soups, broths, sauces and condiments',
#  'Sanhuo Pty Ltdâ€”Sunlight White Sesame Seeds': 'nuts, nut products and seeds',
#  "Schweppes Australia Pty Ltdâ€”All 2 Litre Cottee's Cordial Flavours": 'cocoa and cocoa preparations, coffee and tea',
#  'Simplot Australiaâ€”Frozen Neptune Black Tiger Prawns': 'meat, egg and dairy products',
#  'Smashing Pumpkinsâ€”Yoghurt Sultanas Tubs': 'cocoa and cocoa preparations, coffee and tea',
#  'Solomon Kosher Butcher Pty Ltdâ€”Premium beef mince (diet beef mince)': 'meat, egg and dairy products',
#  'Sony Trading Pty Ltdâ€”Wong Coco Konnyaku Jelly and Wong Coco Mini Jelly Nata de Coco': 'cocoa and cocoa preparations, coffee and tea',
#  'Spiroski Foods Pty Ltdâ€”Chocolate, Hazelnut and Vanilla Duo Spread': 'cocoa and cocoa preparations, coffee and tea',
#  'Sunbeam Foods Pty Ltdâ€”Angas Park and Sunbeam brand dried fruits': 'cocoa and cocoa preparations, coffee and tea',
#  'Sunbeam Pistachios': 'cocoa and cocoa preparations, coffee and tea',
#  'Sunsolâ€”Natural Fruity Muesli 750 gm': 'fruits and vegetables',
#  'Supa IGAâ€”Large BBQ Chickens': 'meat, egg and dairy products',
#  'Suzuran Japan Foods Trading Pty Ltdâ€”Dried seaweed urashima yaki sushi nori 28G 10 oz packet': 'seafood',
#  'Swan Valley Cheese Companyâ€”Fetta Cheese Products': 'nuts, nut products and seeds',
#  'Sweet Successâ€”Cherry & Coconut Chocolate Bar 90gm': 'cocoa and cocoa preparations, coffee and tea',
#  'Swift and Moore Pty Ltdâ€”Kahlua and Milk': 'cocoa and cocoa preparations, coffee and tea',
#  'T & D Trading Co Pty Ltdâ€”Aroy-Dâ€”Mussaman curry soup': 'soups, broths, sauces and condiments',
#  'T & D Trading Co Pty Ltdâ€”Loong Heedâ€”Instant Tai Pla (Fish and spice) Paste': 'meat, egg and dairy products',
#  'Tan & Co. Pty Ltdâ€”Frozen coconut milk with Taro (ice cream)': 'cocoa and cocoa preparations, coffee and tea',
#  'Tarac Australiaâ€”Beenleigh Dark Rum': 'alcoholic beverages',
#  'Tender Choice Foods(Aust) Pty Ltdâ€”Oven Roasted Skinless Sliced Chicken 5kg and 1kg': 'meat, egg and dairy products',
#  'Texas Firm Recalls Beef Trim Products Due To Possible E. coli O157:H7 Contamination': 'meat, egg and dairy products',
#  'The Australian Football Leagueâ€”AFL 2003 Auskick Plastic Drink Bottles': 'cocoa and cocoa preparations, coffee and tea',
#  'The Good Stuff Bakeryâ€”White Bread': 'cereals and bakery products',
#  'The Kettle Chip Companyâ€”Chilli Potato Chips': 'fruits and vegetables',
#  'The Natural Ice Cream Companyâ€”Fruccio Ice Dessert and Fruccio Vanilla Cups': 'cocoa and cocoa preparations, coffee and tea',
#  'The Quang Pty Ltdâ€”Sesame Cake, Mango Pudding and Coconut Cookies.': 'cocoa and cocoa preparations, coffee and tea',
#  "The Smith's Snackfood Companyâ€”Smiths's Classic Crinkle Cut Potato Chips": 'soups, broths, sauces and condiments',
#  'Tibaldi Smallgoodsâ€”Loin Capocollo mild': 'meat, egg and dairy products',
#  'Tonys Meatsâ€”Pork Loin Cherry and Walnut, Pork Loin Apricot and Macadamia & Greek BBQ Butterfly Lamb Leg': 'meat, egg and dairy products',
#  'Top Tasteâ€”Various products': 'alcoholic beverages',
#  'Trade withdrawal of 500ml Ballygowan Pure Irish Still Water': 'alcoholic beverages',
#  'Turkey And Chicken Products Recalled From Texas Plant For PossibleListeria Contamination': 'meat, egg and dairy products',
#  'Uncle Tobysâ€”Bluebird Dunkaroos Biscuits': 'cocoa and cocoa preparations, coffee and tea',
#  'Uncle Tobysâ€”Le Snak Rice Crackers, BBQ Flavoured with Mild Salsa Dip': 'soups, broths, sauces and condiments',
#  "Uncle Tobysâ€”Plus Sultanas 'n Bran": 'cocoa and cocoa preparations, coffee and tea',
#  'United Biscuits recalls certain batches of its Go Ahead! brand Crispy Fruit Slices and Yoghurt Breaks due to possible metal contamination': 'cocoa and cocoa preparations, coffee and tea',
#  'Update on Jumbo Palm Oil': 'meat, egg and dairy products',
#  'Valcorp Fine Foodsâ€”Gee Vee mild chillies in brine': 'soups, broths, sauces and condiments',
#  'Vastrade Pty Ltdâ€”Sesame Sauce': None,
#  'Vihenthi Co Pty Ltdâ€”Hello Bee Bee Pon Rice Snack (Gaueteau de Riz)': 'meat, egg and dairy products',
#  'Village Cheeseâ€”Halloumi cheese': 'meat, egg and dairy products',
#  'WM Morrison recall of deli cooked lamb from their instore delicatessen counters': 'meat, egg and dairy products',
#  'Wah Lien Trading Pty Ltdâ€”Horlicks drink powder': 'alcoholic beverages',
#  'Wah Lien Trading Pty Ltdâ€”Konnyaku Jelly Powder': 'meat, egg and dairy products',
#  'Wah Lien Trading Pty Ltdâ€”Shui Kou Preserved Bean Curd (Chilli)': 'soups, broths, sauces and condiments',
#  'Wanjashanâ€”Soy Sauce': 'soups, broths, sauces and condiments',
#  'Warning on Bottled Mineral Water Suspected of Containing Foreign Matter': 'cocoa and cocoa preparations, coffee and tea',
#  'Wattle Valleyâ€”Chunky Dip Chilli Red with Cashew and Parmesan': 'soups, broths, sauces and condiments',
#  'Wei Wah International Trading Pty Ltdâ€”Lion Globe Dry Seaweed 50g': 'meat, egg and dairy products',
#  'Weight Watchers Australiaâ€”Rich Toffee Bars': 'cocoa and cocoa preparations, coffee and tea',
#  'Welsh Country Foods Ltd recalls certain batches of lamb meat and offal due to possible presence of veterinary medicine residues': 'meat, egg and dairy products',
#  'Whisk and Pinâ€”Gluten Free Muesli': 'meat, egg and dairy products',
#  'White Wingsâ€”Cornflour 300 G': 'cereals and bakery products',
#  'Whitestone Windsor Blue Cheese': 'cocoa and cocoa preparations, coffee and tea',
#  'Willow Confectioneryâ€”60g Dark Chocolate Easter Egg': 'meat, egg and dairy products',
#  'Win Kwong Pty Ltdâ€”Punchun Sesame Sauce': 'soups, broths, sauces and condiments',
#  'Wisconsin Firm Recalls Beef Tongues That Contain Prohibited Materials': 'meat, egg and dairy products',
#  'Withdrawal of two brands of olive-pomace oil': 'cocoa and cocoa preparations, coffee and tea',
#  'Wm Morrison Supermarkets plc recalls a certain date code of its own brand Toffee & Pecan Ice Cream due to possible contamination with pieces of rubber': 'food additives and flavourings',
#  'Woolworths Limitedâ€”All Lamb Products': 'meat, egg and dairy products',
#  'Woolworths Limitedâ€”BBQ Chickens Extra Large': 'meat, egg and dairy products',
#  'Woolworths Limitedâ€”Fruity Muesli Cookies': 'fruits and vegetables',
#  'Woolworths Limitedâ€”Home Brand Frozen Chicken Nuggets': 'meat, egg and dairy products',
#  'Woolworths Limitedâ€”Home Brand Jasmine Rice': 'prepared dishes and snacks',
#  'Woolworths Limitedâ€”Home Brand Mini Spring Rolls 6 pack': 'meat, egg and dairy products',
#  'Woolworths Limitedâ€”Home Brand Oyster Sauce': 'meat, egg and dairy products',
#  'Woolworths Limitedâ€”Home Brand Scorched Almonds Milk Chocolate': 'cocoa and cocoa preparations, coffee and tea',
#  'Woolworths Limitedâ€”Home Brandâ€”Assorted Biscuits': 'pet feed',
#  'Woolworths Limitedâ€”Home Brandâ€”Nacho Cheese Flavoured Corn Chips': 'soups, broths, sauces and condiments',
#  'Woolworths Limitedâ€”Home brand white sliced sandwich bread': 'meat, egg and dairy products',
#  'Woolworths Limitedâ€”Homebrand Corn & Chicken flavour noodles': 'soups, broths, sauces and condiments',
#  'Woolworths Limitedâ€”Homebrand Wheat Biscuits Cereal Retail Pack': 'cereals and bakery products',
#  'Woolworths Limitedâ€”Homebrandâ€”Mackerel in Natural Oil': 'food additives and flavourings',
#  'Woolworths Limitedâ€”Label Regular Minced Lamb': 'meat, egg and dairy products',
#  'Woolworths Limitedâ€”Minced Lamb, Veal, Pork, Heart Smart Beef, Regular Beef or Premium Beef': 'meat, egg and dairy products',
#  'Woolworths Limitedâ€”Premium Beef Mince and Regular Beef Mince': 'meat, egg and dairy products',
#  'Woolworths Limitedâ€”Woolworths Carbonara Pasta Salad': 'soups, broths, sauces and condiments',
#  'Woolworths Limitedâ€”Woolworths Fresh Milk Lite 2 L': 'cocoa and cocoa preparations, coffee and tea',
#  'Woolworths Limitedâ€”Woolworths label Minced Heart Smart Beef': 'meat, egg and dairy products',
#  'Woolworths Supermarketsâ€”Pork mince': 'meat, egg and dairy products',
#  'Woolworths Supermarketsâ€”Pre-Packed Gourmet Lettuce': 'honey and royal jelly',
#  'Woolworthsâ€”Bread soft wholemeal loaf 800g': 'cereals and bakery products',
#  'Woolworthsâ€”Regular Minced Beef': 'meat, egg and dairy products',
#  "Yuen's Market Trading Companyâ€”Pun Chun Lye Water": 'fats and oils',
#  'island2island Beverage Comp. Pty Ltdâ€”Angostura Lemon Lime and Bitters & Angostura Lemon Lime and Bitters light': 'cocoa and cocoa preparations, coffee and tea',
#  'marks & spencer recalls a number of own-brand cake products due to contamination with coloured plastic strands': 'cocoa and cocoa preparations, coffee and tea',
#  'oct 6': 'cocoa and cocoa preparations, coffee and tea'}

# %%
df[:10]
# Out:
#                                                title  \
# 0  2006 - Consumer Alert: Listeria Contamination ...
# 1  2006 - Pinnacle Foods Corporation Issues Aller...
# 2  2006 - Pinnacle Foods Group Inc. Issues Allerg...
# 3  2006 - pinnacle foods group inc. issues allerg...
# 4  2007 - Agriculture Department Warns Consumers ...
# 5  2007 - WholeSoy & Co. Expands National Allergy...
# 6  2007 - Winn-Dixie Stores, Inc. Issues Allergy ...
# 7  2007 - private selectionÂ® ice cream recalled ...
# 8  2008 - Barry Callebaut USA LLC Issues Allergen...
# 9  2008 - dreyer's issues voluntary recall of slo...
#
#                                      extracted_terms
# 0          [listeria, milk, contamination, raw milk]
# 1  [corporation, allergy, pinnacle, foods, muffin...
# 2                 [egg, allergy, frozen, undeclared]
# 3                                 [allergy, brownie]
# 4  [butler, dairy, county, tainted, raw, milk, wa...
# 5                [allergy, dairy, blueberry, yogurt]
# 6                        [allergy, issue, chocolate]
# 7  [store, recalled, cream, ice, stores, private,...
# 8  [chocolate, chip, milk, protein, allergen, iss...
# 9  [undeclared, pecans, recall, dreyer, caramel, ...

# %%
# def classify_title_keywords(df, products, hazards, G, max_distance=5):
#     """
#     Classify title keywords into categories based on distance to product and hazard subgraphs.

#     Parameters:
#     - df (pd.DataFrame): DataFrame containing 'title' and 'extracted_terms' columns.
#     - products (dict): Dictionary mapping product categories to their keywords.
#     - hazards (dict): Dictionary mapping hazard categories to their keywords.
#     - G (networkx.Graph): The ConceptNet graph.
#     - max_distance (int): Maximum BFS distance to consider.

#     Returns:
#     - classifications (dict): Dictionary mapping titles to their classified category.
#     """
#     classifications = {}


#     dc = 0

#     # Iterate over each title and classify
#     for _, row in df.iterrows():
#         title = row['title']
#         keywords = row['extracted_terms']
#         min_distance = float('inf')
#         assigned_category = None

#         for keyword in keywords:
#             keyword_uri = f"/c/en/{keyword.replace(' ', '_').lower()}"

#             # Check distance in product categories
#             for cat, distances in product_distances.items():
#                 distance = distances.get(keyword_uri, float('inf'))
#                 if distance < min_distance:
#                     min_distance = distance
#                     assigned_category = f"Product: {cat}"


#             # Check distance in hazard categories
#             for cat, distances in hazard_distances.items():
#                 distance = distances.get(keyword_uri, float('inf'))
#                 if distance == 'inf':
#                   dc+=1
#                 if distance < min_distance:
#                     min_distance = distance
#                     assigned_category = f"Hazard: {cat}"

#         # Assign the category with the shortest distance
#         classifications[title] = assigned_category

#     return classifications

# %% [markdown]
# # Working

# %%
classifications = classify_title_keywords(df, products, hazards, G)

# %%
classifications
# Out:
# {'2006 - Consumer Alert: Listeria Contamination in Raw Milk': 'Product: alcoholic beverages',
#  '2006 - Pinnacle Foods Corporation Issues Allergy Alert on Bakery-Style Chocolate Chip Muffin Mix': 'Product: dietetic foods, food supplements, fortified foods',
#  '2006 - Pinnacle Foods Group Inc. Issues Allergy Alert on Undeclared Egg in Frozen': 'Product: meat, egg and dairy products',
#  '2006 - pinnacle foods group inc. issues allergy alert on brownie mix': 'Product: other food product / mixed',
#  '2007 - Agriculture Department Warns Consumers of Tainted Raw Milk Sold by Butler County Dairy': 'Product: alcoholic beverages',
#  '2007 - WholeSoy & Co. Expands National Allergy Alert on Undeclared Dairy in Blueberry and Mixed Berry Yogurt': 'Product: dietetic foods, food supplements, fortified foods',
#  '2007 - Winn-Dixie Stores, Inc. Issues Allergy Alert on Mislabeled Prestige Chocolate Ice Cream': 'Product: cocoa and cocoa preparations, coffee and tea',
#  '2007 - private selectionÂ® ice cream recalled from ralphs and food 4 less stores in california': 'Product: dietetic foods, food supplements, fortified foods',
#  '2008 - Barry Callebaut USA LLC Issues Allergen Alert on Undeclared Milk Protein in Kroger Value Semi Sweet Chocolate Chips': 'Product: cocoa and cocoa preparations, coffee and tea',
#  "2008 - dreyer's issues voluntary recall of slow churnedÂ® light caramel delight and butter pecan ice cream flavors for undeclared pecans": 'Product: dietetic foods, food supplements, fortified foods',
#  '2008 - limited number of aunt jemima pancake & waffle mix products recalled for possible health risk': 'Hazard: other hazard',
#  "2008 - pierre's ice cream company issues allergy alert on its homestyle brand of dutch chocolate ice cream for undeclared peanut butter cup candies": 'Product: dietetic foods, food supplements, fortified foods',
#  '2008 - private selection ice cream recalled from kroger stores in twelve southeastern states': 'Product: cereals and bakery products',
#  '2009 - A Manufacturer From England, Cropwell Bishop Creamery Limited, is Conducting a Nationwide Recall on the Cheese Products Blue Stilton and Shropshire Blue Cheese Because of Possible Health Risk': 'Product: cereals and bakery products',
#  '2009 - BIC Acquisition, LLC Recalls World Classic Trading Company Ultimate Chunk Ice Cream': 'Product: ices and desserts',
#  '2009 - Bliss Bros. Dairy, Inc. Recalls Ice Cream Products Because of Possible Health Risk': 'Product: cereals and bakery products',
#  "2009 - Braum's Ice Cream and Dairy Stores Announces Voluntary Recall of its Premium Ice Cream Flavor": 'Product: dietetic foods, food supplements, fortified foods',
#  '2009 - Bucks Ice Cream Recalls Ice Cream Nut Roll Because of Possible Health Risk': 'Product: nuts, nut products and seeds',
#  '2009 - Fieldbrook Foods Corp. Announces Nationwide Voluntary Recall of Select Ice Cream Novelty Products Due to Possible Health Risk': 'Product: cereals and bakery products',
#  '2009 - Fieldbrook Foods Corporation Adds Four Products to Nationwide Voluntary Recall of Select Ice Cream Novelty Products Due to Possible Health Risk': 'Product: cereals and bakery products',
#  '2009 - Garden-Fresh Foods Issues Allergy Alert On Undeclared Milk in 16-Ounce Archer Farms Potato Salad': 'Product: alcoholic beverages',
#  '2009 - Glutenfreeda Foods, Inc. Recalls Peanut Envy Frozen Cookie Dough Because of Possible Health Risk': 'Hazard: other hazard',
#  '2009 - Hershey Creamery Announces Voluntary Recall of Goo Goo Peanut Butter Ice Cream Because of Possible Health Risk': 'Hazard: other hazard',
#  '2009 - Ice Cream Specialties Announces Nationwide Recall of Ice Cream Novelties Because of Possible Health Risk': 'Hazard: other hazard',
#  '2009 - Kroger Recalls Additional Select Ice Cream Product Due to Possible Health Risk': 'Hazard: other hazard',
#  '2009 - Kroger Recalls Select Ice Cream Products Due to Possible Health Risk': 'Product: cereals and bakery products',
#  "2009 - Mooresville Ice Cream Co. Conducts Carolinas Recall of Half Gallon and Three Gallon containers of 'Chocolate Peanut Butter Delight' flavor of DeLuxe Ice Cream Because Of Possible Health Risk": 'Hazard: other hazard',
#  "2009 - Perry's Ice Cream Company Adds Products to Voluntary Recall of Select Peanut Butter Ice Cream Products as a result of PCA Expanded Recall": 'Product: ices and desserts',
#  '2009 - Rich Products Corporation announces nationwide voluntary recall of Peanut Butter Blast Pie and Red Robin 10': 'Product: cereals and bakery products',
#  '2009 - Shamrock Foods Company Issues Voluntary Recall on Nutty Sundae Cones': 'Product: dietetic foods, food supplements, fortified foods',
#  '2009 - Turner Holdings Recalls Peanut Butter Bars Because of Possible Health Risk': 'Hazard: other hazard',
#  '2009 - Unilever Issues Allergy Alert on Wheat in a Limited Number of Tubs of Breyers Ice Cream': 'Product: dietetic foods, food supplements, fortified foods',
#  '2009 - Unilever United States, Inc. Conducts Nationwide Voluntary Recall Of Breyers Tin Roof Sundae Ice Cream Products with Peanuts Due to Possible Health Risk': 'Product: dietetic foods, food supplements, fortified foods',
#  '2009 - Velvet Ice Cream Pulling Cone Products': 'Product: cereals and bakery products',
#  '2009 - arya ice cream dist. co., inc. recalls california dream nut sundae because of possible health risk': 'Hazard: other hazard',
#  '2009 - austinuts wholesale, inc. announces voluntary recall of organic peanuts': 'Product: dietetic foods, food supplements, fortified foods',
#  '2009 - belfonte ice cream and dairy foods co. announces voluntary recall of ice cream due to possible health risk': 'Hazard: other hazard',
#  "2009 - casper's ice cream, inc. voluntarily recalls fat boyÂ® cascoÂ® nut sundae on a stick and fat boyÂ® cascoÂ® cherry cordial nut sundae on a stick products because of possible health risk": 'Product: cereals and bakery products',
#  '2009 - deluxe ice cream co. expands recall to include additional codes of tin roof sundae, goo goo cluster, and candy bar half gallon packaged ice cream product, 3 gallon tin roof sundae and qc 24 pack sundae cone because of possible health risk': 'Product: dietetic foods, food supplements, fortified foods',
#  '2009 - edaleen dairy recalls tin roof sundae ice cream and chocolate peanut butter nut ice cream because of possible health risk': 'Product: nuts, nut products and seeds',
#  "2009 - garber's ice cream company issues voluntary recall on half gallon tin roof sundae ice cream and nutty cones due to expanded peanut recall by peanut corporation of america (pca)": 'Product: nuts, nut products and seeds',
#  '2009 - h-e-b issues precautionary and voluntary recall for creamy creations peanut brittle ice cream': 'Product: nuts, nut products and seeds',
#  '2009 - hiland dairy foods company, llc announces recallof ice cream because of possible health risk': 'Hazard: other hazard',
#  '2009 - hiland-roberts ice cream announces voluntary nationwide recall of specific lot numbers of espo brand and natures promise brand sorbettos due to containing undeclared milk': 'Product: alcoholic beverages',
#  '2009 - house of flavors expands voluntary recall of ice creamdue to possible health risk': 'Hazard: other hazard',
#  '2009 - house of flavors issues voluntary recall in eastern united states due to possible health risk': 'Hazard: other hazard',
#  '2009 - hp hood llc recalls ice cream products': 'Product: cereals and bakery products',
#  '2009 - kroger expands recall of shelled pistachios due to possible health risk': 'Hazard: other hazard',
#  '2009 - multiple brands of tin roof sundae ice cream recalled as part of nationwide peanut corporation of america recall': 'Product: nuts, nut products and seeds',
#  '2009 - peanut corporation of america expands nationwide recall of peanut butter': 'Product: dietetic foods, food supplements, fortified foods',
#  '2009 - peanut corporation of america expands nationwide recall of peanut products': 'Product: cereals and bakery products',
#  "2009 - pierre's ice cream company issues voluntary recall on its pierre's brand sundae-cone style products due to expanded peanut recall by peanut corporation of america (pca)": 'Product: cereals and bakery products',
#  '2009 - prairie farms dairy announces voluntary nationwide recall because of possible health risk': 'Hazard: other hazard',
#  "2009 - rich ice cream company expands precautionary voluntary multi-state recall to include rich's candy bar avalanche": 'Product: dietetic foods, food supplements, fortified foods',
#  "2009 - rich ice cream company, inc. issues multi-state voluntary recall of rich's nutty sundae cone because of possible health risk": 'Hazard: other hazard',
#  '2009 - roman meal company initiates nationwide recall of whole grain & fruit dark chocolate peanut butter snack bars because of possible health risk': 'Product: nuts, nut products and seeds',
#  '2009 - safeway recalls selected peanut products sold at 66 stores with nut kiosks': 'Product: cereals and bakery products',
#  '2009 - super store industries announces voluntary recall of select ice cream products due to possible health risk': 'Hazard: other hazard',
#  '2009 - turkey hill dairy expands voluntary ice cream recall to include': 'Product: dietetic foods, food supplements, fortified foods',
#  '2009 - umpqua dairy issues voluntary recall on its tin roof sundae ice cream products due to expanded peanut recall by peanut corporation of america (pca)': 'Product: dietetic foods, food supplements, fortified foods',
#  '2009 - update: schwan expands voluntary recall of ice cream, citing possible health risk': 'Hazard: other hazard',
#  '2009 - wonder ice cream company announces nationwide voluntary recall of candy blast 10oz cups because of possible health risk': 'Hazard: other hazard',
#  '2010 - Azteca Linda Corp. Recalls QUESO FRESCO and QUESO HEBRA Because of Possible Risk of Health': 'Hazard: other hazard',
#  '2010 - Del Bueno Recalls Queso Fresco Because of Possible Health Risk': 'Hazard: other hazard',
#  '2010 - Quaker Snack Mix Baked Cheddar Voluntarily Recalled Due to Possible Health Risk': 'Hazard: other hazard',
#  '2010 - Sirob Imports Issues Alert on Undeclared Sulfites in Strawberry Farms Sun Dried Tomatoes': 'Product: cocoa and cocoa preparations, coffee and tea',
#  '2010 - del bueno amends recall of queso fresco cheese because of possible health risk': 'Hazard: other hazard',
#  '2010 - golden pacific foods, inc. issues allergy alert for undeclared milk and soy in marco polo brand shrimp snacks': 'Product: alcoholic beverages',
#  '2010 - harry london candies, inc. announces a voluntary and limited recall of harry london chocolate pecan caramel stars due to an undeclared allergen': 'Product: dietetic foods, food supplements, fortified foods',
#  "2010 - kellogg company voluntarily recalls select packages of kellogg'sÂ® corn popsÂ®, kellogg'sÂ® honey smacksÂ®, kellogg'sÂ® froot loopsÂ® and kellogg'sÂ® apple jacksÂ®": 'Product: honey and royal jelly',
#  '2010 - kroger amends code date on recalled seasoning blend garlic powder': 'Product: herbs and spices',
#  '2010 - minnesota firm issues recall due to undeclared dairy allergen in certain sunflower seeds': 'Product: nuts, nut products and seeds',
#  '2010 - olde westport spice announces a voluntary recall of garden harvest special blend seasoning': 'Product: herbs and spices',
#  '2010 - p&g joins industry ingredient recall by voluntarily recalling two flavors of pringlesÂ® in the united states in response to fda industry guidance': 'Product: cocoa and cocoa preparations, coffee and tea',
#  '2010 - queseria bendita recalls queso fresco, panela, and requeson because of possible health risk': 'Product: food contact materials',
#  '2010 - so shing hing (usa) trading co ltd issues an alert on undeclared sulfites in dried melon': 'Product: alcoholic beverages',
#  '2010 - spice barn, inc. voluntarily recalls two lots of black pepper': 'Product: herbs and spices',
#  '2010 - turkey hill dairy issues recall on chocolate marshmallow ice cream that may contain undeclared treenuts (almonds)': 'Product: cocoa and cocoa preparations, coffee and tea',
#  '2010 - whole foods market voluntarily recalls frozen whole catch yellow fin tuna steaks due to possible health risks': 'Hazard: other hazard',
#  '2010 - wholesome spice recalls 25 lb. boxes of crushed red pepper because of possible health risk': 'Hazard: other hazard',
#  'A. Clouet Pty Ltdâ€”Ayam Thai Massaman Curry, Cooking Sauce': 'Product: soups, broths, sauces and condiments',
#  "Acquilla Bulk Tradingâ€”Sasso Pasta D'acciughe Linea Mare anchovies paste": 'Product: dietetic foods, food supplements, fortified foods',
#  'Alba Cheeseâ€”Shredded Mozzarella': 'Product: dietetic foods, food supplements, fortified foods',
#  'Alba Gelati': 'Product: food contact materials',
#  'Allfect Ltdâ€”Ghost Drop Lollies': 'Product: food contact materials',
#  'American Foods Group is voluntarily recalling approximately 95,927 pounds of various coarse and fine ground beef products because they may be contaminated with E. coli O157:H7.': 'Product: cereals and bakery products',
#  'Angelakis Brothersâ€”Pacific Redâ€”Frozen Whole Cooked Vannamei Prawn': 'Product: seafood',
#  'Apr 4': 'Product: food contact materials',
#  'Aqua Marine Marketing Pty Ltdâ€”Cooked Medium Tiger Prawns (sold loosely)': 'Product: seafood',
#  'Archive - ALLERGY ALERT - UNDECLARED PECAN AND WALNUT IN ICE CREAM AND ICE MILK MANUFACTURED BY LAITERIE DE COATICOOK LT&#201 E': 'Product: nuts, nut products and seeds',
#  'Archive - ALLERGY ALERT - UNDECLARED SOY PROTEIN AND SOY LECITHIN IN DUNCAN HINES WHITE CAKE MIX': 'Product: dietetic foods, food supplements, fortified foods',
#  'Archive - PRODUCT ALERT - POSSIBLE BOTULISM TOXIN IN ULIVETO DEL SAPORE BRAND GIANT OLIVES TUSCAN STYLE': 'Product: cereals and bakery products',
#  'Aristocrat Gourmet Foodsâ€”Aristocrat and Melton Pork Pies': 'Product: meat, egg and dairy products',
#  'Aug 7': 'Product: alcoholic beverages',
#  'Aus Soya Productsâ€”Tofu (5 products)': 'Product: cereals and bakery products',
#  "Australian Discount Retailâ€”Ricky's BBQ flavoured Rice Crackers": 'Product: dietetic foods, food supplements, fortified foods',
#  'Australian Eatwell Pty Ltdâ€”Australian Eatwell Garden Fresh Vegie Burgers â€“ Red Lentil': 'Product: alcoholic beverages',
#  'Australian International Foods Pty Ltdâ€”Darshan Savoury Rolls': 'Product: dietetic foods, food supplements, fortified foods',
#  'Australian Seafood Producersâ€”Daruma Tuna Steaks and Tuna Steaks (Product of Indonesia purchased from Foodland stores in South Australia only)': 'Product: seafood',
#  'Azurra Gelatiâ€”Azurra Sorbet Strawberry, Mango, Lemon and Blueberry Flavours 1.5ltr': 'Product: cocoa and cocoa preparations, coffee and tea',
#  'Azzura Gelatiâ€”Azzura Kisses': 'Product: dietetic foods, food supplements, fortified foods',
#  'B.-d. Farm Paris Creek Pty Ltdâ€”Paris Creek Cheese Comâ€™n Bear French Style Camembert & Brie French Style Brie': 'Product: alcoholic beverages',
#  'Balfour Wauchopeâ€”Cake with Icing': 'Product: dietetic foods, food supplements, fortified foods',
#  'Barillaâ€”Arrabbiata Pasta Sauce & Barilla Pesto Calabrese': 'Product: soups, broths, sauces and condiments',
#  'Begaâ€”So Extra Light 50% Less Fat Tasty Grated Cheese': 'Product: dietetic foods, food supplements, fortified foods',
#  'Bella Fantasiaâ€”240mL Hazelnut Gelato and 3-pack Bacio Romantico Gelato': 'Product: nuts, nut products and seeds',
#  'Better Choiceâ€”Frozen Cooked and Peeled Prawns': 'Product: seafood',
#  'Bi-Loâ€”Apricot and Raisin Cake': 'Product: dietetic foods, food supplements, fortified foods',
#  'Big Mâ€”Chocolate flavoured Milk': 'Product: cocoa and cocoa preparations, coffee and tea',
#  'Black & Goldâ€”Sliced Shoulder Ham': 'Product: dietetic foods, food supplements, fortified foods',
#  'Blue Lotus Foodsâ€”Tofu Cutlets': 'Product: cocoa and cocoa preparations, coffee and tea',
#  'Blue Lotusâ€”Organic tofu hakea & smoked tofu': 'Hazard: chemical',
#  'Bluebirdâ€”Incredibites Choc/Hazelnut Snack': 'Product: prepared dishes and snacks',
#  'Borgo Smallgoods Coâ€”Friulano Salame, Lismore Salame and Casalingo Salame': None,
#  'Boustani Enterprises Pty Ltdâ€”Tahini Sauce': 'Product: soups, broths, sauces and condiments',
#  'Bruny Island Cheese Coâ€”Soft cheeses': 'Product: dietetic foods, food supplements, fortified foods',
#  'Buderim Ginger Ltdâ€”Ginger Lemon & Lime Marmalade': 'Product: dietetic foods, food supplements, fortified foods',
#  'Bulla Dairy Foodsâ€”Bulla , Farmland & Homebrand Brand Namesâ€”Low Fat Cottage Cheese, all flavours': 'Product: dietetic foods, food supplements, fortified foods',
#  'Byrnes Quality Meatsâ€”Sliced Cooked Meat Products': 'Product: meat, egg and dairy products',
#  'Byrnes Quality Meatsâ€”Sliced Roast Beef and Pepperoni': 'Product: dietetic foods, food supplements, fortified foods',
#  'Cadbury Pty Ltdâ€”Cadbury Old Gold Dark Chocolate 70% Cocoa 200g block only': 'Product: cocoa and cocoa preparations, coffee and tea',
#  'Cadbury Pty Ltdâ€”Cadbury Old Gold Dark Chocolate 70% Cocoa 200g block': 'Product: cocoa and cocoa preparations, coffee and tea',
#  'Cadbury Schweppes Pty Ltdâ€”Boost Totally Nuts 60g bar': 'Product: nuts, nut products and seeds',
#  'Cadbury Schweppesâ€”Cottees Hazelnut Spread': 'Product: nuts, nut products and seeds',
#  'Cadburyâ€”250g Hazelnut Block Chocolate': 'Product: nuts, nut products and seeds',
#  'Cadburyâ€”Teeny Freddo Ice Cream and Party Cake': 'Product: dietetic foods, food supplements, fortified foods',
#  'California Firm Recalls Chicken Product For Undeclared Allergen': 'Hazard: allergens',
#  'California Firm Recalls Ground Beef Products Due to Possible Salmonella Contamination': 'Product: cereals and bakery products',
#  'Canon Foodsâ€”Chicken and Cheese Schnitzel': 'Product: dietetic foods, food supplements, fortified foods',
#  'Casa Dairy Productsâ€”Marinated Feta': 'Product: meat, egg and dairy products',
#  'Cerenâ€”Halva (Middle Eastern Sweet)': 'Product: dietetic foods, food supplements, fortified foods',
#  'Challenge Meats Pty Ltdâ€”Country Lite Ham Steaks': 'Product: meat, egg and dairy products',
#  'Charkas Middle East Foodsâ€”Al-Rabih Brand Tahineh': 'Product: cereals and bakery products',
#  'Charkas Middle Eastern Foodsâ€”Al-Ribah Halawa Plain and Pistachio': 'Product: nuts, nut products and seeds',
#  'Coca Cola Hellenic Bottling Co withdraws certain batches of 500ml PET bottles of Dr Pepper due to high levels of benzoic acid (Northern Ireland)': 'Product: pet feed',
#  'Coca-Cola Amatil Limitedâ€”Winnie the Pooh Juice Drink 250ml PET Bottles': 'Product: pet feed',
#  'Coles Group Ltdâ€”Coles Smart Buy Frozen Hamburger Patties': 'Product: dietetic foods, food supplements, fortified foods',
#  "Coles Group Ltdâ€”You'll Love Coles branded thin BBQ Sausages, Bi-Lo branded BBQ thin BBQ sausages, Coles Smart-Buy branded BBQ Pack and Bi-Lo branded BBQ pack": 'Product: dietetic foods, food supplements, fortified foods',
#  "Coles Group Ltdâ€”You'll Love Colesâ€”Basil Pesto Dip": 'Product: soups, broths, sauces and condiments',
#  'Coles Myer Limitedâ€”Farmland Tropical Muesli': 'Product: dietetic foods, food supplements, fortified foods',
#  'Coles Myer Ltdâ€”Bi-Lo Shredded Lite Tasty Cheese': 'Product: dietetic foods, food supplements, fortified foods',
#  'Coles Myer Ltdâ€”Bilo & Savingsâ€”Choc Coated Ice Cream': 'Product: dietetic foods, food supplements, fortified foods',
#  'Coles Myer Ltdâ€”Farmland Apple Oven Baked Fruit Bars': 'Product: nuts, nut products and seeds',
#  'Coles Myer Ltdâ€”Peppermint Choc Coated Muesli Bars': 'Product: food contact materials',
#  'Coles Myer Supermarketsâ€”Chocolate Sultanas 400gm': 'Product: cocoa and cocoa preparations, coffee and tea',
#  'Coles Myer Supermarketsâ€”Value Bag Choc Sultanas': 'Product: cereals and bakery products',
#  'Coles Myers Pty Ltdâ€”Savings Luncheon Ham and Chicken Meat': 'Product: meat, egg and dairy products',
#  'Coles Supermarketsâ€”Farmland sausage meat': 'Product: meat, egg and dairy products',
#  'Colesâ€”Candy Lane Chocolate Coated Sultanas': 'Product: cocoa and cocoa preparations, coffee and tea',
#  'Colesâ€”Chewy Oat and Raisin and Anzac Cookies': 'Product: cereals and bakery products',
#  'Colesâ€”Eucalyptus & Honey Tea Recipe': 'Product: honey and royal jelly',
#  'Colesâ€”Farmland & BI-LOâ€”Fruit juice cordial orange crush 2L': 'Product: dietetic foods, food supplements, fortified foods',
#  'Colesâ€”Farmland Natural Spring Water': 'Product: alcoholic beverages',
#  'Colesâ€”Farmland Tropical Muesli (750g)': 'Hazard: fraud',
#  'Colesâ€”Garden Vegetable Pasta Sauce': 'Product: soups, broths, sauces and condiments',
#  'Colesâ€”Parmagiana Beef Rissoles': 'Product: dietetic foods, food supplements, fortified foods',
#  'Colesâ€”Premium Fruit Mince Pie 4 Pack': 'Product: fruits and vegetables',
#  'Colesâ€”Savings Brand Frozen Fish Fingers': 'Product: alcoholic beverages',
#  'Colesâ€”and Bi-Lo thin BBQ sausages (random weight and assorted pack sizes)': 'Product: dietetic foods, food supplements, fortified foods',
#  'Colorado Firm Recalls Ground Beef Products For Possible E. coli O157:H7': 'Product: cereals and bakery products',
#  'Confectionery Trading Companyâ€”IGAâ€”Fabulously Fun Lolly Pops': 'Product: dietetic foods, food supplements, fortified foods',
#  'Conga Foods Pty Ltdâ€”Spanish Black Pitted Olives, Green Valley, 350g, Glass Jar': 'Product: food contact materials',
#  "Conroy's Smallgoods Pty Ltdâ€”Ham Steaks": 'Product: dietetic foods, food supplements, fortified foods',
#  "Conroy's Smallgoods, MQF, Foodland, Drakeâ€”Ready-to-eat meats and smallgoods (excluding bacon)": 'Product: meat, egg and dairy products',
#  "Conroy'sâ€”Polish Sausage": 'Product: dietetic foods, food supplements, fortified foods',
#  'Country Cuisine Pty Ltdâ€”Maloufâ€™s Spice Mezza': 'Product: herbs and spices',
#  'Country Valleyâ€”Classic Cream (minimum 35% fat)': 'Product: fats and oils',
#  'Curlwaa Orange Juiceâ€”Various Products': 'Product: dietetic foods, food supplements, fortified foods',
#  "D'Orsognaâ€”Pressed Chicken": 'Product: dietetic foods, food supplements, fortified foods',
#  'Darling Downs Baconâ€”Boneless Champagne Leg Ham': 'Product: alcoholic beverages',
#  'Darling Downs Foods Pty Ltdâ€”Selected KR Castlemaine products': 'Product: honey and royal jelly',
#  "Darragh's Plaza Butcheryâ€”Sliced Roast Beef": 'Product: dietetic foods, food supplements, fortified foods',
#  'Dawn Farm Foods Ltd withdraws cooked bacon used in three own-brand chicken and bacon sandwich fillers due to possible salmonella contamination': 'Product: dietetic foods, food supplements, fortified foods',
#  "Day In Import & Export Co Ltd recalls one batch of Guilin Rice Flour Noodles due to the presence of unauthorised 'BT63' genetically modified rice": 'Product: cereals and bakery products',
#  'Dec 11': 'Product: cereals and bakery products',
#  'Dec 1': 'Product: food contact materials',
#  'Delight Dim Sumâ€”Siu Mai': 'Product: dietetic foods, food supplements, fortified foods',
#  "Dick Smith'sâ€”Shortbread Vanilla Creams": 'Product: dietetic foods, food supplements, fortified foods',
#  'Dons Smallgoodsâ€”Deli Supreme Premium Smoked Leg Ham': 'Product: dietetic foods, food supplements, fortified foods',
#  'Duncan Mannâ€”Black & Gold Choc sultanas': 'Product: food contact materials',
#  'Eggs and products thereof in ice cream by Island Farms Dairy from Canada': 'Product: cereals and bakery products',
#  'Emerging incident involving distribution of Moubon Yoghurt Dessert from an unapproved establishment': 'Product: food contact materials',
#  'Ettason Pty Ltdâ€”Punchun Sesame Sauce, 290g jar': 'Product: nuts, nut products and seeds',
#  'Exquisineâ€”Traditional Chocolate Mousse & Hazelnut Chocolate Mousse': 'Product: cocoa and cocoa preparations, coffee and tea',
#  'F Mayer Imports Pty Ltdâ€”Smoked Salmon (All Natural - Sliced - Ready to Serve), Royal Line, 100gram': 'Product: dietetic foods, food supplements, fortified foods',
#  'Fantastic Snacksâ€”Fortune Brand and Jade Brand Instant Cup Noodles': 'Product: meat, egg and dairy products',
#  'Farmwood Delicatessenâ€”Smoked Chicken Breast': 'Product: dietetic foods, food supplements, fortified foods',
#  'Favourite Foods Pty Ltdâ€”Mexigos Nacho Cheese & Salso and Mexigos Bean Dip & Nacho Cheese': 'Product: dietetic foods, food supplements, fortified foods',
#  'Feb 12': 'Product: food contact materials',
#  'Fidlers Choiceâ€”Tasty Cheese': None,
#  'Fishboy Pty Ltdâ€”Salty Chicken, Fuligi Chicken, Sliced Ham and Boneless Pork Hoof': 'Product: dietetic foods, food supplements, fortified foods',
#  'Foodland Associated Limitedâ€”Signature Range Classic Caesar Salad Dressing': 'Product: dietetic foods, food supplements, fortified foods',
#  'Foodland Associated Ltdâ€”Basics Brand Frozen Lasagne': 'Product: dietetic foods, food supplements, fortified foods',
#  'Foodland Associated Ltdâ€”Signature Range BBQ Flavoured Rice Crackers': 'Product: dietetic foods, food supplements, fortified foods',
#  'Foodland Associated Ltdâ€”Signature Range Cereal Bars': 'Product: food contact materials',
#  'Foodland Associated Ltdâ€”Signature Range Plain, Seaweed & Tomato Salso Flavoured Rice Crackers': 'Product: cereals and bakery products',
#  'Four Bee Meatsâ€”Smoked Premium Leg Ham and Silverside Eye Corn Beef': 'Product: dietetic foods, food supplements, fortified foods',
#  'Franklins Limitedâ€”Frozen Chicken Nuggets': 'Product: dietetic foods, food supplements, fortified foods',
#  'Franklins Ltdâ€”Big Fresh & Franklins Fresh Labelled Cakes': 'Product: dietetic foods, food supplements, fortified foods',
#  'Franklins Ltdâ€”First Choice Young Corn Cuts': 'Product: dietetic foods, food supplements, fortified foods',
#  'Franklins Ltdâ€”No Frillsâ€”Chocolate mint slice biscuits': 'Product: cocoa and cocoa preparations, coffee and tea',
#  'Franklins Pty Ltdâ€”No Frillsâ€”Potato Salad in Mayonnaise': 'Product: dietetic foods, food supplements, fortified foods',
#  'Franklinsâ€”No Frills Pizzaâ€”Ham and Pineapple and Supreme varieties': 'Product: dietetic foods, food supplements, fortified foods',
#  'Fresco Cheese Company Pty Ltdâ€”Baked Ricotta Cheese': 'Product: dietetic foods, food supplements, fortified foods',
#  'Fromagent Australiaâ€”Mauri brand cheese Bon Taleggio Valsassina': 'Product: dietetic foods, food supplements, fortified foods',
#  'Game Farm Enterprises (Qld) Pty Ltdâ€”Top of the Range brand free range eggs': 'Product: dietetic foods, food supplements, fortified foods',
#  'George Weston Foods Ltdâ€”Watsonia Salami Slims Original': 'Product: dietetic foods, food supplements, fortified foods',
#  'George Weston Foodsâ€”DonÂ® Pre Packaged Kabana': 'Product: alcoholic beverages',
#  'George Weston Foodsâ€”Kitchen Collection Brand Bread Mixes': 'Product: dietetic foods, food supplements, fortified foods',
#  'Gold Coast Bakery Queensland Pty Ltdâ€”Vogelsâ€”Fruit and Nut Bread': 'Product: nuts, nut products and seeds',
#  'Gold Medal Snacksâ€”Prawn Crackersâ€”Crispy Prawn Snacks': 'Product: seafood',
#  'Golden Circleâ€”Fruit Salad': 'Product: dietetic foods, food supplements, fortified foods',
#  'Golden Circleâ€”Meal Variety 4 and 8 Pack Baby Food': 'Product: dietetic foods, food supplements, fortified foods',
#  'Golden Mountainâ€”Soya Bean Sauce': 'Product: soups, broths, sauces and condiments',
#  'Goodman Fielder Bakingâ€”Pampas Family Chicken and Vegetable Pie': 'Product: dietetic foods, food supplements, fortified foods',
#  'Goodman Fielder Consumer Foods Ltdâ€”Figurines included in White Wings Learn to Bake Chocolate Cup Cakes with Chocolate Icing': 'Product: dietetic foods, food supplements, fortified foods',
#  'Grand Continental Food Company Pty Ltdâ€”Dried Whole Anchovies': 'Product: dietetic foods, food supplements, fortified foods',
#  "Green Valley Dairyâ€”Cheese 100% Pure Cow's milk": 'Product: pet feed',
#  'Green Valleyâ€”Fresh Cheese': 'Product: dietetic foods, food supplements, fortified foods',
#  "Green'sâ€”Pastry Mix": 'Product: dietetic foods, food supplements, fortified foods',
#  'Gulsanâ€”Halva (Middle eastern sweet also known as Helva or Halwa)': 'Product: dietetic foods, food supplements, fortified foods',
#  'Haberfieldsâ€”Country Fresh Thickened Cream': 'Product: alcoholic beverages',
#  "Haigh's Chocolate and Almond Cookies": 'Product: cocoa and cocoa preparations, coffee and tea',
#  'Hans Continental Smallgoodsâ€”German Salami (Mettwurst Style)': 'Product: dietetic foods, food supplements, fortified foods',
#  'Hans Continental Smallgoodsâ€”Latvian Liverwurst': 'Product: alcoholic beverages',
#  'Harkola Pty Ltdâ€”Halawa with Pistachios (Middle Eastern Sweet also known as helva or halwa)': 'Product: nuts, nut products and seeds',
#  'Harvey Fresh Ltdâ€”All White Milk': 'Product: alcoholic beverages',
#  'Health Brands Australiaâ€”Healtheries Kidscare Rice Roundsâ€”Cheese and Bacon Flavour': 'Product: dietetic foods, food supplements, fortified foods',
#  'Heinzâ€”Baked Beans in Tomato Sauce': 'Product: soups, broths, sauces and condiments',
#  'Heinzâ€”Dijon Mustard Sauce With a Hint of Orange': 'Product: soups, broths, sauces and condiments',
#  'Heinzâ€”Dijon Mustard Sauce with Orange': 'Product: soups, broths, sauces and condiments',
#  'Heinzâ€”Spaghetti In Tomato Sauce, Spaghetti Bolognese & Spaghetti Oops.': 'Product: dietetic foods, food supplements, fortified foods',
#  'Heng Fai Trading Co Pty Ltdâ€”Heng Fai Dried Seaweed Brand (Sargassum fusiforme)': 'Product: alcoholic beverages',
#  'Heng Heng Tradingâ€”A1 Salted Mackerel': 'Product: dietetic foods, food supplements, fortified foods',
#  'Henry Jones Foodsâ€”Allowrie Fruit Of The Forest Jam': 'Product: fruits and vegetables',
#  'Home Brandâ€”Sultanas Milk Chocolate': 'Product: cocoa and cocoa preparations, coffee and tea',
#  'Hong Australia Corp Pty Ltdâ€”Pun Chen Lye Water': 'Product: alcoholic beverages',
#  "Hormel Foods Australia Pty Ltdâ€”Kid's Kitchenâ€”Mini Beef Ravioli in Tomato Sauce, 213g": 'Product: dietetic foods, food supplements, fortified foods',
#  'Hungs Trading Company Pty Ltdâ€”Seawoods Soft Flour Cake (FSANZ 2005/01)': 'Product: dietetic foods, food supplements, fortified foods',
#  'Hunts Foodsâ€”Frozen Hunts Beef Savoury Rice & Chicken Savoury Rice': 'Product: dietetic foods, food supplements, fortified foods',
#  'IGAâ€”Christmas Kisses (Cream filled sponge cakes)': 'Product: dietetic foods, food supplements, fortified foods',
#  'IXLâ€”Raspberry Conserve': 'Product: fruits and vegetables',
#  'Indiana Firm Recalls Duckling Products': 'Product: cereals and bakery products',
#  'Italian Foodsâ€”Prosciutto Parma whole legs & Serrano ham slices and whole legs': 'Product: dietetic foods, food supplements, fortified foods',
#  'J Sainsbury recall Dry Cured York Ham sold from their in-store delicatessen counters': 'Product: alcoholic beverages',
#  'J&F Corbo Pty Ltdâ€”Buona Pasta Beef Ravioli and Ravioli Da Brodo': 'Product: dietetic foods, food supplements, fortified foods',
#  'Jacobs Well Egg Farmâ€”Jacobs Well Egg Farm Cage Eggs': 'Product: meat, egg and dairy products',
#  'Jalong Goat Dairyâ€”Frozen Goat Milk, Soft Cheese & Fetta': 'Product: alcoholic beverages',
#  'Jalong Goat Dairyâ€”Plain Gormet Fetta, Fetta with Chives and Fetta with Sun-dried Tomato and Olives': 'Product: cocoa and cocoa preparations, coffee and tea',
#  'John Westâ€”Scottish sardines In vegetable oil': 'Product: alcoholic beverages',
#  'Jun 15': 'Product: dietetic foods, food supplements, fortified foods',
#  'Jun 26': 'Product: dietetic foods, food supplements, fortified foods',
#  'Jun 8': 'Product: cereals and bakery products',
#  'KR Darling Downâ€”Boneless Champagne Leg Ham Portions': 'Product: alcoholic beverages',
#  'Kadac Pty Ltdâ€”Ancient Harvest Brand Quinoa Supergrain Pasta': 'Product: dietetic foods, food supplements, fortified foods',
#  'Kadac Pty Ltdâ€”Whole Earth Brand Organic Cornflakes': 'Hazard: chemical',
#  'Kaisi Australia Pty Ltdâ€”Kirin Milk Tea': 'Product: cocoa and cocoa preparations, coffee and tea',
#  'Kinnerton Confectionary Australia Pty Ltdâ€”Spiderman 3â€”Ceramic Mug and Egg': 'Product: meat, egg and dairy products',
#  'Kmartâ€”Boxed Chocolates And Easter Chocolate Items': 'Product: cocoa and cocoa preparations, coffee and tea',
#  'Koh-kaeâ€”Peanuts coconut cream flavour': 'Product: dietetic foods, food supplements, fortified foods',
#  "Kooka's Country Cookiesâ€”Choc Coated Assorted": 'Product: other food product / mixed',
#  'Koz Worldwide Importsâ€”Ttangkong Kangjung (Peanut Snack)': 'Product: nuts, nut products and seeds',
#  'Kyana Farmsâ€”IGA Deli Roast Beef': 'Product: dietetic foods, food supplements, fortified foods',
#  'La Toscaâ€”Sugodoro bolognese Sauce with beef': 'Product: soups, broths, sauces and condiments',
#  'Liquorlandâ€”Scotch Whiskyâ€”Hankey Bannister': 'Product: alcoholic beverages',
#  'Lismore Country Meatsâ€”Sliced Leg Ham': 'Product: dietetic foods, food supplements, fortified foods',
#  'Lolliland Pty Ltdâ€”Quanta Armadaâ€”Soft nougat caramel and peanuts in milk chocolate': 'Product: dietetic foods, food supplements, fortified foods',
#  'Lucas Quality Meatsâ€”Sliced Virginia Leg Ham': 'Product: dietetic foods, food supplements, fortified foods',
#  'Madelaine Confectionery Pty Ltdâ€”Madelaine Gummy Baby Crocodiles, Madelaine Gummy Day Old Chicks and Madelaine Gummy Coral Fish.': 'Product: dietetic foods, food supplements, fortified foods',
#  'Manassen Foods Australia Pty Ltdâ€”Atkins Advantage Chocolate Decadence Bar': 'Product: dietetic foods, food supplements, fortified foods',
#  'Manassen Foods Australia Pty Ltdâ€”Globus Dill Cucumbers (Polski Ogorki)': 'Product: meat, egg and dairy products',
#  'Manassen Foods Australia Pty Ltdâ€”Trident Multigrain Rice Cakes': 'Product: dietetic foods, food supplements, fortified foods',
#  'Manassen Foods Australia Pty Ltdâ€”Trident Oriental Favouritesâ€”Pad Thai Noodles': 'Product: meat, egg and dairy products',
#  "Manassen Foods Pty Ltdâ€”McVitie's The Original Digestive": 'Product: dietetic foods, food supplements, fortified foods',
#  'Manassen Foodsâ€”Trident Rice Crackers (Teriyaki Flavour)': 'Product: dietetic foods, food supplements, fortified foods',
#  'Manifold Food Trading Pty Ltdâ€”Chinese Gingili Paste (Sesame Paste)': 'Product: dietetic foods, food supplements, fortified foods',
#  'Marco Polo Foods Pty Ltdâ€”Trata Brand Anchovy Fillets in Sunflower Oil': 'Product: meat, egg and dairy products',
#  'Marks & Spencer plc withdraws batches of its own brand Strawberry & Almond Crunch due to incorrect allergy labelling': 'Product: nuts, nut products and seeds',
#  'Marks & Spencer recalls own-brand 3 Bean & Spinach Salad with Chive Dressing due to incorrect labelling information': 'Product: dietetic foods, food supplements, fortified foods',
#  'Marks & Spencer withdraws cheesecake desserts due to possible metal contamination': 'Product: dietetic foods, food supplements, fortified foods',
#  'Mars Confectioneryâ€”Starburst Lollipops': 'Product: dietetic foods, food supplements, fortified foods',
#  "Mary's Pasta Productsâ€”various pasta products": 'Product: cereals and bakery products',
#  'Masterfoodsâ€”Dolmio Tomato Sauces': 'Product: soups, broths, sauces and condiments',
#  'Masterfoodsâ€”Mars and Snickers Bars': 'Product: dietetic foods, food supplements, fortified foods',
#  'Masterfoodsâ€”Marsâ€”Fundraising speckled eggs boxes': 'Product: dietetic foods, food supplements, fortified foods',
#  'May 25': 'Product: cereals and bakery products',
#  'McCainâ€”Stir Fry Vegetables Pasta Alfredo with Sauce': 'Product: soups, broths, sauces and condiments',
#  'Menora Foods Pty Ltdâ€”Jindi Cheese, Top Paddock, Wattle Valley and Willow Grove Cheese': 'Product: dietetic foods, food supplements, fortified foods',
#  'Montefiore Cheese (Aust) P/Lâ€”Montefiore Cheese Mozzarella Fiorello': 'Product: dietetic foods, food supplements, fortified foods',
#  'Mountain Creek Meatsâ€”Silverside and Boneless Ham': 'Product: dietetic foods, food supplements, fortified foods',
#  "Mrs Mac'sâ€”All products, individually wrapped only. All Bakewell and Bakewell Classic Products. All Mrs Mac's Good Eating products, individually wrapped only. Red Embers Chicken Leek & Mushroom Pies, Greek Souvlaki Pies and Premium Sausage Roll": 'Product: dietetic foods, food supplements, fortified foods',
#  "Mum's Choice Pty Ltdâ€”Baba-Ghannouje": 'Product: dietetic foods, food supplements, fortified foods',
#  'Mur Thai Food Co Pty Ltdâ€”Vinawang Pumpkin Seed Cake 100g Cellophone pack': 'Product: dietetic foods, food supplements, fortified foods',
#  'National Foods Limitedâ€”Baby Yoplait and Yoplait ElivaÃ© Yoghurt': 'Product: dietetic foods, food supplements, fortified foods',
#  'National Foods Ltdâ€”Fruche': 'Product: dietetic foods, food supplements, fortified foods',
#  "National Foods Ltdâ€”Yo-Split Vanilla Yogurt with Muesli 'n Fruit": 'Product: dietetic foods, food supplements, fortified foods',
#  'National Foods Pty Ltdâ€”Tilba Cheese': 'Product: dietetic foods, food supplements, fortified foods',
#  'National Foodsâ€”Milk Products': 'Product: cereals and bakery products',
#  'Naturally Good Products Pty Ltdâ€”Soy Carob Products': 'Product: cereals and bakery products',
#  'Naturally Good, Deliciously Freeâ€”Moist Chocolate Mudcake mix': 'Product: cocoa and cocoa preparations, coffee and tea',
#  'Nebraska Firm Recalls Beef Tongues That Contain Prohibited Materials': 'Product: feed materials',
#  'Nestleâ€”Billabong chocolate ice cream 8 pack': 'Product: cocoa and cocoa preparations, coffee and tea',
#  'NestlÃ©â€”Kit Kat Caramel & Kit Kat Cookie Dough': 'Product: dietetic foods, food supplements, fortified foods',
#  'NestlÃ©â€”Maggi Liquid Cooking Sauce': 'Product: soups, broths, sauces and condiments',
#  'NestlÃ©â€”Maggiâ€”Frozen Macaroni Cheese': 'Product: dietetic foods, food supplements, fortified foods',
#  'NestlÃ©â€”Nan 2 H.A. Gold Infant Formula': 'Product: feed materials',
#  'New World Trading Company Pty Ltdâ€”Preserved Bean Curd â€“ Sakura, Fermented Bean Curd - in dressing with Chili and Liu Ma Bao Kee â€“ Preserved Bean Sauce': 'Product: soups, broths, sauces and condiments',
#  'New York Firm Recalls Fresh Ground Beef Products Due To Possible E. coli O157:H7 Contamination': 'Product: cereals and bakery products',
#  'Nocelle Foodsâ€”Various Pistachio Products': 'Product: nuts, nut products and seeds',
#  'Norco Co-Operativeâ€”Richmond Vanilla Icecream': 'Product: soups, broths, sauces and condiments',
#  'North Dakota Firm Recalls Whole Beef Head Products That Contain Prohibited Materials': 'Product: cereals and bakery products',
#  'Nut Producers Australiaâ€”Value Pack Dry Roasted and Salted Pistachios': 'Product: nuts, nut products and seeds',
#  'Nutellaâ€”Hazelnut Spread in Collectable Glasses': 'Product: nuts, nut products and seeds',
#  'Oceanic Foodâ€”Sichuan Spicy Noodle': 'Product: dietetic foods, food supplements, fortified foods',
#  'Oct 11': 'Product: cereals and bakery products',
#  'Oct 6': 'Product: dietetic foods, food supplements, fortified foods',
#  'Oriental Merchant Pty Ltdâ€”Shandong Peanuts (Peanuts in Shells)': 'Product: dietetic foods, food supplements, fortified foods',
#  'Oriental Merchantâ€”Koh-kae peanuts coconut cream flavour': 'Product: dietetic foods, food supplements, fortified foods',
#  'P & M Quality Smallgoods Pty Ltdâ€”Courtway Continental Double Smoked Leg Ham, Deli Style Slices': 'Product: dietetic foods, food supplements, fortified foods',
#  'P & M Quality Smallgoods Pty Ltdâ€”Primo Cocktail Frankfurts': 'Product: dietetic foods, food supplements, fortified foods',
#  'PRESENCE OF UNDECLARED PEANUT BUTTER IN CHOCOLATE ICE CREAM CAKE MANUFACTURED BY ICE CREAM UNLIMITED INC.': 'Product: dietetic foods, food supplements, fortified foods',
#  'Paesanella Cheese Manufacturersâ€”Stracchino Cheese & Fresh Peccornio Cheese': 'Product: dietetic foods, food supplements, fortified foods',
#  'Paesanella Cheeseâ€”Bocconcini cheese': 'Product: dietetic foods, food supplements, fortified foods',
#  'Parilla Freshâ€”Woolworths brand, Action brand Alfalfa sprouts': 'Product: dietetic foods, food supplements, fortified foods',
#  'Parillaâ€”Fresh and Woolworths brand Alfalfa Sprouts': 'Product: dietetic foods, food supplements, fortified foods',
#  'Parmalat Australia Limitedâ€”PhysiCAL No Fat Milk': 'Product: alcoholic beverages',
#  'Parmalat Australia Ltdâ€”Chocolate flavoured milk UHT Longlife': 'Product: cocoa and cocoa preparations, coffee and tea',
#  'Parmalat Australia Ltdâ€”Pauls Vanilla Custard': 'Product: dietetic foods, food supplements, fortified foods',
#  'Parmalat Foods Australia Pty Ltdâ€”Fresh Milk packed in 2 litre plastic bottles': 'Product: alcoholic beverages',
#  'Parmalat Foods Australia Pty Ltdâ€”Skinny Milk': 'Product: alcoholic beverages',
#  "Patak's Foods Limitedâ€”Rogan Josh Simmer Sauce": 'Product: soups, broths, sauces and condiments',
#  'Paulsâ€”Breaka chocolate UHT milk': 'Product: cocoa and cocoa preparations, coffee and tea',
#  'Pavlova Pantryâ€”Lamingtons': None,
#  'Pernod Ricard Pacific Pty Ltdâ€”Maison Supreme, White, Rose and Lambrusco': 'Product: cocoa and cocoa preparations, coffee and tea',
#  'Pixie Ice Creamâ€”Berry Koolick flavour Ice Blocks': 'Product: ices and desserts',
#  'Polycyclic aromatic hydrocarbons in olive pomace oil by Aris Calamata from Greece': 'Product: fats and oils',
#  'Polycyclic aromatic hydrocarbons in olive pomace oil by Grifo, San Remo, La Molisana from Italy': 'Product: alcoholic beverages',
#  'Primo Smallgoodsâ€”Corned Silverside': 'Product: dietetic foods, food supplements, fortified foods',
#  'Primo Smallgoodsâ€”Shaved Chicken Breast': 'Product: alcoholic beverages',
#  'Princi Smallgoodsâ€”Fermented Dry Italian sausage cacciatore': 'Product: dietetic foods, food supplements, fortified foods',
#  "Product recall of Marks & Spencer Cheesy Spirals 'Loved by Kids' meal": 'Product: cocoa and cocoa preparations, coffee and tea',
#  "Product recall of Unilever Bestfoods Ltd Bertolli brand 'Pesto Rosso' sauce 185g jar": 'Product: soups, broths, sauces and condiments',
#  'Product recall of various brands of frozen ready-to-eat meals with rice due to possible glass contamination': 'Product: cocoa and cocoa preparations, coffee and tea',
#  'Product withdrawal of Pork Farms, Bowyers, Marks and Spencer and Somerfield brand Scotch eggs, picnic eggs and Savoury Bites': 'Product: meat, egg and dairy products',
#  'Pronasindo Australia Pty Ltd trading as Simply The Best Smallgoodsâ€”Leg Ham Portion â€“ Simply The Best and Leg Ham Portion â€“ Harris Farm': 'Product: dietetic foods, food supplements, fortified foods',
#  'Pura And Woolworthsâ€”Whole Milk': 'Product: alcoholic beverages',
#  'Puraâ€”UHT (Long Life) Whole Milk': 'Hazard: chemical',
#  'Puraâ€”UHT (long life) Whole Milk': 'Hazard: chemical',
#  'Quaker Oats Ltd withdraws a batch of Quaker Oats due to the presence of moth pupae and larvae within the product': 'Product: dietetic foods, food supplements, fortified foods',
#  'Recall Notification Report 006-2001': 'Product: soups, broths, sauces and condiments',
#  'Recall Notification Report 075-2000, Expanded': 'Product: food contact materials',
#  'Recall Notification: FSIS-001-94': 'Product: food contact materials',
#  'Recall Notification: FSIS-002-95': 'Product: food contact materials',
#  'Recall Notification: FSIS-003-95': 'Product: food contact materials',
#  'Recall Notification: FSIS-005-94': 'Product: food contact materials',
#  'Recall Notification: FSIS-006-95': 'Product: food contact materials',
#  'Recall Notification: FSIS-006-97': 'Product: food contact materials',
#  'Recall Notification: FSIS-009-94': 'Product: food contact materials',
#  'Recall Notification: FSIS-009-96': 'Product: food contact materials',
#  'Recall Notification: FSIS-010-97': 'Product: food contact materials',
#  'Recall Notification: FSIS-011-98': 'Product: food contact materials',
#  'Recall Notification: FSIS-014-94': 'Product: food contact materials',
#  'Recall Notification: FSIS-014-97': 'Product: food contact materials',
#  'Recall Notification: FSIS-015-97': 'Product: food contact materials',
#  'Recall Notification: FSIS-016-97': 'Product: food contact materials',
#  'Recall Notification: FSIS-017-96': 'Product: food contact materials',
#  'Recall Notification: FSIS-017-97': 'Product: food contact materials',
#  'Recall Notification: FSIS-017-98': 'Product: food contact materials',
#  'Recall Notification: FSIS-018-94': 'Product: food contact materials',
#  'Recall Notification: FSIS-018-97': 'Product: food contact materials',
#  'Recall Notification: FSIS-020-98': 'Product: food contact materials',
#  'Recall Notification: FSIS-021-95': 'Product: food contact materials',
#  'Recall Notification: FSIS-021-97': 'Product: food contact materials',
#  'Recall Notification: FSIS-022-97': 'Product: food contact materials',
#  'Recall Notification: FSIS-023-96': 'Product: food contact materials',
#  'Recall Notification: FSIS-023-97': 'Product: food contact materials',
#  'Recall Notification: FSIS-023-98': 'Product: food contact materials',
#  'Recall Notification: FSIS-024-94': 'Product: food contact materials',
#  'Recall Notification: FSIS-024-96': 'Product: food contact materials',
#  'Recall Notification: FSIS-025-95': 'Product: food contact materials',
#  'Recall Notification: FSIS-026-94': 'Product: food contact materials',
#  'Recall Notification: FSIS-033-94': 'Product: food contact materials',
#  'Recall Notification: FSIS-035-98': 'Product: food contact materials',
#  'Recall Notification: FSIS-037-98': 'Product: food contact materials',
#  'Recall Notification: FSIS-038-95': 'Product: food contact materials',
#  'Recall Notification: FSIS-041-95': 'Product: food contact materials',
#  'Recall Notification: FSIS-044-94': 'Product: food contact materials',
#  'Recall Notification: FSIS-045-94': 'Product: food contact materials',
#  'Recall of Certain Bottled Mineral Water in the United States and Canada (Updated on 12 March 2007)': 'Product: food contact materials',
#  'Recall of Certain Bottled Mineral Water in the United States and Canada (Updated on 26 March 2007)': 'Product: food contact materials',
#  'Red Dragon Foods Pty Ltdâ€”Glory Brand Rice Cookies': 'Product: dietetic foods, food supplements, fortified foods',
#  "Ricegrowers' Co-operativeâ€”Long Grain Jasmine Rice": 'Product: cereals and bakery products',
#  'Riviana Foods Pty Ltdâ€”Always Fresh Baby Clams - Tin Can 200g': 'Product: honey and royal jelly',
#  "Roger's Select Meatsâ€”Roast Beefâ€”Ready-to-Eat meat": 'Product: meat, egg and dairy products',
#  'Rosemount Estateâ€”Semillon Sauvignon Blanc Wine': 'Product: alcoholic beverages',
#  'Safcolâ€”95g Premium Selection Tuna Range with Gold Foil Top Packaging and 95g Sandwich Delite Tuna Range with Gold Foil Top Packaging': 'Product: dietetic foods, food supplements, fortified foods',
#  'Sanhuo Pty Ltdâ€”Sunlight White Sesame Seeds': 'Product: nuts, nut products and seeds',
#  "Schweppes Australia Pty Ltdâ€”All 2 Litre Cottee's Cordial Flavours": 'Product: meat, egg and dairy products',
#  'Simplot Australiaâ€”Frozen Neptune Black Tiger Prawns': 'Product: food contact materials',
#  'Smashing Pumpkinsâ€”Yoghurt Sultanas Tubs': 'Product: dietetic foods, food supplements, fortified foods',
#  'Solomon Kosher Butcher Pty Ltdâ€”Premium beef mince (diet beef mince)': 'Product: dietetic foods, food supplements, fortified foods',
#  'Sony Trading Pty Ltdâ€”Wong Coco Konnyaku Jelly and Wong Coco Mini Jelly Nata de Coco': 'Product: cocoa and cocoa preparations, coffee and tea',
#  'Spiroski Foods Pty Ltdâ€”Chocolate, Hazelnut and Vanilla Duo Spread': 'Product: nuts, nut products and seeds',
#  'Sunbeam Foods Pty Ltdâ€”Angas Park and Sunbeam brand dried fruits': 'Product: dietetic foods, food supplements, fortified foods',
#  'Sunbeam Pistachios': 'Product: nuts, nut products and seeds',
#  'Sunsolâ€”Natural Fruity Muesli 750 gm': 'Product: nuts, nut products and seeds',
#  'Supa IGAâ€”Large BBQ Chickens': 'Product: dietetic foods, food supplements, fortified foods',
#  'Suzuran Japan Foods Trading Pty Ltdâ€”Dried seaweed urashima yaki sushi nori 28G 10 oz packet': 'Product: meat, egg and dairy products',
#  'Swan Valley Cheese Companyâ€”Fetta Cheese Products': 'Product: dietetic foods, food supplements, fortified foods',
#  'Sweet Successâ€”Cherry & Coconut Chocolate Bar 90gm': 'Product: cocoa and cocoa preparations, coffee and tea',
#  'Swift and Moore Pty Ltdâ€”Kahlua and Milk': 'Product: alcoholic beverages',
#  'T & D Trading Co Pty Ltdâ€”Aroy-Dâ€”Mussaman curry soup': 'Product: soups, broths, sauces and condiments',
#  'T & D Trading Co Pty Ltdâ€”Loong Heedâ€”Instant Tai Pla (Fish and spice) Paste': 'Product: herbs and spices',
#  'Tan & Co. Pty Ltdâ€”Frozen coconut milk with Taro (ice cream)': 'Product: alcoholic beverages',
#  'Tarac Australiaâ€”Beenleigh Dark Rum': 'Product: alcoholic beverages',
#  'Tender Choice Foods(Aust) Pty Ltdâ€”Oven Roasted Skinless Sliced Chicken 5kg and 1kg': 'Product: dietetic foods, food supplements, fortified foods',
#  'Texas Firm Recalls Beef Trim Products Due To Possible E. coli O157:H7 Contamination': 'Product: dietetic foods, food supplements, fortified foods',
#  'The Australian Football Leagueâ€”AFL 2003 Auskick Plastic Drink Bottles': 'Product: alcoholic beverages',
#  'The Good Stuff Bakeryâ€”White Bread': 'Product: dietetic foods, food supplements, fortified foods',
#  'The Kettle Chip Companyâ€”Chilli Potato Chips': 'Product: dietetic foods, food supplements, fortified foods',
#  'The Natural Ice Cream Companyâ€”Fruccio Ice Dessert and Fruccio Vanilla Cups': 'Product: dietetic foods, food supplements, fortified foods',
#  'The Quang Pty Ltdâ€”Sesame Cake, Mango Pudding and Coconut Cookies.': 'Product: dietetic foods, food supplements, fortified foods',
#  "The Smith's Snackfood Companyâ€”Smiths's Classic Crinkle Cut Potato Chips": 'Product: meat, egg and dairy products',
#  'Tibaldi Smallgoodsâ€”Loin Capocollo mild': 'Product: meat, egg and dairy products',
#  'Tonys Meatsâ€”Pork Loin Cherry and Walnut, Pork Loin Apricot and Macadamia & Greek BBQ Butterfly Lamb Leg': 'Product: meat, egg and dairy products',
#  'Top Tasteâ€”Various products': 'Product: cereals and bakery products',
#  'Trade withdrawal of 500ml Ballygowan Pure Irish Still Water': 'Product: alcoholic beverages',
#  'Turkey And Chicken Products Recalled From Texas Plant For PossibleListeria Contamination': 'Product: cereals and bakery products',
#  'Uncle Tobysâ€”Bluebird Dunkaroos Biscuits': 'Product: meat, egg and dairy products',
#  'Uncle Tobysâ€”Le Snak Rice Crackers, BBQ Flavoured with Mild Salsa Dip': 'Product: dietetic foods, food supplements, fortified foods',
#  "Uncle Tobysâ€”Plus Sultanas 'n Bran": 'Product: cocoa and cocoa preparations, coffee and tea',
#  'United Biscuits recalls certain batches of its Go Ahead! brand Crispy Fruit Slices and Yoghurt Breaks due to possible metal contamination': 'Product: fruits and vegetables',
#  'Update on Jumbo Palm Oil': 'Product: cocoa and cocoa preparations, coffee and tea',
#  'Valcorp Fine Foodsâ€”Gee Vee mild chillies in brine': 'Product: alcoholic beverages',
#  'Vastrade Pty Ltdâ€”Sesame Sauce': None,
#  'Vihenthi Co Pty Ltdâ€”Hello Bee Bee Pon Rice Snack (Gaueteau de Riz)': 'Product: prepared dishes and snacks',
#  'Village Cheeseâ€”Halloumi cheese': 'Product: dietetic foods, food supplements, fortified foods',
#  'WM Morrison recall of deli cooked lamb from their instore delicatessen counters': 'Product: meat, egg and dairy products',
#  'Wah Lien Trading Pty Ltdâ€”Horlicks drink powder': 'Product: alcoholic beverages',
#  'Wah Lien Trading Pty Ltdâ€”Konnyaku Jelly Powder': 'Product: dietetic foods, food supplements, fortified foods',
#  'Wah Lien Trading Pty Ltdâ€”Shui Kou Preserved Bean Curd (Chilli)': 'Product: soups, broths, sauces and condiments',
#  'Wanjashanâ€”Soy Sauce': 'Product: soups, broths, sauces and condiments',
#  'Warning on Bottled Mineral Water Suspected of Containing Foreign Matter': 'Product: alcoholic beverages',
#  'Wattle Valleyâ€”Chunky Dip Chilli Red with Cashew and Parmesan': 'Product: nuts, nut products and seeds',
#  'Wei Wah International Trading Pty Ltdâ€”Lion Globe Dry Seaweed 50g': 'Product: alcoholic beverages',
#  'Weight Watchers Australiaâ€”Rich Toffee Bars': 'Product: dietetic foods, food supplements, fortified foods',
#  'Welsh Country Foods Ltd recalls certain batches of lamb meat and offal due to possible presence of veterinary medicine residues': 'Product: meat, egg and dairy products',
#  'Whisk and Pinâ€”Gluten Free Muesli': 'Product: meat, egg and dairy products',
#  'White Wingsâ€”Cornflour 300 G': 'Product: alcoholic beverages',
#  'Whitestone Windsor Blue Cheese': 'Product: dietetic foods, food supplements, fortified foods',
#  'Willow Confectioneryâ€”60g Dark Chocolate Easter Egg': 'Product: meat, egg and dairy products',
#  'Win Kwong Pty Ltdâ€”Punchun Sesame Sauce': 'Product: soups, broths, sauces and condiments',
#  'Wisconsin Firm Recalls Beef Tongues That Contain Prohibited Materials': 'Product: feed materials',
#  'Withdrawal of two brands of olive-pomace oil': 'Product: fats and oils',
#  'Wm Morrison Supermarkets plc recalls a certain date code of its own brand Toffee & Pecan Ice Cream due to possible contamination with pieces of rubber': 'Product: dietetic foods, food supplements, fortified foods',
#  'Woolworths Limitedâ€”All Lamb Products': 'Product: cereals and bakery products',
#  'Woolworths Limitedâ€”BBQ Chickens Extra Large': 'Product: dietetic foods, food supplements, fortified foods',
#  'Woolworths Limitedâ€”Fruity Muesli Cookies': 'Product: nuts, nut products and seeds',
#  'Woolworths Limitedâ€”Home Brand Frozen Chicken Nuggets': 'Product: dietetic foods, food supplements, fortified foods',
#  'Woolworths Limitedâ€”Home Brand Jasmine Rice': 'Product: cereals and bakery products',
#  'Woolworths Limitedâ€”Home Brand Mini Spring Rolls 6 pack': 'Hazard: packaging defect',
#  'Woolworths Limitedâ€”Home Brand Oyster Sauce': 'Product: soups, broths, sauces and condiments',
#  'Woolworths Limitedâ€”Home Brand Scorched Almonds Milk Chocolate': 'Product: alcoholic beverages',
#  'Woolworths Limitedâ€”Home Brandâ€”Assorted Biscuits': 'Product: dietetic foods, food supplements, fortified foods',
#  'Woolworths Limitedâ€”Home Brandâ€”Nacho Cheese Flavoured Corn Chips': 'Product: dietetic foods, food supplements, fortified foods',
#  'Woolworths Limitedâ€”Home brand white sliced sandwich bread': 'Product: dietetic foods, food supplements, fortified foods',
#  'Woolworths Limitedâ€”Homebrand Corn & Chicken flavour noodles': 'Product: dietetic foods, food supplements, fortified foods',
#  'Woolworths Limitedâ€”Homebrand Wheat Biscuits Cereal Retail Pack': 'Product: dietetic foods, food supplements, fortified foods',
#  'Woolworths Limitedâ€”Homebrandâ€”Mackerel in Natural Oil': 'Product: fats and oils',
#  'Woolworths Limitedâ€”Label Regular Minced Lamb': 'Product: meat, egg and dairy products',
#  'Woolworths Limitedâ€”Minced Lamb, Veal, Pork, Heart Smart Beef, Regular Beef or Premium Beef': 'Product: dietetic foods, food supplements, fortified foods',
#  'Woolworths Limitedâ€”Premium Beef Mince and Regular Beef Mince': 'Product: dietetic foods, food supplements, fortified foods',
#  'Woolworths Limitedâ€”Woolworths Carbonara Pasta Salad': 'Product: dietetic foods, food supplements, fortified foods',
#  'Woolworths Limitedâ€”Woolworths Fresh Milk Lite 2 L': 'Product: alcoholic beverages',
#  'Woolworths Limitedâ€”Woolworths label Minced Heart Smart Beef': 'Product: honey and royal jelly',
#  'Woolworths Supermarketsâ€”Pork mince': 'Product: meat, egg and dairy products',
#  'Woolworths Supermarketsâ€”Pre-Packed Gourmet Lettuce': 'Product: dietetic foods, food supplements, fortified foods',
#  'Woolworthsâ€”Bread soft wholemeal loaf 800g': 'Product: dietetic foods, food supplements, fortified foods',
#  'Woolworthsâ€”Regular Minced Beef': 'Product: dietetic foods, food supplements, fortified foods',
#  "Yuen's Market Trading Companyâ€”Pun Chun Lye Water": 'Product: alcoholic beverages',
#  'island2island Beverage Comp. Pty Ltdâ€”Angostura Lemon Lime and Bitters & Angostura Lemon Lime and Bitters light': 'Product: alcoholic beverages',
#  'marks & spencer recalls a number of own-brand cake products due to contamination with coloured plastic strands': 'Product: dietetic foods, food supplements, fortified foods',
#  'oct 6': 'Product: dietetic foods, food supplements, fortified foods'}

# %% [markdown]
# # Random Sh

# %%
import gzip

# Define the target string
target = "/c/en/oils/"

file_name = "/content/conceptnet-lite.csv"

# Decompress and process line by line
output_file = "filtered_results.csv"
with gzip.open(file_name, "rt", encoding="utf-8") as f_in, open(output_file, "w", encoding="utf-8") as f_out:
    for line in f_in:
        if target in line:
            f_out.write(line)  # Write matching lines to a new CSV file

print(f"Filtered lines containing '{target}' are saved to {output_file}")
# Out:
# ---------------------------------------------------------------------------
# BadGzipFile                               Traceback (most recent call last)
# <ipython-input-81-9ad260157798> in <cell line: 10>()
#       9 output_file = "filtered_results.csv"
#      10 with gzip.open(file_name, "rt", encoding="utf-8") as f_in, open(output_file, "w", encoding="utf-8") as f_out:
# ---> 11     for line in f_in:
#      12         if target in line:
#      13             f_out.write(line)  # Write matching lines to a new CSV file
#
# /usr/lib/python3.10/gzip.py in read1(self, size)
#     312         if size < 0:
#     313             size = io.DEFAULT_BUFFER_SIZE
# --> 314         return self._buffer.read1(size)
#     315
#     316     def peek(self, n):
#
# /usr/lib/python3.10/_compression.py in readinto(self, b)
#      66     def readinto(self, b):
#      67         with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68             data = self.read(len(byte_view))
#      69             byte_view[:len(data)] = data
#      70         return len(data)
#
# /usr/lib/python3.10/gzip.py in read(self, size)
#     486                 # jump to the next member, if there is one.
#     487                 self._init_read()
# --> 488                 if not self._read_gzip_header():
#     489                     self._size = self._pos
#     490                     return b""
#
# /usr/lib/python3.10/gzip.py in _read_gzip_header(self)
#     434
#     435         if magic != b'\037\213':
# --> 436             raise BadGzipFile('Not a gzipped file (%r)' % magic)
#     437
#     438         (method, flag,
#
# BadGzipFile: Not a gzipped file (b'@i')

# %%
file_name = "/content/conceptnet-lite.csv"

# !grep '/c/en/oils/' /content/conceptnet-lite.csv
# Out:
# "/a/[/r/FormOf/,/c/en/oils/,/c/en/oil/n/]",/r/FormOf,/c/en/oils,/c/en/oil/n,"{""dataset"": ""/d/wiktionary/de"", ""license"": ""cc:by-sa/4.0"", ""sources"": [{""contributor"": ""/s/resource/wiktionary/de"", ""process"": ""/s/process/wikiparsec/2""}], ""weight"": 1.0}"
# "/a/[/r/FormOf/,/c/en/oils/n/,/c/en/oil/]",/r/FormOf,/c/en/oils/n,/c/en/oil,"{""dataset"": ""/d/wiktionary/en"", ""license"": ""cc:by-sa/4.0"", ""sources"": [{""contributor"": ""/s/resource/wiktionary/en"", ""process"": ""/s/process/wikiparsec/2""}], ""weight"": 1.0}"
# "/a/[/r/FormOf/,/c/en/oils/v/,/c/en/oil/]",/r/FormOf,/c/en/oils/v,/c/en/oil,"{""dataset"": ""/d/wiktionary/en"", ""license"": ""cc:by-sa/4.0"", ""sources"": [{""contributor"": ""/s/resource/wiktionary/en"", ""process"": ""/s/process/wikiparsec/2""}], ""weight"": 1.0}"

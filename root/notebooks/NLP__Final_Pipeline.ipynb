# %% [markdown]
# <a href="https://colab.research.google.com/github/karthiksairam01/SemEval-Task9/blob/main/root/notebooks/NLP__Final_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pre-processing and Importing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/karthiksairam01/SemEval-Task9.git
# !git clone https://github.com/food-hazard-detection-semeval-2025/food-hazard-detection-semeval-2025.github.io.git
# Out:
# Cloning into 'SemEval-Task9'...
# remote: Enumerating objects: 145, done.
# remote: Counting objects: 100% (145/145), done.
# remote: Compressing objects: 100% (123/123), done.
# remote: Total 145 (delta 39), reused 48 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (145/145), 1.14 MiB | 5.73 MiB/s, done.
# Resolving deltas: 100% (39/39), done.
# Cloning into 'food-hazard-detection-semeval-2025.github.io'...
# remote: Enumerating objects: 125, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (102/102), done.
# remote: Total 125 (delta 57), reused 58 (delta 18), pack-reused 0 (from 0)
# Receiving objects: 100% (125/125), 3.80 MiB | 5.23 MiB/s, done.
# Resolving deltas: 100% (57/57), done.

# %%
#!rm -rf /content/SemEval-Task9/

# %%
# Install necessary libraries
# !pip install networkx pandas tqdm

#!pip install -U pip setuptools wheel
# Out:
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.4.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.6)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import numpy as np
import networkx as nx
import pandas as pd
from tqdm import tqdm
import json
from sklearn.metrics import classification_report

# %% [markdown]
# # Functions (deprecated)

# %%
def get_titles_dict(incidents: pd.DataFrame, column: str) -> dict:
    try:
        values = np.unique(np.concatenate(incidents[column].values))
    except ValueError:
        values = np.unique(incidents[column].values)

    counts = np.array([sum([v in label for label in incidents[column].values]) for v in values])
    result = {}

    for v, n in zip(values, counts):
        doc = nlp(v)
        words = []
        for token in doc:
            if token.pos_ in {"NOUN","ADJ"}:
                words.append(token.text)
        result[v] = {"words": words}

    return result

def get_nodes_dict(incidents: pd.DataFrame, column: str) -> dict:
    try:
        values = np.unique(np.concatenate(incidents[column].values))
    except ValueError:
        values = np.unique(incidents[column].values)

    counts = np.array([sum([v in label for label in incidents[column].values]) for v in values])
    result = {}

    for v, n in zip(values, counts):
        doc = nlp(v)
        words = []
        for token in doc:
            if token.pos_ in {"NOUN", "PROPN", "VERB", "ADJ"}:
                words.append(token.text)
        result[v] = {"words": words}

    return result

def print_nodes(incidents: pd.DataFrame, column: str):
    try:
        values = np.unique(np.concatenate(incidents[column].values))
    except ValueError:
        values = np.unique(incidents[column].values)
    counts = np.array([sum([v in label for label in incidents[column].values]) for v in values])

    for v, n in zip(values, counts):
        # print(v)
        doc = nlp(v)
        words = []
        for token in doc:
            if token.pos_ in {"NOUN", "PROPN", "VERB", "ADJ"}:
                words.append(token.text)
        print(f'  {v}: {words}')

# %% [markdown]
# # Functions
# ## 1. Preprocess ConceptNet URI
# ## 2. Convert ConceptNet CSV to a graph

# %%
def canonicalize_node(uri):
    """
    Canonicalizes a ConceptNet URI by removing parts after the lemma.
    For example:
    "/c/en/condiment/n" -> "/c/en/condiment"
    "/c/en/condiments/n" -> "/c/en/condiments"
    "/c/en/apple" stays "/c/en/apple"
    """
    parts = uri.strip('/').split('/')

    if len(parts) >= 3:
        return "/" + "/".join(parts[:3])
    else:
        return uri

def load_conceptnet_lite_csv(file_path):
    """
    Loads the filtered ConceptNet Lite CSV into a NetworkX graph.

    Parameters:
    - file_path (str): Path to the filtered CSV file.

    Returns:
    - G (networkx.Graph): The constructed undirected graph with canonicalized nodes.
    """
    print("Loading ConceptNet Lite into NetworkX...")
    G = nx.Graph()

    try:
        df = pd.read_csv(file_path, sep=',', encoding='utf-8')
    except Exception as e:
        print(f"Error reading filtered CSV: {e}")
        return G

    print("Adding edges to NetworkX...")
    for index, row in tqdm(df.iterrows(), total=df.shape[0], desc="Adding edges"):
        start = canonicalize_node(row['start'])
        end = canonicalize_node(row['end'])
        rel = row['rel']
        G.add_edge(start, end, relation=rel)

    print(f"Graph has {G.number_of_nodes()} nodes and {G.number_of_edges()} edges.")
    return G

# %% [markdown]
# # Loading ConceptNet with NetworkX

# %%
FILTERED_CSV_FILE = "/content/drive/MyDrive/NeSym/conceptnet-lite[RelatedTo,FormOf,Synonym].csv"

#load graph
G = load_conceptnet_lite_csv(FILTERED_CSV_FILE)
# Out:
# Loading ConceptNet Lite into NetworkX...
# Adding edges to NetworkX...
# Adding edges: 100%|██████████| 2304597/2304597 [01:56<00:00, 19712.06it/s]
# Graph has 948526 nodes and 2052758 edges.

# %% [markdown]
# # Output Labels (hazard/prod categories)

# %%
json_file_path = '/content/SemEval-Task9/root/data/extracted_keywords_hazard_category.json'
with open(json_file_path, 'r') as file:
    data = json.load(file)

df_1 = pd.DataFrame(list(data.items()), columns=['hazard_category', 'extracted_terms'])
hazards = dict(zip(df_1['hazard_category'], df_1['extracted_terms']))

print(hazards)

json_file_path = '/content/SemEval-Task9/root/data/extracted_keywords_product_category.json'
with open(json_file_path, 'r') as file:
    data = json.load(file)

df_2 = pd.DataFrame(list(data.items()), columns=['product_category', 'extracted_terms'])
products = dict(zip(df_2['product_category'], df_2['extracted_terms']))
print(products)
# Out:
# {'allergens': ['allergens'], 'chemical': ['chemical'], 'food additives and flavourings': ['food additives', 'flavourings'], 'foreign bodies': ['foreign bodies', 'bodies'], 'fraud': ['fraud'], 'migration': ['migration'], 'organoleptic aspects': ['organoleptic', 'aspects'], 'other hazard': ['hazard'], 'packaging defect': ['defect']}
# {'alcoholic beverages': ['alcoholic beverage', 'beverage', 'alcoholic', 'beverages'], 'cereals and bakery products': ['cereals', 'bakery', 'products'], 'cocoa and cocoa preparations, coffee and tea': ['cocoa', 'coffee', 'tea'], 'dietetic foods, food supplements, fortified foods': ['dietetic', 'fortified', 'food', 'supplements'], 'fats and oils': ['fats', 'oils'], 'feed materials': ['materials'], 'food additives and flavourings': ['additive', 'flavourings', 'food additives'], 'food contact materials': ['food', 'contact', 'materials'], 'fruits and vegetables': ['fruits', 'vegetables'], 'herbs and spices': ['herbs', 'spices'], 'honey and royal jelly': ['honey', 'royal jelly'], 'ices and desserts': ['desserts', 'ices'], 'meat, egg and dairy products': ['meat', 'egg', 'dairy products'], 'non-alcoholic beverages': ['beverage', 'beverages'], 'nuts, nut products and seeds': ['nut', 'nuts', 'products', 'seeds'], 'other food product / mixed': ['food', 'mixed'], 'pet feed': ['pet'], 'prepared dishes and snacks': ['dishes', 'snacks', 'prepared'], 'seafood': ['seafood'], 'soups, broths, sauces and condiments': ['broth', 'broths', 'soups', 'soup', 'sauces', 'sauce', 'condiments', 'condiment'], 'sugars and syrups': ['sugars', 'syrups']}

# %% [markdown]
# # Input Labels (title keywords)

# %%
json_file_path = '/content/SemEval-Task9/root/data/extracted_keywords_incidents_train.json'
with open(json_file_path, 'r') as file:
    data = json.load(file)

df = pd.DataFrame(list(data.items()), columns=['title', 'extracted_terms'])

len(df)
# Out:
# 4943

# %% [markdown]
# # Experimentation

# %% [markdown]
# ## 1. Removing ban words

# %%
def clean_categories(categories, remove_strings):
    """
    Remove any keywords containing specified strings from both category keys and their associated keywords.

    Parameters:
    - categories (dict): Dictionary mapping category labels to their associated keywords.
    - remove_strings (list): List of strings to be removed from both category keys and their associated keywords.

    Returns:
    - cleaned_categories (dict): Modified dictionary with specified strings removed from each category.
    """
    cleaned_categories = {}

    for label, keywords in categories.items():

        filtered_keywords = [kw for kw in keywords if all(remove_string != kw for remove_string in remove_strings)]

        if filtered_keywords:
            cleaned_categories[label] = filtered_keywords

    return cleaned_categories

# %%
def remove_terms_from_extracted_terms(df, terms_to_remove):
    """Removes specified terms from the 'extracted_terms' column of a DataFrame.

    Args:
        df: The input DataFrame.
        terms_to_remove: A list of terms to remove.

    Returns:
        A new DataFrame with the specified terms removed from the 'extracted_terms' column.
    """

    df_cleaned = df.copy()

    df_cleaned['extracted_terms'] = df_cleaned['extracted_terms'].apply(
        lambda terms: [term for term in terms if term not in terms_to_remove]
    )

    return df_cleaned

# %% [markdown]
# ## 2. Pruning

# %%
to_remove = ['good', 'white', 'recall', 'selected', 'stores', 'sold', 'food', 'materials', 'emphasise', 'beverage', 'beverages', 'products', 'mixed', 'issues', 'mix', 'alert', 'health', 'product', 'update']
print(hazards)
hazards = clean_categories(hazards, to_remove)


print(products)
products = clean_categories(products, to_remove)

print(df.head())

df_cleaned = remove_terms_from_extracted_terms(df, to_remove)

df = df_cleaned
print(df.head())
len(df)

# %% [markdown]
# ## 3. Searching for one specific useless title repeated 70 times

# %%
search_string = 'recall notification'
matches = df[df['title'].str.contains(search_string, case=False, na=False)]

print("Rows matching the search string:")
print(matches)
len(matches)

# %% [markdown]
# ## 4. Deleting said useless title

# %%
df_cleaned = df[~df['title'].str.contains(search_string, case=False, na=False)]

search_string = 'recall notification'

df_cleaned = df[~df['title'].str.contains(search_string, case=False, na=False)]

print("DataFrame after removing matching rows:")
print(df_cleaned)

df = df_cleaned

# %% [markdown]
# # Function to generate the sub-graphs

# %%
from collections import deque

def multi_source_bfs(G, start_nodes, max_distance=3):
    """
    Perform BFS from multiple start nodes up to max_distance.

    Parameters:
    - G (networkx.Graph): The graph to traverse.
    - start_nodes (list): List of node identifiers to start BFS from.
    - max_distance (int): Maximum distance to traverse.

    Returns:
    - distance (dict): Dictionary mapping nodes to their shortest distance from any start node.
    """
    distance = {}
    queue = deque()

    for node in start_nodes:
        if node in G:
            distance[node] = 0
            queue.append((node, 0))
        else:
            print(f"Warning: Start node {node} not in graph.")

    while queue:
        current_node, current_distance = queue.popleft()

        if current_distance >= max_distance:
            continue

        for neighbor in G.neighbors(current_node):
            if neighbor not in distance:
                distance[neighbor] = current_distance + 1
                queue.append((neighbor, current_distance + 1))

    return distance

# %% [markdown]
# # Testing and Debugging

# %%
start_concepts = ["alcohol"]  # Modify this list as needed

start_uris = [f"/c/en/{concept.lower()}" for concept in start_concepts]

print(start_uris)
# Out:
# ['/c/en/alcohol']

# %%
max_distance = 5  # Adjust as needed

dist_map = multi_source_bfs(G, start_uris, max_distance)

# %%
print(len(dist_map))
# Out:
# 825502

# %% [markdown]
# ## 1. Verify if node in ConceptNet

# %%
def verify_nodes(G, nodes):
    """
    Verifies if the given nodes exist in the graph.

    Parameters:
    - G (networkx.Graph or networkx.DiGraph): The graph.
    - nodes (list): List of ConceptNet URIs to verify.

    Returns:
    - existing_nodes (list): Nodes that exist in the graph.
    - missing_nodes (list): Nodes that do not exist in the graph.
    """
    existing_nodes = []
    missing_nodes = []
    for node in nodes:
        if node in G:
            existing_nodes.append(node)
        else:
            missing_nodes.append(node)
    return existing_nodes, missing_nodes

# %%
start_concepts = ["dietetical"]  # Modify this list as needed

start_uris = [f"/c/en/{concept.lower()}" for concept in start_concepts]

print(start_uris)

existing, missing = verify_nodes(G, start_uris)

print("\n=== Node Verification ===")
for node in existing:
    print(f"{node} exists in the graph.")
for node in missing:
    print(f"{node} does NOT exist in the graph.")
# Out:
# ['/c/en/dietetical']
#
# === Node Verification ===
# /c/en/dietetical exists in the graph.

# %% [markdown]
# # Subgraph generation

# %%
#print(products)

# Convert product and hazard keywords to ConceptNet URIs
product_uris = {cat: [f"/c/en/{kw.replace(' ', '_').lower()}" for kw in kws] for cat, kws in products.items()}
hazard_uris = {cat: [f"/c/en/{kw.replace(' ', '_').lower()}" for kw in kws] for cat, kws in hazards.items()}

# Generate subgraphs for products and hazards
product_subgraphs = {cat: multi_source_bfs(G, uris, max_distance) for cat, uris in product_uris.items()}
hazard_subgraphs = {cat: multi_source_bfs(G, uris, max_distance) for cat, uris in hazard_uris.items()}
# Out:
# {'alcoholic beverages': ['alcoholic beverage', 'alcoholic'], 'cereals and bakery products': ['cereals', 'bakery'], 'cocoa and cocoa preparations, coffee and tea': ['cocoa', 'coffee', 'tea'], 'dietetic foods, food supplements, fortified foods': ['dietetic', 'fortified', 'supplements'], 'fats and oils': ['fats', 'oils'], 'food additives and flavourings': ['additive', 'flavourings', 'food additives'], 'food contact materials': ['contact'], 'fruits and vegetables': ['fruits', 'vegetables'], 'herbs and spices': ['herbs', 'spices'], 'honey and royal jelly': ['honey', 'royal jelly'], 'ices and desserts': ['desserts', 'ices'], 'meat, egg and dairy products': ['meat', 'egg', 'dairy products'], 'nuts, nut products and seeds': ['nut', 'nuts', 'seeds'], 'pet feed': ['pet'], 'prepared dishes and snacks': ['dishes', 'snacks', 'prepared'], 'seafood': ['seafood'], 'soups, broths, sauces and condiments': ['broth', 'broths', 'soups', 'soup', 'sauces', 'sauce', 'condiments', 'condiment'], 'sugars and syrups': ['sugars', 'syrups']}

# %% [markdown]
# # Classification Function

# %%
def classify_title_keywords(df, categories, max_distance=5):
    """
    Classify titles into categories based on the minimum distance between title keywords and pre-generated category subgraphs.

    Parameters:
    - df (pd.DataFrame): DataFrame containing 'title' and 'extracted_terms' columns.
    - categories (dict): Dictionary mapping category labels to their distance dictionaries (pre-generated subgraphs).
    - max_distance (int): Maximum BFS distance to consider.

    Returns:
    - classifications (dict): Dictionary mapping titles to their classified category.
    """
    classifications = {}

    # Iterate over each title in the DataFrame and classify
    for _, row in df.iterrows():
        title = row['title']
        keywords = row['extracted_terms']
        #print(keywords)
        #print(f"Processing title: {title}, Keywords: {keywords}")

        min_distance = float('inf')
        assigned_category = None

        for category, distances in categories.items():

            # MIN CODE
            category_min_distance = float('inf')

            for keyword in keywords:
                keyword_uri = f"/c/en/{keyword.replace(' ', '_').lower()}"
                distance = distances.get(keyword_uri, float('inf'))
                if distance < category_min_distance:
                    category_min_distance = distance
                    #print(f"Category: {category}, Keyword: {keyword}, Distance: {distance}")

            # # AVG CODE

            # # Calculate the average distance to all keywords in the title for each category
            # category_average_distance = float('inf')

            # if keywords:
            #     distances_sum = 0
            #     valid_distances = 0

            #     for keyword in keywords:
            #         #print(keyword)
            #         keyword_uri = f"/c/en/{keyword.replace(' ', '_').lower()}"
            #         distance = distances.get(keyword_uri, float('inf'))

            #         # Only consider valid distances
            #         if distance != float('inf'):
            #             #print(f"Category: {category}, Keyword: {keyword}, Distance: {distance}")
            #             distances_sum += distance
            #             valid_distances += 1


            #     # Compute average distance if there are valid distances
            #     if valid_distances > 0:
            #         category_average_distance = distances_sum
            #         #print(f"Category: {category}, Average Distance: {category_average_distance}")


            # # Check if this category has a smaller average distance than previously found categories
            # if category_average_distance < min_distance:
            #     min_distance = category_average_distance
            #     assigned_category = category

            if category_min_distance < min_distance:
                min_distance = category_min_distance
                assigned_category = category

        classifications[title] = assigned_category

    return classifications

# %% [markdown]
# # Classification

# %%
categories = product_subgraphs
classifications_products_cat = classify_title_keywords(df, categories, G)

#classifications_products_cat

# %%
categories = hazard_subgraphs
classifications_hazards_cat = classify_title_keywords(df, categories, G)

#classifications_hazards_cat

# %%
title = "2009 - deluxe ice cream co. expands recall to include additional codes of tin roof sundae, goo goo cluster, and candy bar half gallon packaged ice cream product, 3 gallon tin roof sundae and qc 24 pack sundae cone because of possible health risk"

if title in classifications_products_cat:
    print(classifications_products_cat[title])
else:
    print(f"The key '{title}' does not exist in the dictionary.")
# Out:
# None

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## 1. Preprocessing
# To format correctly and also replace 'inf' classifications with 'Unknown'

# %%
# Prepare the data to evaluate

def prepare_predictions(classifications):
    """
    Prepare predictions in the required format for evaluation.

    Parameters:
    - classifications (dict): Dictionary of titles and their classified categories.

    Returns:
    - formatted_predictions (dict): Predictions formatted for evaluation.
    """
    formatted_predictions = {}

    for title, category in classifications.items():
        formatted_predictions[title] = category

    return formatted_predictions

# %%
def sanitize_predictions(predictions):
    for title in list(predictions.keys()):
        if predictions[title] is None:
            #print(title)
            predictions[title] = 'Unknown'  #replace None with 'Unknown'
        elif not isinstance(predictions[title], str):
            predictions[title] = str(predictions[title])
    return predictions

# %%
# Prepare the predictions
formatted_predictions_pc = prepare_predictions(classifications_products_cat)
formatted_predictions_pc = sanitize_predictions(formatted_predictions_pc)

print(formatted_predictions_pc)
len(formatted_predictions_pc)
# Out:
# {'Vilis Lamb, Mint and Rosemary Pies 160g': 'meat, egg and dairy products', "'Jackpot Mix' brand of Mix of Pretzels, Sticks and Salted Biscuits recalled": 'cocoa and cocoa preparations, coffee and tea', '(Updated) Bradbury &amp  Son (Buxton) recalls Lo-Col because milk is not emphasised on the labelling': 'cocoa and cocoa preparations, coffee and tea', '*(Updated on 2 June 2020) Not to consume a batch of bottled apple juice drink contaminated with patulin': 'alcoholic beverages', '*(Updated on 5 July 2022) Not to consume smoked salmon products with dill possibly contaminated with Listeria monocytogenes': 'alcoholic beverages', '165368 C. Corporation Recalls Pork Products Due to Possible Listeria Contamination': 'meat, egg and dairy products', '168 Express Ltd recalls various Jelly products because of a choking hazard': 'meat, egg and dairy products', '2006 - Consumer Alert: Listeria Contamination in Raw Milk': 'cocoa and cocoa preparations, coffee and tea', '2006 - Pinnacle Foods Corporation Issues Allergy Alert on Bakery-Style Chocolate Chip Muffin Mix': 'cocoa and cocoa preparations, coffee and tea', '2006 - Pinnacle Foods Group Inc. Issues Allergy Alert on Undeclared Egg in Frozen': 'meat, egg and dairy products', '2006 - allergy alert on undeclared almonds in albertsons chocolate ice cream': 'honey and royal jelly', '2006 - pinnacle foods group inc. issues allergy alert on brownie mix': 'cereals and bakery products', '2007 - Agriculture Department Warns Consumers of Tainted Raw Milk Sold by Butler County Dairy': 'cocoa and cocoa preparations, coffee and tea', '2007 - WholeSoy & Co. Expands National Allergy Alert on Undeclared Dairy in Blueberry and Mixed Berry Yogurt': 'meat, egg and dairy products', '2007 - Winn-Dixie Stores, Inc. Issues Allergy Alert on Mislabeled Prestige Chocolate Ice Cream': 'cocoa and cocoa preparations, coffee and tea', '2007 - private selection® ice cream recalled from ralphs and food 4 less stores in california': 'meat, egg and dairy products', '2008 - Barry Callebaut USA LLC Issues Allergen Alert on Undeclared Milk Protein in Kroger Value Semi Sweet Chocolate Chips': 'cocoa and cocoa preparations, coffee and tea', "2008 - dreyer's issues voluntary recall of slow churned® light caramel delight and butter pecan ice cream flavors for undeclared pecans": 'nuts, nut products and seeds', '2008 - limited number of aunt jemima pancake & waffle mix products recalled for possible health risk': 'cocoa and cocoa preparations, coffee and tea', "2008 - pierre's ice cream company issues allergy alert on its homestyle brand of dutch chocolate ice cream for undeclared peanut butter cup candies": 'cocoa and cocoa preparations, coffee and tea', '2008 - private selection ice cream recalled from kroger stores in twelve southeastern states': 'cocoa and cocoa preparations, coffee and tea', '2009 - A Manufacturer From England, Cropwell Bishop Creamery Limited, is Conducting a Nationwide Recall on the Cheese Products Blue Stilton and Shropshire Blue Cheese Because of Possible Health Risk': 'meat, egg and dairy products', '2009 - Alexia Foods issues nationwide allergy alert and product recall on its Alexia Olive Oil, Sun-Dried Tomatoes & Pesto Oven Reds frozen potatoes due to undeclared pine nut allergen': 'cereals and bakery products', '2009 - BIC Acquisition, LLC Recalls World Classic Trading Company Ultimate Chunk Ice Cream': 'ices and desserts', '2009 - Bliss Bros. Dairy, Inc. Recalls Ice Cream Products Because of Possible Health Risk': 'cocoa and cocoa preparations, coffee and tea', '2009 - Boca Grande Foods Announces a Nationwide Recall of POCO PAC?, and GRANDE GOURMETT Peanut Butter Products Because of Possible Health Risk': 'cocoa and cocoa preparations, coffee and tea', "2009 - Braum's Ice Cream and Dairy Stores Announces Voluntary Recall of its Premium Ice Cream Flavor": 'soups, broths, sauces and condiments', '2009 - Bucks Ice Cream Recalls Ice Cream Nut Roll Because of Possible Health Risk': 'cocoa and cocoa p ...
# 4880

# %%
formatted_predictions_hc = prepare_predictions(classifications_hazards_cat)
formatted_predictions_hc = sanitize_predictions(formatted_predictions_hc)

print(formatted_predictions_hc)
len(formatted_predictions_hc)
# Out:
# {'Vilis Lamb, Mint and Rosemary Pies 160g': 'chemical', "'Jackpot Mix' brand of Mix of Pretzels, Sticks and Salted Biscuits recalled": 'other hazard', '(Updated) Bradbury &amp  Son (Buxton) recalls Lo-Col because milk is not emphasised on the labelling': 'chemical', '*(Updated on 2 June 2020) Not to consume a batch of bottled apple juice drink contaminated with patulin': 'chemical', '*(Updated on 5 July 2022) Not to consume smoked salmon products with dill possibly contaminated with Listeria monocytogenes': 'chemical', '165368 C. Corporation Recalls Pork Products Due to Possible Listeria Contamination': 'chemical', '168 Express Ltd recalls various Jelly products because of a choking hazard': 'other hazard', '2006 - Consumer Alert: Listeria Contamination in Raw Milk': 'chemical', '2006 - Pinnacle Foods Corporation Issues Allergy Alert on Bakery-Style Chocolate Chip Muffin Mix': 'allergens', '2006 - Pinnacle Foods Group Inc. Issues Allergy Alert on Undeclared Egg in Frozen': 'allergens', '2006 - allergy alert on undeclared almonds in albertsons chocolate ice cream': 'allergens', '2006 - pinnacle foods group inc. issues allergy alert on brownie mix': 'allergens', '2007 - Agriculture Department Warns Consumers of Tainted Raw Milk Sold by Butler County Dairy': 'chemical', '2007 - WholeSoy & Co. Expands National Allergy Alert on Undeclared Dairy in Blueberry and Mixed Berry Yogurt': 'allergens', '2007 - Winn-Dixie Stores, Inc. Issues Allergy Alert on Mislabeled Prestige Chocolate Ice Cream': 'allergens', '2007 - private selection® ice cream recalled from ralphs and food 4 less stores in california': 'chemical', '2008 - Barry Callebaut USA LLC Issues Allergen Alert on Undeclared Milk Protein in Kroger Value Semi Sweet Chocolate Chips': 'allergens', "2008 - dreyer's issues voluntary recall of slow churned® light caramel delight and butter pecan ice cream flavors for undeclared pecans": 'fraud', '2008 - limited number of aunt jemima pancake & waffle mix products recalled for possible health risk': 'other hazard', "2008 - pierre's ice cream company issues allergy alert on its homestyle brand of dutch chocolate ice cream for undeclared peanut butter cup candies": 'allergens', '2008 - private selection ice cream recalled from kroger stores in twelve southeastern states': 'foreign bodies', '2009 - A Manufacturer From England, Cropwell Bishop Creamery Limited, is Conducting a Nationwide Recall on the Cheese Products Blue Stilton and Shropshire Blue Cheese Because of Possible Health Risk': 'other hazard', '2009 - Alexia Foods issues nationwide allergy alert and product recall on its Alexia Olive Oil, Sun-Dried Tomatoes & Pesto Oven Reds frozen potatoes due to undeclared pine nut allergen': 'allergens', '2009 - BIC Acquisition, LLC Recalls World Classic Trading Company Ultimate Chunk Ice Cream': 'chemical', '2009 - Bliss Bros. Dairy, Inc. Recalls Ice Cream Products Because of Possible Health Risk': 'other hazard', '2009 - Boca Grande Foods Announces a Nationwide Recall of POCO PAC?, and GRANDE GOURMETT Peanut Butter Products Because of Possible Health Risk': 'other hazard', "2009 - Braum's Ice Cream and Dairy Stores Announces Voluntary Recall of its Premium Ice Cream Flavor": 'chemical', '2009 - Bucks Ice Cream Recalls Ice Cream Nut Roll Because of Possible Health Risk': 'other hazard', '2009 - Fieldbrook Foods Corp. Announces Nationwide Voluntary Recall of Select Ice Cream Novelty Products Due to Possible Health Risk': 'other hazard', '2009 - Fieldbrook Foods Corporation Adds Four Products to Nationwide Voluntary Recall of Select Ice Cream Novelty Products Due to Possible Health Risk': 'other hazard', '2009 - Frito-Lay Issues Nationwide Voluntary Recall of In-Shell Pistachio Nuts Due to Possible Health Risk': 'other hazard', '2009 - Garden-Fresh Foods Issues Allergy Alert On Undeclared Milk in 16-Ounce Archer Farms Potato Salad': 'chemical', '2009 - Glutenfreeda Foods, Inc. Recalls Peanut Envy Frozen Cookie Dough Because of Possible Health R ...
# 4880

# %% [markdown]
# ## Evaluation Function

# %%
def evaluate_predictions(dataset_path, predictions, category):
    """
    Evaluate model predictions against the ground truth in the dataset for a specific category.

    Parameters:
    - dataset_path (str): Path to the dataset containing ground truth.
    - predictions (dict): Dictionary with titles as keys and predicted categories as values.
                          Format: {title: predicted_category}
    - category (str): The category to evaluate (e.g., 'hazard-category', 'product-category').

    Returns:
    - None (prints the evaluation results)
    """
    import pandas as pd
    from sklearn.metrics import classification_report

    df = pd.read_csv(dataset_path)

    required_columns = ['title', category]
    if not all(col in df.columns for col in required_columns):
        raise ValueError(f"The dataset must contain the columns: {required_columns}")

    filtered_df = df[df['title'].isin(predictions.keys())]

    true_labels = []
    predicted_labels = []
    examples = []

    for _, row in filtered_df.iterrows():
        title = row['title']
        ground_truth = row[category]

        true_labels.append(ground_truth)

        prediction = predictions.get(title, 'Unknown')
        predicted_labels.append(prediction)

        examples.append((title, ground_truth, prediction))

    print(f"Evaluation of {category.replace('-', ' ').capitalize()} Predictions:")
    print(classification_report(true_labels, predicted_labels, zero_division=0))

    # # Display mismatched predictions
    # print("\nExamples of Predictions vs Ground Truth:")
    # mismatches = [ex for ex in examples if ex[1] != ex[2]]
    # for i, (title, truth, pred) in enumerate(mismatches[:10]):  # Show the first 10 mismatches
    #     print(f"{i+1}. Title: {title}")
    #     print(f"   Truth: {truth}")
    #     print(f"   Predicted: {pred}")
    #     print("")

    output_df = pd.DataFrame(examples, columns=['title', 'ground_truth', 'predicted'])
    output_df.to_csv(f"predictions_vs_truth_{category}.csv", index=False)
    print(f"\nFull results saved to 'predictions_vs_truth_{category}.csv'")

# %%
dataset_path = "/content/food-hazard-detection-semeval-2025.github.io/data/incidents_train.csv"

evaluate_predictions(dataset_path, formatted_predictions_pc, 'product-category')
# Out:
# Evaluation of Product category Predictions:
#                                                    precision    recall  f1-score   support
#
#                                           Unknown       0.00      0.00      0.00         0
#                               alcoholic beverages       0.06      0.80      0.11        59
#                       cereals and bakery products       0.40      0.30      0.35       661
#      cocoa and cocoa preparations, coffee and tea       0.14      0.65      0.23       205
#                                     confectionery       0.00      0.00      0.00       169
# dietetic foods, food supplements, fortified foods       0.65      0.13      0.22       128
#                                     fats and oils       0.14      0.05      0.08        19
#                                    feed materials       0.00      0.00      0.00         6
#                    food additives and flavourings       0.00      0.00      0.00         8
#                            food contact materials       0.00      0.00      0.00         7
#                             fruits and vegetables       0.34      0.17      0.23       531
#                                  herbs and spices       0.68      0.14      0.23       125
#                             honey and royal jelly       0.08      0.75      0.15         8
#                                 ices and desserts       0.81      0.06      0.11       218
#                      meat, egg and dairy products       0.55      0.58      0.57      1349
#                           non-alcoholic beverages       0.00      0.00      0.00       133
#                      nuts, nut products and seeds       0.31      0.28      0.29       255
#                        other food product / mixed       0.00      0.00      0.00        53
#                                          pet feed       0.15      0.40      0.21        20
#                        prepared dishes and snacks       0.33      0.04      0.07       458
#                                           seafood       0.73      0.18      0.29       267
#              soups, broths, sauces and condiments       0.41      0.46      0.43       261
#                                 sugars and syrups       0.00      0.00      0.00         5
#
#                                          accuracy                           0.32      4945
#                                         macro avg       0.25      0.22      0.15      4945
#                                      weighted avg       0.43      0.32      0.31      4945
#
#
# Full results saved to 'predictions_vs_truth_product-category.csv'

# %%
evaluate_predictions(dataset_path, formatted_predictions_hc, 'hazard-category')
# Out:
# Evaluation of Hazard category Predictions:
#                                 precision    recall  f1-score   support
#
#                        Unknown       0.00      0.00      0.00         0
#                      allergens       0.94      0.38      0.54      1826
#                     biological       0.00      0.00      0.00      1691
#                       chemical       0.07      0.84      0.13       279
# food additives and flavourings       0.09      0.13      0.11        23
#                 foreign bodies       0.11      0.02      0.03       547
#                          fraud       0.21      0.11      0.15       342
#                      migration       0.03      0.33      0.05         3
#           organoleptic aspects       0.00      0.00      0.00        52
#                   other hazard       0.04      0.17      0.07       128
#               packaging defect       0.10      0.13      0.12        54
#
#                       accuracy                           0.20      4945
#                      macro avg       0.14      0.19      0.11      4945
#                   weighted avg       0.38      0.20      0.22      4945
#
#
# Full results saved to 'predictions_vs_truth_hazard-category.csv'

# %% [markdown]
# # Hazards

# %%
json_file_path = '/content/SemEval-Task9/root/data/extracted_keywords_hazards.json'
with open(json_file_path, 'r') as file:
    data = json.load(file)

df_3 = pd.DataFrame(list(data.items()), columns=['hazard', 'extracted_terms'])
hazards_true = dict(zip(df_3['hazard'], df_3['extracted_terms']))

print(hazards_true)
# Out:
# {'Aflatoxin': ['aflatoxin'], 'abnormal smell': ['smell', 'abnormal'], 'alcohol content': ['alcohol', 'content'], 'alkaloids': ['alkaloids'], 'allergens': ['allergens'], 'almond': ['almond'], 'altered organoleptic characteristics': ['altered', 'organoleptic', 'characteristics'], 'amygdalin': ['amygdalin'], 'antibiotics, vet drugs': ['antibiotics'], 'bacillus spp.': ['bacillus'], 'bad smell / off odor': ['bad', 'smell', 'odor'], 'bone fragment': ['bone', 'fragment'], 'brazil nut': ['brazil', 'nut'], 'bulging packaging': ['bulging'], 'cashew': ['cashew'], 'celery and products thereof': ['celery', 'products'], 'cereals containing gluten and products thereof': ['cereals', 'gluten', 'products'], 'cereals': ['cereals'], 'chemical compound (high content)': ['chemical', 'compound', 'high'], 'chemical compound (unauthorised)': ['chemical', 'compound', 'unauthorised'], 'chemical': ['chemical'], 'chlorine': ['chlorine'], 'clostridium botulinum': ['clostridium', 'botulinum'], 'coconut': ['coconut'], 'coliforms': ['coliforms'], 'compositional deviation': ['compositional', 'deviation'], 'contaminant': ['contaminant'], 'cronobacter spp': ['cronobacter'], 'crustaceans and products thereof': ['crustaceans', 'products'], 'dairy products': ['dairy products', 'products', 'dairy'], 'damaged packaging': ['damaged'], 'dioxins': ['dioxins'], 'e 425 - konjac unauthorised': ['konjac'], 'eggs and products thereof': ['egg', 'products'], 'enteroviruses': ['enteroviruses'], 'escherichia coli': ['escherichia coli'], 'false marketing claims': ['claim', 'false'], 'fish and products thereof': ['fish', 'products'], 'foreign bodies': ['foreign bodies', 'foreign body', 'bodies'], 'glass fragment': [], 'haloxyfop': ['haloxyfop'], 'hazelnut': ['hazelnut'], 'heavy metals': ['heavy metals', 'heavy metal', 'metals'], 'high content of copper': ['copper', 'content'], 'high content of cyanide': ['cyanide', 'high'], 'high content of vitamins': ['vitamins'], 'improper conditions': ['improper', 'conditions'], 'improper packaging': ['improper'], 'incorrect labeling': ['incorrect'], 'incorrect use by dates': ['use', 'date', 'incorrect'], 'insects': ['insects'], 'inspection issues': ['issue', 'inspection'], 'insufficient labelling/documentation': ['insufficient'], 'listeria monocytogenes': ['listeria monocytogenes'], 'listeria spp': ['listeria'], 'metal fragment': ['metal', 'fragment'], 'microbiological contamination': ['microbiological', 'contamination'], 'milk and products thereof': ['milk', 'products'], 'misbranding': ['misbranding'], 'misdescription': ['misdescription'], 'molluscs and products thereof': ['molluscs', 'products'], 'moulds': ['moulds'], 'mustard and products thereof': ['mustard'], 'nitrogen': ['nitrogen'], 'non compliance with HACCP': ['haccp', 'non compliance'], 'novel food': ['novel', 'food'], 'nuts': ['nuts'], 'ochratoxin': ['ochratoxin'], 'organochlorine': ['organochlorine'], 'other misbranding issues': ['misbranding', 'issues'], 'other not classified allergen hazards': ['hazards', 'allergen'], 'other not classified biological hazards': ['hazards', 'hazard', 'biological'], 'other not classified chemical hazards': ['chemical', 'hazards'], 'other not classified hazards for foreign bodies': ['hazards', 'foreign bodies', 'body', 'foreign body', 'hazard'], 'packaging defect': ['defect'], 'paralytic shellfish poisoning (psp) toxins': ['paralytic', 'shellfish', 'toxins'], 'pathogenic bacteria': ['pathogenic'], 'patulin': ['patulin'], 'peanuts and products thereof': ['peanuts', 'products'], 'pecan nut': ['pecan', 'nut'], 'phenylpyrazole': ['phenylpyrazole'], 'pieces of wood': ['wood', 'pieces'], 'pistachio nut': ['nut', 'pistachio'], 'plastic fragment': ['plastic', 'fragment'], 'polycyclic aromatic hydrocarbons': [], 'poor hygienic state': ['hygienic', 'poor'], 'poor or insufficient controls': ['insufficient', 'poor'], 'product category/characteristics': ['product'], 'pseudomonas spp.': ['pseudomonas'], 'rubber fragments': ['fragments', 'rubber'], 'salmonella': [' ...

# %%
hazards_true = clean_categories(hazards_true, to_remove)
hazards_true
# Out:
# {'Aflatoxin': ['aflatoxin'],
#  'abnormal smell': ['smell', 'abnormal'],
#  'alcohol content': ['alcohol', 'content'],
#  'alkaloids': ['alkaloids'],
#  'allergens': ['allergens'],
#  'almond': ['almond'],
#  'altered organoleptic characteristics': ['altered',
#   'organoleptic',
#   'characteristics'],
#  'amygdalin': ['amygdalin'],
#  'antibiotics, vet drugs': ['antibiotics'],
#  'bacillus spp.': ['bacillus'],
#  'bad smell / off odor': ['bad', 'smell', 'odor'],
#  'bone fragment': ['bone', 'fragment'],
#  'brazil nut': ['brazil', 'nut'],
#  'bulging packaging': ['bulging'],
#  'cashew': ['cashew'],
#  'celery and products thereof': ['celery'],
#  'cereals containing gluten and products thereof': ['cereals', 'gluten'],
#  'cereals': ['cereals'],
#  'chemical compound (high content)': ['chemical', 'compound', 'high'],
#  'chemical compound (unauthorised)': ['chemical', 'compound', 'unauthorised'],
#  'chemical': ['chemical'],
#  'chlorine': ['chlorine'],
#  'clostridium botulinum': ['clostridium', 'botulinum'],
#  'coconut': ['coconut'],
#  'coliforms': ['coliforms'],
#  'compositional deviation': ['compositional', 'deviation'],
#  'contaminant': ['contaminant'],
#  'cronobacter spp': ['cronobacter'],
#  'crustaceans and products thereof': ['crustaceans'],
#  'dairy products': ['dairy products', 'dairy'],
#  'damaged packaging': ['damaged'],
#  'dioxins': ['dioxins'],
#  'e 425 - konjac unauthorised': ['konjac'],
#  'eggs and products thereof': ['egg'],
#  'enteroviruses': ['enteroviruses'],
#  'escherichia coli': ['escherichia coli'],
#  'false marketing claims': ['claim', 'false'],
#  'fish and products thereof': ['fish'],
#  'foreign bodies': ['foreign bodies', 'foreign body', 'bodies'],
#  'haloxyfop': ['haloxyfop'],
#  'hazelnut': ['hazelnut'],
#  'heavy metals': ['heavy metals', 'heavy metal', 'metals'],
#  'high content of copper': ['copper', 'content'],
#  'high content of cyanide': ['cyanide', 'high'],
#  'high content of vitamins': ['vitamins'],
#  'improper conditions': ['improper', 'conditions'],
#  'improper packaging': ['improper'],
#  'incorrect labeling': ['incorrect'],
#  'incorrect use by dates': ['use', 'date', 'incorrect'],
#  'insects': ['insects'],
#  'inspection issues': ['issue', 'inspection'],
#  'insufficient labelling/documentation': ['insufficient'],
#  'listeria monocytogenes': ['listeria monocytogenes'],
#  'listeria spp': ['listeria'],
#  'metal fragment': ['metal', 'fragment'],
#  'microbiological contamination': ['microbiological', 'contamination'],
#  'milk and products thereof': ['milk'],
#  'misbranding': ['misbranding'],
#  'misdescription': ['misdescription'],
#  'molluscs and products thereof': ['molluscs'],
#  'moulds': ['moulds'],
#  'mustard and products thereof': ['mustard'],
#  'nitrogen': ['nitrogen'],
#  'non compliance with HACCP': ['haccp', 'non compliance'],
#  'novel food': ['novel'],
#  'nuts': ['nuts'],
#  'ochratoxin': ['ochratoxin'],
#  'organochlorine': ['organochlorine'],
#  'other misbranding issues': ['misbranding'],
#  'other not classified allergen hazards': ['hazards', 'allergen'],
#  'other not classified biological hazards': ['hazards',
#   'hazard',
#   'biological'],
#  'other not classified chemical hazards': ['chemical', 'hazards'],
#  'other not classified hazards for foreign bodies': ['hazards',
#   'foreign bodies',
#   'body',
#   'foreign body',
#   'hazard'],
#  'packaging defect': ['defect'],
#  'paralytic shellfish poisoning (psp) toxins': ['paralytic',
#   'shellfish',
#   'toxins'],
#  'pathogenic bacteria': ['pathogenic'],
#  'patulin': ['patulin'],
#  'peanuts and products thereof': ['peanuts'],
#  'pecan nut': ['pecan', 'nut'],
#  'phenylpyrazole': ['phenylpyrazole'],
#  'pieces of wood': ['wood', 'pieces'],
#  'pistachio nut': ['nut', 'pistachio'],
#  'plastic fragment': ['plastic', 'fragment'],
#  'poor hygienic state': ['hygienic', 'poor'],
#  'poor or insufficient controls': ['insufficient', 'poor'],
#  'pseudomonas spp.': ['pseudomonas'],
#  'rubber fragments': ['fragments', 'rubber'],
#  'salmonella': ['salmonella'],
#  'sesame seeds and products thereof': ['sesame', 'seeds'],
#  'soybeans and products thereof': ['soybeans'],
#  'specified risk material (srm)': ['specified', 'risk', 'material', 'srm'],
#  'spoilage': ['spoilage'],
#  'staphylococcal enterotoxin': ['staphylococcal enterotoxin', 'enterotoxin'],
#  'stones': ['stones'],
#  'sulfamethazine unauthorised': ['unauthorised'],
#  'sulphur dioxide and sulphites': ['sulphur', 'sulphites'],
#  'sulphur dioxide': ['sulphur', 'dioxide', 'sulphur dioxide'],
#  'taste disturbance': ['taste', 'disturbance'],
#  'too high content of fluorinated organic chemicals': ['fluorinated',
#   'high',
#   'chemical',
#   'organic'],
#  'too high content of tetrahydrocannabinol (THC)': ['tetrahydrocannabinol',
#   'thc',
#   'high',
#   'content'],
#  'toxin': ['toxin'],
#  'unauthorised colour sudan 4': ['sudan', 'colour'],
#  'unauthorised import': ['unauthorised', 'import'],
#  'unauthorised operator': ['operator'],
#  'unauthorised placing on the market': ['place', 'market', 'placing on'],
#  'unauthorised substance ethylene oxide': ['oxide', 'ethylene'],
#  'unauthorised substance sildenafil': ['sildenafil'],
#  'undeclared additive': ['undeclared', 'additive'],
#  'undeclared constituent': ['constituent'],
#  'unfit for human consumption': ['consumption', 'human'],
#  'vibrio spp': ['vibrio'],
#  'walnut': ['walnut'],
#  'yeasts': ['yeasts']}

# %%
# Convert product and hazard keywords to ConceptNet URIs
hazard_true_uris = {cat: [f"/c/en/{kw.replace(' ', '_').lower()}" for kw in kws] for cat, kws in hazards_true.items()}

# Generate subgraphs for products and hazards
hazard_true_subgraphs = {cat: multi_source_bfs(G, uris, max_distance) for cat, uris in hazard_true_uris.items()}
# Out:
# Warning: Start node /c/en/haccp not in graph.
# Warning: Start node /c/en/non_compliance not in graph.
# Warning: Start node /c/en/staphylococcal_enterotoxin not in graph.

# %%
categories = hazard_true_subgraphs
classifications_hazards = classify_title_keywords(df, categories, G)

# %%
classifications_hazards

# %%
# Prepare the predictions
formatted_hazards = prepare_predictions(classifications_hazards)
formatted_hazards = sanitize_predictions(formatted_hazards)


print(formatted_hazards)
len(formatted_hazards)
# Out:
# {'Vilis Lamb, Mint and Rosemary Pies 160g': 'Aflatoxin', "'Jackpot Mix' brand of Mix of Pretzels, Sticks and Salted Biscuits recalled": 'incorrect use by dates', '(Updated) Bradbury &amp  Son (Buxton) recalls Lo-Col because milk is not emphasised on the labelling': 'milk and products thereof', '*(Updated on 2 June 2020) Not to consume a batch of bottled apple juice drink contaminated with patulin': 'patulin', '*(Updated on 5 July 2022) Not to consume smoked salmon products with dill possibly contaminated with Listeria monocytogenes': 'listeria monocytogenes', '165368 C. Corporation Recalls Pork Products Due to Possible Listeria Contamination': 'listeria spp', '168 Express Ltd recalls various Jelly products because of a choking hazard': 'other not classified biological hazards', '2006 - Consumer Alert: Listeria Contamination in Raw Milk': 'listeria spp', '2006 - Pinnacle Foods Corporation Issues Allergy Alert on Bakery-Style Chocolate Chip Muffin Mix': 'milk and products thereof', '2006 - Pinnacle Foods Group Inc. Issues Allergy Alert on Undeclared Egg in Frozen': 'eggs and products thereof', '2006 - allergy alert on undeclared almonds in albertsons chocolate ice cream': 'undeclared additive', '2006 - pinnacle foods group inc. issues allergy alert on brownie mix': 'chemical compound (high content)', '2007 - Agriculture Department Warns Consumers of Tainted Raw Milk Sold by Butler County Dairy': 'dairy products', '2007 - WholeSoy & Co. Expands National Allergy Alert on Undeclared Dairy in Blueberry and Mixed Berry Yogurt': 'dairy products', '2007 - Winn-Dixie Stores, Inc. Issues Allergy Alert on Mislabeled Prestige Chocolate Ice Cream': 'milk and products thereof', '2007 - private selection® ice cream recalled from ralphs and food 4 less stores in california': 'dairy products', '2008 - Barry Callebaut USA LLC Issues Allergen Alert on Undeclared Milk Protein in Kroger Value Semi Sweet Chocolate Chips': 'milk and products thereof', "2008 - dreyer's issues voluntary recall of slow churned® light caramel delight and butter pecan ice cream flavors for undeclared pecans": 'pecan nut', '2008 - limited number of aunt jemima pancake & waffle mix products recalled for possible health risk': 'specified risk material (srm)', "2008 - pierre's ice cream company issues allergy alert on its homestyle brand of dutch chocolate ice cream for undeclared peanut butter cup candies": 'undeclared additive', '2008 - private selection ice cream recalled from kroger stores in twelve southeastern states': 'abnormal smell', '2009 - A Manufacturer From England, Cropwell Bishop Creamery Limited, is Conducting a Nationwide Recall on the Cheese Products Blue Stilton and Shropshire Blue Cheese Because of Possible Health Risk': 'specified risk material (srm)', '2009 - Alexia Foods issues nationwide allergy alert and product recall on its Alexia Olive Oil, Sun-Dried Tomatoes & Pesto Oven Reds frozen potatoes due to undeclared pine nut allergen': 'inspection issues', '2009 - BIC Acquisition, LLC Recalls World Classic Trading Company Ultimate Chunk Ice Cream': 'dairy products', '2009 - Bliss Bros. Dairy, Inc. Recalls Ice Cream Products Because of Possible Health Risk': 'dairy products', '2009 - Boca Grande Foods Announces a Nationwide Recall of POCO PAC?, and GRANDE GOURMETT Peanut Butter Products Because of Possible Health Risk': 'specified risk material (srm)', "2009 - Braum's Ice Cream and Dairy Stores Announces Voluntary Recall of its Premium Ice Cream Flavor": 'abnormal smell', '2009 - Bucks Ice Cream Recalls Ice Cream Nut Roll Because of Possible Health Risk': 'specified risk material (srm)', '2009 - Fieldbrook Foods Corp. Announces Nationwide Voluntary Recall of Select Ice Cream Novelty Products Due to Possible Health Risk': 'specified risk material (srm)', '2009 - Fieldbrook Foods Corporation Adds Four Products to Nationwide Voluntary Recall of Select Ice Cream Novelty Products Due to Possible Health Risk': 'specified risk material (srm)', '2009 - Frito-Lay  ...
# 4880

# %%
dataset_path = "/content/food-hazard-detection-semeval-2025.github.io/data/incidents_train.csv"

evaluate_predictions(dataset_path, formatted_hazards, 'hazard')
# Out:
# Evaluation of Hazard Predictions:
#                                                    precision    recall  f1-score   support
#
#                                         Aflatoxin       0.07      0.60      0.12        10
#                                           Unknown       0.00      0.00      0.00         0
#                                    abnormal smell       0.01      0.25      0.02         4
#                                   alcohol content       0.00      0.00      0.00         3
#                                         alkaloids       1.00      0.33      0.50         3
#                                         allergens       0.02      0.33      0.04        12
#                                            almond       0.30      0.38      0.34        64
#              altered organoleptic characteristics       0.00      0.00      0.00         3
#                                         amygdalin       0.00      0.00      0.00         3
#                            antibiotics, vet drugs       0.50      0.33      0.40         6
#                                     bacillus spp.       1.00      0.07      0.13        14
#                              bad smell / off odor       0.00      0.00      0.00         6
#                                     bone fragment       0.05      0.42      0.09        12
#                                        brazil nut       0.00      0.00      0.00         4
#                                 bulging packaging       0.00      0.00      0.00        21
#                                            cashew       0.37      0.24      0.29        29
#                       celery and products thereof       0.25      0.57      0.35         7
#                                           cereals       0.00      0.00      0.00         7
#    cereals containing gluten and products thereof       0.39      0.26      0.31       201
#                                          chemical       0.00      0.00      0.00         5
#                  chemical compound (high content)       0.00      0.00      0.00         8
#                  chemical compound (unauthorised)       0.00      0.00      0.00        11
#                                          chlorine       0.00      0.00      0.00         3
#                             clostridium botulinum       0.25      0.05      0.09        39
#                                           coconut       0.02      0.67      0.03         3
#                                         coliforms       1.00      0.29      0.44         7
#                           compositional deviation       0.00      0.00      0.00         3
#                                       contaminant       0.00      0.00      0.00         3
#                                   cronobacter spp       0.75      0.43      0.55         7
#                  crustaceans and products thereof       1.00      0.18      0.30        17
#                                        cyclospora       0.00      0.00      0.00         9
#                                    dairy products       0.01      0.33      0.01         3
#                                 damaged packaging       0.00      0.00      0.00         7
#                       e 425 - konjac unauthorised       0.00      0.00      0.00        12
#                         eggs and products thereof       0.41      0.54      0.47       208
#                                     enteroviruses       0.00      0.00      0.00         9
#                                  escherichia coli       0.00      0.00      0.00       223
#                            false marketing claims       0.00      0.00      0.00         3
#                         fish and products thereof       0.08      0.29      0.13        38
#                                    foreign bodies       0.00      0.00      0.00        26
#                                    glass fragment       0.00      0.00      0.00        86
#                                         haloxyfop       1.00      0.33      0.50         3
#                                          hazelnut       0.24      0.27      0.25        15
#                                      heavy metals       0.00      0.00      0.00        28
#                            high content of copper       0.00      0.00      0.00         3
#                           high content of cyanide       0.60      0.67      0.63         9
#                          high content of vitamins       0.50      0.25      0.33         4
#                               improper conditions       0.25      0.08      0.12        13
#                                improper packaging       0.00      0.00      0.00         4
#                                incorrect labeling       0.06      0.07      0.06        30
#                            incorrect use by dates       0.11      0.27      0.15        22
#                                           insects       0.94      0.77      0.85        22
#                                 inspection issues       0.38      0.86      0.52        98
#              insufficient labelling/documentation       0.00      0.00      0.00        15
#                          labelling/misdescription       0.00      0.00      0.00        36
#                            listeria monocytogenes       0.99      0.23      0.37       647
#                                      listeria spp       0.00      0.00      0.00         0
#                                    metal fragment       0.73      0.42      0.53       155
#                     microbiological contamination       0.00      0.06      0.01        17
#                         milk and products thereof       0.67      0.44      0.53       578
#                                       misbranding       0.04      0.36      0.07        11
#                                    misdescription       0.00      0.00      0.00        22
#                                       mislabelled       0.00      0.00      0.00         4
#                     molluscs and products thereof       0.00      0.00      0.00         4
#                                            moulds       0.64      0.32      0.43        28
#                      mustard and products thereof       0.51      0.60      0.55        48
#                                          nitrogen       1.00      0.33      0.50         3
#                         non compliance with HACCP       0.00      0.00      0.00         4
#                                         norovirus       0.00      0.00      0.00        20
#                                        novel food       0.17      0.25      0.20         4
#                                              nuts       0.10      0.11      0.11        28
#                                        ochratoxin       1.00      1.00      1.00         3
#                                    organochlorine       0.00      0.00      0.00         3
#                                             other       0.00      0.00      0.00       100
#                          other misbranding issues       0.00      0.00      0.00         3
#                              other not classified       0.00      0.00      0.00        32
#             other not classified allergen hazards       0.00      0.00      0.00         3
#           other not classified biological hazards       0.00      0.00      0.00        13
#             other not classified chemical hazards       0.00      0.00      0.00        22
#   other not classified hazards for foreign bodies       0.00      0.00      0.00         8
#                                  packaging defect       0.00      0.00      0.00        22
#                                              pahs       0.00      0.00      0.00         4
#        paralytic shellfish poisoning (psp) toxins       0.33      0.67      0.44         3
#                               pathogenic bacteria       0.00      0.00      0.00         7
#                                           patulin       1.00      0.50      0.67        10
#                      peanuts and products thereof       0.78      0.17      0.28       209
#                                         pecan nut       0.25      0.06      0.10        16
#                                    phenylpyrazole       0.00      0.00      0.00         3
#                                    pieces of wood       0.04      0.50      0.07         4
#                                     pistachio nut       0.09      0.25      0.13         8
#                                  plastic fragment       0.91      0.22      0.36       194
#                  polycyclic aromatic hydrocarbons       0.00      0.00      0.00         4
#                               poor hygienic state       0.00      0.00      0.00         6
#                     poor or insufficient controls       0.00      0.00      0.00        12
#                                        processing       0.00      0.00      0.00        38
#                  product category/characteristics       0.00      0.00      0.00         3
#                                  pseudomonas spp.       0.00      0.00      0.00         5
#                                  rubber fragments       0.36      0.14      0.21        28
#                                        salmonella       0.99      0.30      0.46       610
#                 sesame seeds and products thereof       0.35      0.45      0.39        38
#                     soybeans and products thereof       1.00      0.01      0.01       169
#                     specified risk material (srm)       0.01      0.33      0.01         6
#                                          spoilage       0.89      0.28      0.42        29
#                        staphylococcal enterotoxin       0.00      0.00      0.00         3
#                                    staphylococcus       0.00      0.00      0.00         9
#                                            stones       0.00      0.00      0.00         7
#                       sulfamethazine unauthorised       0.00      0.00      0.00         1
#                               sulphates/sulphites       0.00      0.00      0.00         9
#                                   sulphur dioxide       0.50      0.12      0.20        16
#                     sulphur dioxide and sulphites       0.83      0.22      0.34        93
#                                         tampering       0.00      0.00      0.00         3
#                                 taste disturbance       0.06      0.33      0.10         6
# too high content of fluorinated organic chemicals       0.00      0.00      0.00         3
#    too high content of tetrahydrocannabinol (THC)       0.83      0.71      0.77         7
#                                             toxin       0.00      0.00      0.00        21
#                       unauthorised colour sudan 4       0.11      0.25      0.15         4
#                               unauthorised import       0.14      0.14      0.14         7
#                             unauthorised operator       0.00      0.00      0.00         3
#                unauthorised placing on the market       0.00      0.00      0.00         6
#             unauthorised substance ethylene oxide       1.00      0.06      0.11        51
#                 unauthorised substance sildenafil       0.80      1.00      0.89         4
#                               undeclared additive       0.02      0.27      0.04        11
#                            undeclared constituent       0.00      0.00      0.00         6
#                       unfit for human consumption       0.33      0.33      0.33         3
#                                        vibrio spp       0.00      0.00      0.00         3
#                                             virus       0.00      0.00      0.00         4
#                                            walnut       0.00      0.00      0.00        32
#                                            yeasts       0.00      0.00      0.00         4
#
#                                          accuracy                           0.25      4945
#                                         macro avg       0.23      0.17      0.15      4945
#                                      weighted avg       0.58      0.25      0.30      4945
#
#
# Full results saved to 'predictions_vs_truth_hazard.csv'

# %% [markdown]
# # Products

# %%
json_file_path = '/content/extracted_keywords_products.json'
with open(json_file_path, 'r') as file:
    data = json.load(file)

df_4 = pd.DataFrame(list(data.items()), columns=['product', 'extracted_terms'])
products_true = dict(zip(df_4['product'], df_4['extracted_terms']))

print(products_true)
# Out:
# {'Catfishes (freshwater)': ['catfish', 'freshwater'], 'Dried pork meat': ['meat', 'dried'], 'Fishes not identified': ['identify', 'fishes'], 'Groupers (generic)': ['groupers', 'generic'], 'Not classified pork meat': ['meat', 'pork'], 'Pangas catfishes (generic)': ['catfish', 'pangas'], 'Precooked cooked pork meat products': ['cook', 'cooked', 'products', 'meat', 'pork'], 'Torpedo-shaped catfishes (generic)': ['catfishes', 'generic'], 'Veggie Burger': ['veggie', 'burger'], 'adobo seasoning': ['adobo'], 'after dinner mints': ['mints', 'dinner'], 'alcoholic beverages': ['alcoholic beverages', 'alcoholic', 'beverages'], 'alfalfa sprouts': ['alfalfa', 'sprouts'], 'all purpose seasoning': ['purpose'], 'allspice': ['allspice'], 'almond kernels': ['almond', 'kernels'], 'almond milk': ['almond', 'milk'], 'almond powder': ['almond', 'powder'], 'almond products': ['almond', 'products'], 'almonds': ['almonds', 'almond'], 'amaranth': ['amaranth'], 'anchovies in oil': ['oil', 'anchovy'], 'anchovy paste': [], 'angus beef': ['angus', 'beef'], 'animal by-products': ['animal'], 'appetizers': ['appetizers'], 'apple cake': ['apple', 'cake'], 'apple juice': ['apple', 'juice'], 'apples': ['apple'], 'apricot kernels': ['apricot', 'kernel'], 'apricots': ['apricot', 'apricots'], 'assorted bread roll selection': ['assorted', 'bread', 'roll', 'selection'], 'assortment of filled chocolates': ['assortment', 'filled', 'chocolates'], 'baby food pouches': ['food', 'pouches', 'baby'], 'baby food': ['baby', 'food'], 'baby foods': ['baby foods', 'baby food', 'foods'], 'baby spinach': ['baby', 'spinach'], 'bagels': ['bagel', 'bagels'], 'baguettes': ['baguette', 'baguettes'], 'bakery products': ['bakery', 'products'], 'baking mix': ['baking mix'], 'baklava': ['baklava'], 'balsamic': ['balsamic'], 'bamboo shoots': ['bamboo shoots', 'bamboo', 'shoot'], 'bamboo': ['bamboo'], 'bananas': ['bananas'], 'barbecue sauce': ['barbecue', 'sauce'], 'bars': ['bars'], 'basil pesto sauce': ['basil', 'pesto', 'sauce'], 'basil': ['basil'], 'batter mix': ['batter', 'mix'], 'bean paste': ['bean', 'paste'], 'bean sauce': ['bean', 'sauce'], 'bean snack': ['bean', 'snack'], 'bean sprouts': ['bean sprouts', 'bean sprout', 'sprouts', 'sprout'], 'beans': ['beans'], 'beef burrito': ['beef', 'burrito'], 'beef meat': ['beef', 'meat'], 'beef products': ['beef', 'products'], 'beef stewed': ['beef', 'stewed'], 'beef tallow': ['beef', 'tallow'], 'beef tenderloin cuts': ['beef', 'tenderloin', 'cuts'], 'beef tongue': ['beef', 'tongue'], 'beef trimmings': ['beef', 'trimmings'], 'beef': ['beef'], 'beer': ['beer'], 'beetroots': ['beetroot', 'beetroots'], 'beverage base of non-fruit origin, liquid': ['base', 'origin', 'beverage'], 'beverage': ['beverage'], 'bilberry extract used in a food supplement': ['food', 'supplement', 'extract'], 'biscuit mix': ['biscuit'], 'biscuits': ['biscuits'], 'bitter apricot kernels': ['apricot', 'kernel'], 'black caviar': ['caviar', 'black'], 'black pepper': ['black pepper', 'pepper'], 'blackberries': ['blackberries', 'blackberry'], 'blackcurrant drink concentrate': ['blackcurrant', 'drink', 'concentrate'], 'bloody mary beverage mix': ['mary', 'mix', 'beverage'], 'blue cheese': ['blue', 'cheese'], 'blue poppy seeds': ['blue', 'poppy', 'seeds'], 'blueberries': ['blueberries'], 'boar': ['boar'], 'boletus mushrooms, stems and pieces': ['mushrooms', 'pieces'], 'bolognese sauce': ['bolognese sauce', 'sauce'], 'boneless beef': ['beef'], 'bottled mineral water': ['mineral water', 'bottled'], 'bottled water': ['bottled', 'water'], 'bovine fat': ['fat'], 'bovine meat and offal': ['meat', 'offal'], 'brazil nuts': ['brazil nuts'], 'bread and products therefor': ['bread', 'products'], 'bread crumb': ['bread', 'crumb'], 'bread mix': ['bread', 'mix'], 'bread': ['bread'], 'breakfast cereals and products therefor': ['cereals', 'breakfast', 'cereal', 'product', 'products'], 'breakfast cereals for babies': ['cereals', 'babies', 'breakfast'], 'breakfast cereals': ['cereals', 'breakfast'],  ...

# %%
products_true = clean_categories(products_true, to_remove)
products_true
# Out:
# {'Catfishes (freshwater)': ['catfish', 'freshwater'],
#  'Dried pork meat': ['meat', 'dried'],
#  'Fishes not identified': ['identify', 'fishes'],
#  'Groupers (generic)': ['groupers', 'generic'],
#  'Not classified pork meat': ['meat', 'pork'],
#  'Pangas catfishes (generic)': ['catfish', 'pangas'],
#  'Precooked cooked pork meat products': ['cook', 'cooked', 'meat', 'pork'],
#  'Torpedo-shaped catfishes (generic)': ['catfishes', 'generic'],
#  'Veggie Burger': ['veggie', 'burger'],
#  'adobo seasoning': ['adobo'],
#  'after dinner mints': ['mints', 'dinner'],
#  'alcoholic beverages': ['alcoholic beverages', 'alcoholic'],
#  'alfalfa sprouts': ['alfalfa', 'sprouts'],
#  'all purpose seasoning': ['purpose'],
#  'allspice': ['allspice'],
#  'almond kernels': ['almond', 'kernels'],
#  'almond milk': ['almond', 'milk'],
#  'almond powder': ['almond', 'powder'],
#  'almond products': ['almond'],
#  'almonds': ['almonds', 'almond'],
#  'amaranth': ['amaranth'],
#  'anchovies in oil': ['oil', 'anchovy'],
#  'angus beef': ['angus', 'beef'],
#  'animal by-products': ['animal'],
#  'appetizers': ['appetizers'],
#  'apple cake': ['apple', 'cake'],
#  'apple juice': ['apple', 'juice'],
#  'apples': ['apple'],
#  'apricot kernels': ['apricot', 'kernel'],
#  'apricots': ['apricot', 'apricots'],
#  'assorted bread roll selection': ['assorted', 'bread', 'roll', 'selection'],
#  'assortment of filled chocolates': ['assortment', 'filled', 'chocolates'],
#  'baby food pouches': ['pouches', 'baby'],
#  'baby food': ['baby'],
#  'baby foods': ['baby foods', 'baby food', 'foods'],
#  'baby spinach': ['baby', 'spinach'],
#  'bagels': ['bagel', 'bagels'],
#  'baguettes': ['baguette', 'baguettes'],
#  'bakery products': ['bakery'],
#  'baking mix': ['baking mix'],
#  'baklava': ['baklava'],
#  'balsamic': ['balsamic'],
#  'bamboo shoots': ['bamboo shoots', 'bamboo', 'shoot'],
#  'bamboo': ['bamboo'],
#  'bananas': ['bananas'],
#  'barbecue sauce': ['barbecue', 'sauce'],
#  'bars': ['bars'],
#  'basil pesto sauce': ['basil', 'pesto', 'sauce'],
#  'basil': ['basil'],
#  'batter mix': ['batter'],
#  'bean paste': ['bean', 'paste'],
#  'bean sauce': ['bean', 'sauce'],
#  'bean snack': ['bean', 'snack'],
#  'bean sprouts': ['bean sprouts', 'bean sprout', 'sprouts', 'sprout'],
#  'beans': ['beans'],
#  'beef burrito': ['beef', 'burrito'],
#  'beef meat': ['beef', 'meat'],
#  'beef products': ['beef'],
#  'beef stewed': ['beef', 'stewed'],
#  'beef tallow': ['beef', 'tallow'],
#  'beef tenderloin cuts': ['beef', 'tenderloin', 'cuts'],
#  'beef tongue': ['beef', 'tongue'],
#  'beef trimmings': ['beef', 'trimmings'],
#  'beef': ['beef'],
#  'beer': ['beer'],
#  'beetroots': ['beetroot', 'beetroots'],
#  'beverage base of non-fruit origin, liquid': ['base', 'origin'],
#  'bilberry extract used in a food supplement': ['supplement', 'extract'],
#  'biscuit mix': ['biscuit'],
#  'biscuits': ['biscuits'],
#  'bitter apricot kernels': ['apricot', 'kernel'],
#  'black caviar': ['caviar', 'black'],
#  'black pepper': ['black pepper', 'pepper'],
#  'blackberries': ['blackberries', 'blackberry'],
#  'blackcurrant drink concentrate': ['blackcurrant', 'drink', 'concentrate'],
#  'bloody mary beverage mix': ['mary'],
#  'blue cheese': ['blue', 'cheese'],
#  'blue poppy seeds': ['blue', 'poppy', 'seeds'],
#  'blueberries': ['blueberries'],
#  'boar': ['boar'],
#  'boletus mushrooms, stems and pieces': ['mushrooms', 'pieces'],
#  'bolognese sauce': ['bolognese sauce', 'sauce'],
#  'boneless beef': ['beef'],
#  'bottled mineral water': ['mineral water', 'bottled'],
#  'bottled water': ['bottled', 'water'],
#  'bovine fat': ['fat'],
#  'bovine meat and offal': ['meat', 'offal'],
#  'brazil nuts': ['brazil nuts'],
#  'bread and products therefor': ['bread'],
#  'bread crumb': ['bread', 'crumb'],
#  'bread mix': ['bread'],
#  'bread': ['bread'],
#  'breakfast cereals and products therefor': ['cereals', 'breakfast', 'cereal'],
#  'breakfast cereals for babies': ['cereals', 'babies', 'breakfast'],
#  'breakfast cereals': ['cereals', 'breakfast'],
#  "brewer's yeast": ['brewer', 'yeast'],
#  'brie cheese': ['brie', 'cheese'],
#  'brioche': ['brioche'],
#  'broccoli mix': ['broccoli'],
#  'broccoli': ['broccoli'],
#  'broths': ['broth', 'broths'],
#  'brown beans': ['beans', 'brown'],
#  'brown mushrooms': ['mushrooms', 'brown'],
#  'brown rice': ['brown', 'rice'],
#  'brownies': ['brownie', 'brownies'],
#  'brussel sprouts': ['brussel sprouts', 'sprouts'],
#  'buffalo milk mozzarella cheese': ['buffalo', 'mozzarella', 'cheese'],
#  'buns': ['buns'],
#  'burrata': ['burrata'],
#  'burrito (ready to eat)': ['burrito', 'eat'],
#  'butter': ['butter'],
#  'cabbage': ['cabbage'],
#  'cake decoration': ['decoration', 'cake'],
#  'cakes': ['cakes'],
#  'camembert': ['camembert'],
#  'candies': ['candies'],
#  'canned artichoke hearts': ['artichoke', 'hearts'],
#  'canned black beans': ['black beans', 'beans'],
#  'canned chicken': ['chicken'],
#  'canned corn': ['corn'],
#  'canned crab meat in brine': ['crab', 'meat', 'brine'],
#  'canned fish products': ['fish'],
#  'canned meat stew': ['stew', 'meat'],
#  'canned mussels': ['mussels'],
#  'canned spinach': ['spinach'],
#  'cantaloupe (fresh)': ['cantaloupe'],
#  'caramel bites': ['bites', 'caramel'],
#  'carbonated  water': ['carbonated', 'water'],
#  'carbonated beverage': ['carbonated'],
#  'carcasses of veal': ['carcass', 'veal'],
#  'cardamom seeds': ['cardamom', 'seeds'],
#  'cardamon seeds': ['cardamon', 'seeds'],
#  'carps, barbels and other cyprinids': ['carps', 'barbels'],
#  'cashew': ['cashew'],
#  'cattle from which the milk was used to produce raw milk cheese': ['cattle',
#   'milk',
#   'cheese'],
#  'cauliflower': ['cauliflower'],
#  'cbd oil': ['oil', 'cbd'],
#  'cereal bars with chocolate': ['cereal bars', 'chocolate'],
#  'cereal bars': ['cereal bars', 'bars', 'cereal'],
#  'cereal drink': ['cereal', 'drink'],
#  'cereal': ['cereal'],
#  'cereals and bakery products': ['bakery', 'cereals'],
#  'cereals': ['cereals'],
#  'cheddar cheese': ['cheddar', 'cheese'],
#  'cheese (taleggio capriolo)': ['cheese', 'taleggio'],
#  'cheese - made from raw milk': ['cheese', 'made', 'milk', 'raw milk'],
#  'cheese - melted': ['cheese'],
#  'cheese burgers': ['cheese'],
#  'cheese dip': ['cheese', 'dip'],
#  'cheese flavoured snacks': ['cheese', 'flavoured', 'snacks'],
#  'cheese products': ['cheese'],
#  'cheese sausages': ['cheese', 'sausages'],
#  'cheese spread': ['cheese spread'],
#  'cheese tortilla': ['cheese', 'tortilla'],
#  'cheese tray': ['cheese', 'tray'],
#  'cheese': ['cheese'],
#  'cheesy spirals': ['cheesy', 'spirals'],
#  'cherries': ['cherries'],
#  'chia seeds': ['chia', 'seeds'],
#  'chicken and chicken preparations': ['chicken', 'preparations'],
#  'chicken based products': ['chicken', 'based'],
#  'chicken breast': ['breast', 'chicken'],
#  'chicken broth': ['chicken', 'broth'],
#  'chicken dippers': ['chicken', 'dippers'],
#  'chicken drumsticks': ['chicken', 'drumsticks'],
#  'chicken fillets': ['chicken fillets', 'chicken', 'fillets', 'fillet'],
#  'chicken meat meal': ['chicken', 'meat'],
#  'chicken meat products': ['chicken', 'meat'],
#  'chicken noodle soup': ['chicken', 'noodle', 'soup'],
#  'chicken pie': ['chicken', 'pie'],
#  'chicken preparations': ['chicken', 'preparations'],
#  'chicken products - frozen': ['chicken', 'frozen'],
#  'chicken slices': ['chicken', 'slices'],
#  'chicken steak without bone': ['steak', 'chicken'],
#  'chicken': ['chicken'],
#  'chickpeas': ['chickpeas'],
#  'chilled beef preparations': ['chilled', 'beef', 'preparations'],
#  'chilled beef': ['chilled', 'beef'],
#  'chilled bengali cod curry': ['bengali', 'cod', 'curry', 'chilled'],
#  'chilled boneless pork meat': ['meat', 'pork', 'boneless', 'chilled'],
#  'chilled chicken parts': ['chilled', 'chicken', 'parts'],
#  'chilled chicken thighs': ['chilled', 'chicken', 'thighs'],
#  'chilled chicken wings': ['chilled', 'chicken', 'wings'],
#  'chilled chicken': ['chilled', 'chicken'],
#  'chilled dumplings with meat': ['dumplings', 'meat'],
#  'chilled lasagne': ['chilled', 'lasagne'],
#  'chilled pork ribs': ['ribs', 'chilled', 'pork'],
#  'chilled pork sausages': ['sausages', 'chilled', 'pork'],
#  'chilled pork': ['chilled', 'pork'],
#  'chilled ready to eat salad and side dishes': ['salad', 'side dishes'],
#  'chilled salads': ['chilled', 'salads'],
#  'chilled smoked ham': ['ham', 'smoked ham', 'chilled'],
#  'chilled vacuum packed beef': ['beef', 'chilled', 'vacuum', 'packed'],
#  'chilli oil': ['chilli', 'oil'],
#  'chilli paste': ['chilli', 'paste'],
#  'chilli peppers': ['chilli peppers', 'peppers'],
#  'chilli pickle': ['chilli', 'pickle'],
#  'chilli powder': ['chilli', 'powder'],
#  'chilli sauce': ['chilli', 'sauce'],
#  'chilli': ['chilli'],
#  'chillies': ['chillies', 'chilli'],
#  'chocolate and chocolate products': ['chocolate'],
#  'chocolate and hazelnut spread': ['chocolate', 'hazelnut'],
#  'chocolate and products therefor': ['chocolate'],
#  'chocolate and strawberry flavoured cyclone milk': ['chocolate',
#   'strawberry',
#   'flavoured',
#   'milk'],
#  'chocolate bars': ['chocolate bars', 'chocolate bar', 'chocolate'],
#  'chocolate chips': ['chocolate', 'chips'],
#  'chocolate confectionery': ['chocolate', 'confectionery'],
#  'chocolate dessert': ['chocolate', 'dessert'],
#  'chocolate drink powder': ['chocolate', 'drink', 'powder'],
#  'chocolate drinks': ['chocolate', 'drinks'],
#  'chocolate easter eggs with filling': ['easter eggs',
#   'chocolate',
#   'easter egg'],
#  'chocolate eggs': ['chocolate eggs', 'eggs', 'chocolate'],
#  'chocolate flavoured cereals': ['chocolate',
#   'flavoured',
#   'cereal',
#   'cereals'],
#  'chocolate flavoured meringues': ['chocolate', 'meringue'],
#  'chocolate mini muffins': ['chocolate', 'muffins'],
#  'chocolate mousse': ['chocolate', 'mousse'],
#  'chocolate products': ['chocolate'],
#  'chocolate spelt balls': ['chocolate', 'balls'],
#  'chocolate spread with hazelnuts': ['chocolate', 'hazelnuts'],
#  'chocolate spread': ['chocolate', 'spread'],
#  'chocolate truffles': ['chocolate truffles',
#   'chocolate',
#   'truffles',
#   'truffle'],
#  'chocolate wafers': ['chocolate', 'wafers'],
#  'chocolate': ['chocolate'],
#  'chocolates': ['chocolate', 'chocolates'],
#  'chorizo sausage': ['chorizo', 'sausage'],
#  'chorizo': ['chorizo'],
#  'cider': ['cider'],
#  'cinnamon rolls': ['cinnamon', 'roll', 'rolls'],
#  'cinnamon': ['cinnamon'],
#  'clams (canned)': ['clams'],
#  'clams': ['clam', 'clams'],
#  'cocktail sausage rolls': ['cocktail', 'sausage', 'rolls'],
#  'coconut drink': ['coconut', 'drink'],
#  'coconut juice': ['coconut', 'juice'],
#  'coconut milk drink': ['drink'],
#  'coconut milk': ['coconut', 'milk'],
#  'coconut oil': ['coconut oil'],
#  'coconut sugar': ['coconut', 'sugar'],
#  'coconuts': ['coconuts'],
#  'cod fillets': ['cod', 'fillets'],
#  'cod': ['cod'],
#  'coffee beans': ['coffee', 'beans'],
#  'coffee drink': ['coffee', 'drink'],
#  'cola drink': ['cola', 'drink'],
#  'colours': ['colour', 'colours'],
#  'concentrated apples': ['concentrated', 'apples'],
#  'confectionery for decoration': ['decoration'],
#  'cooked chicken skewer': ['chicken', 'cooked', 'skewer'],
#  'cooked chicken': ['cooked', 'chicken'],
#  'cooked ham': ['ham', 'cooked'],
#  'cooked meat products': ['cooked', 'meat'],
#  'cooked sausages': ['cooked', 'sausages'],
#  'cooking sauce': ['sauce'],
#  'coriander': ['coriander'],
#  'corn': ['corn'],
#  'cottage cheese': ['cottage cheese', 'cheese'],
#  'cottage pie': ['cottage pie', 'pie'],
#  'courgettes': ['courgettes'],
#  'cow milk cheese': ['cow', 'milk', 'cheese'],
#  'crabs': ['crabs'],
#  'crackers': ['crackers'],
#  'cranberry jam': ['cranberry', 'jam'],
#  'cranberry juice': ['cranberry', 'juice'],
#  'cream cheese': ['cream', 'cheese'],
#  'cream chocolate pie': ['cream', 'chocolate', 'pie'],
#  'crepe mix': ['crepe'],
#  'crisp cheese snack': ['snack', 'crisp', 'cheese'],
#  'crispbread': ['crispbread'],
#  'crisps': ['crisps'],
#  'croissants': ['croissant', 'croissants'],
#  'crustaceans and products thereof': ['crustaceans'],
#  'cultivated fungi': ['cultivated', 'fungi'],
#  'cumin powder': ['cumin', 'powder'],
#  'cupcakes': ['cupcake', 'cupcakes'],
#  'curd cheese': ['curd', 'cheese'],
#  'cured loin': ['cured', 'loin'],
#  'cured pork meat': ['cured', 'pork', 'meat'],
#  'cured smoked ham': ['cured', 'smoked', 'ham'],
#  'curry paste': ['curry paste'],
#  'curry sauces': ['curry', 'sauces'],
#  'curry': ['curry'],
#  'custard': ['custard'],
#  'cuttlefish': ['cuttlefish'],
#  'dark chocolate coated almonds': ['dark chocolate', 'almonds'],
#  'dark chocolates': ['dark chocolates', 'dark chocolate', 'chocolate'],
#  'dates': ['date', 'dates'],
#  'deboned chicken thighs': ['chicken', 'deboned', 'thighs'],
#  'desserts': ['dessert', 'desserts'],
#  'diced beef': ['beef', 'diced'],
#  'dietary capsules': ['capsules', 'dietary'],
#  'dietary supplement': ['dietary', 'supplement'],
#  'dietetic foods, food supplements, fortified foods': ['fortified foods',
#   'food supplements'],
#  'dipping sauce': ['dipping sauce', 'dipping', 'sauce'],
#  'donuts': ['donut', 'donuts'],
#  'dressing sauces': ['sauces'],
#  'dried almonds': ['almonds', 'dried'],
#  'dried anchovies': ['anchovy', 'anchovies'],
#  'dried apples': ['apples', 'apple'],
#  'dried apricots': ['apricot', 'apricots'],
#  'dried beans': ['beans', 'bean'],
#  'dried beef meat': ['meat', 'dried'],
#  'dried brown beans': ['beans', 'brown', 'dried'],
#  'dried chilli peppers': ['dried', 'chilli', 'pepper'],
#  'dried coconut': ['coconut', 'dried'],
#  'dried cranberries': ['cranberries', 'cranberry'],
#  'dried elder berries': ['dried', 'berry', 'berries'],
#  'dried figs': ['dried', 'figs'],
#  'dried fruit in jars': ['dried', 'fruit', 'jar'],
#  'dried fruit mix': ['dried'],
#  'dried fruits with chocolate': ['chocolate', 'fruits'],
#  'dried fruits': ['dried fruits', 'dried', 'dry'],
#  'dried garlic': ['garlic', 'dried'],
#  'dried herb powder ashwagandha (withania somnifera)': ['ashwagandha',
#   'withania',
#   'herb',
#   'powder'],
#  'dried lilies': ['lily', 'lilies'],
#  'dried mushrooms': ['mushrooms', 'dried'],
#  'dried pangash': ['dried'],
#  'dried plums': ['plum', 'plums', 'dried'],
#  'dried pork sausages': ['sausages', 'pork'],
#  'dried sausage': ['dried sausage', 'sausage'],
#  'dried shitake mushrooms (lentinula edodes)': ['mushroom',
#   'mushrooms',
#   'shitake',
#   'dried',
#   'dry'],
#  'dried shrimp noodles': ['shrimp', 'dried', 'noodles'],
#  'dried strawberries': ['strawberries', 'dried'],
#  'drink powder': ['drink', 'powder'],
#  'drinking chocolate powder': ['chocolate', 'drinking'],
#  'dry ham': ['ham'],
#  'dry sausage': ['sausage'],
#  'duck': ['duck'],
#  'dumplings': ['dumplings'],
#  'edam cheese': ['edam', 'cheese'],
#  'egg products': ['egg'],
#  'egg rolls': ['egg', 'roll', 'rolls'],
#  'egg salad with ham': ['ham', 'egg salad'],
#  'eggplants': ['eggplant', 'eggplants'],
#  'eggs and egg products': ['eggs', 'egg', 'egg products'],
#  'eggs': ['egg', 'eggs'],
#  'emulsifiers, stabilizers, thickeners and gelling agents': ['emulsifiers',
#   'stabilizers',
#   'thickeners',
#   'gelling agents'],
#  'energy and protein bars': ['protein bars', 'energy', 'protein'],
#  'energy drink': ['energy', 'drink'],
#  'fajita meal': ['fajita', 'meal'],
#  'fats and oils': ['fats', 'oils'],
#  'feed materials': ['material'],
#  'fennel seeds': ['fennel', 'seeds'],
#  'fermented beef meat': ['beef', 'meat', 'fermented'],
#  'fermented milk product': ['fermented', 'milk'],
#  'feta cheese': ['feta', 'cheese'],
#  'filled chocolate': ['filled', 'chocolate'],
#  'fish and fish products': ['fish'],
#  'fish products': ['fish'],
#  'fish roe': ['fish', 'roe'],
#  'fish sauce': ['fish', 'sauce'],
#  'flavoured drinks': ['flavoured', 'drinks'],
#  'flavoured fresh and creamy cheese spread': ['flavoured',
#   'fresh',
#   'creamy',
#   'cheese',
#   'spread'],
#  'flavoured milk': ['flavoured', 'milk'],
#  'flavoured potato chips': ['flavoured', 'potato', 'chips'],
#  'flavoured soft drink': ['flavoured', 'soft drink'],
#  'flavoured whey protein preparations': ['flavoured',
#   'whey',
#   'protein',
#   'preparations'],
#  'flavours': ['flavours'],
#  'flaxseed': ['flaxseed'],
#  'flounders, halibuts, soles': ['halibuts', 'flounders', 'soles'],
#  'flour': ['flour'],
#  'food supplement': ['supplement'],
#  'french beans / green beans': ['green beans', 'french beans'],
#  'french toast': ['french toast', 'toast'],
#  'fresh apples': ['apples', 'fresh'],
#  'fresh beef meat': ['beef', 'meat'],
#  'fresh beef': ['beef'],
#  'fresh broccoli': ['broccoli'],
#  'fresh cheese': ['cheese'],
#  'fresh cut vegetables': ['fresh', 'cut', 'vegetables'],
#  'fresh dough': ['dough'],
#  'fresh goat cheese': ['cheese', 'goat'],
#  'fresh lychees': ['lychees', 'fresh'],
#  'fresh mushrooms': ['mushrooms', 'fresh'],
#  'fresh parsley': ['parsley', 'fresh'],
#  'fresh pork leg': ['pork', 'leg'],
#  'fresh pork loin': ['pork loin', 'loin', 'pork'],
#  'fresh pork': ['pork'],
#  'fresh poultry and poultry prepations': ['poultry', 'fresh'],
#  'fresh processed beef meat products': ['beef', 'meat', 'processed', 'fresh'],
#  'fresh vegetables': ['vegetables', 'fresh'],
#  'frozen beef lasagne': ['beef', 'lasagne'],
#  'frozen beef patties': ['beef', 'patties'],
#  'frozen beef products': ['frozen', 'beef'],
#  'frozen beef tongue': ['beef', 'tongue'],
#  'frozen beef trimmings': ['beef', 'frozen'],
#  'frozen beef': ['beef'],
#  'frozen berries mix': ['berries', 'frozen'],
#  'frozen boneless beef': ['beef'],
#  'frozen bourbon ribs': ['bourbon', 'ribs'],
#  'frozen breaded turkey': ['turkey', 'frozen'],
#  'frozen broccoli': ['broccoli', 'frozen'],
#  'frozen burger buns': ['burger', 'buns'],
#  'frozen burgers': ['frozen'],
#  'frozen chicken strips with tendons': ['chicken', 'strips', 'frozen'],
#  'frozen chicken wings': ['chicken wings', 'frozen'],
#  'frozen chicken': ['chicken', 'frozen'],
#  'frozen cod fillets': ['cod', 'frozen'],
#  'frozen cooked lobster meat': ['frozen', 'cooked', 'meat'],
#  'frozen diced chicken roast': ['chicken', 'roast'],
#  'frozen dumplings with pork': ['pork', 'dumplings'],
#  'frozen fish burgers': ['fish', 'frozen'],
#  'frozen fish fillets': ['fish', 'fillets', 'frozen'],
#  'frozen fish products': ['fish', 'frozen'],
#  'frozen fried rice': ['fry', 'fried', 'rice'],
#  'frozen grated coconut': ['coconut', 'frozen'],
#  'frozen green beans': ['beans', 'green beans', 'frozen'],
#  'frozen hamburgers': ['hamburgers', 'frozen'],
#  'frozen hash browns': ['frozen', 'hash browns'],
#  'frozen leek': ['leek', 'frozen'],
#  'frozen lobster': ['lobster', 'frozen'],
#  'frozen marinated beef': ['marinated', 'beef'],
#  'frozen marinated chicken': ['marinated', 'frozen'],
#  'frozen pancakes': ['frozen', 'pancakes'],
#  'frozen peas': ['frozen', 'peas'],
#  'frozen peppers': ['peppers', 'frozen'],
#  'frozen pie': ['pie'],
#  'frozen pizza': ['frozen', 'pizza'],
#  'frozen pork meat': ['frozen', 'pork'],
#  'frozen pork preparations': ['preparations', 'pork', 'frozen'],
#  'frozen pork ribs': ['pork ribs', 'frozen'],
#  'frozen pork trimmings': ['frozen', 'pork'],
#  'frozen potatoes': ['potatoes', 'frozen'],
#  'frozen poultry meat': ['frozen', 'poultry', 'meat'],
#  'frozen poultry preparations': ['frozen', 'poultry', 'preparations'],
#  'frozen poultry products': ['frozen', 'poultry'],
#  'frozen poultry': ['frozen', 'poultry'],
#  'frozen prepared dish of chicken tikka masala with pilau rice': ['chicken',
#   'masala',
#   'pilau',
#   'rice'],
#  'frozen raw ground beef': ['beef', 'frozen'],
#  'frozen ready to cook chicken': ['chicken', 'frozen', 'cook'],
#  'frozen ready to eat products': ['frozen', 'ready'],
#  'frozen sausage rolls': ['frozen', 'sausage', 'rolls'],
#  'frozen sausages': ['sausages', 'frozen'],
#  'frozen seafood': ['seafood', 'frozen'],
#  'frozen seasoned potato wedges': ['potato', 'frozen', 'wedge'],
#  'frozen sliced coconut': ['frozen', 'sliced', 'coconut'],
#  'frozen spicy chicken wings': ['spicy', 'frozen', 'chicken', 'wings'],
#  'frozen spinach': ['spinach', 'frozen'],
#  'frozen spring rolls': ['frozen', 'spring', 'roll'],
#  'frozen strawberry': ['strawberry', 'frozen'],
#  'frozen vegetables mix': ['vegetables'],
#  'frozen vegetables': ['vegetables', 'frozen vegetables'],
#  'frozen vegetarian cutlet': ['vegetarian', 'cutlet'],
#  'frozen whole fish': ['whole', 'frozen'],
#  'fruit bars': ['fruit', 'bars'],
#  'fruit juice smoothie': ['fruit', 'juice', 'smoothie'],
#  'fruit juice': ['fruit', 'juice'],
#  'fruit mix': ['fruit'],
#  'fruit pies': ['fruit', 'pies'],
#  'fruit punch': ['fruit', 'punch'],
#  'fruit salad with cantaloupe': ['fruit', 'salad', 'cantaloupe'],
#  'fruit salad': ['fruit', 'salad'],
#  'fruit snacks': ['fruit', 'snacks'],
#  'fruits and vegetables': ['fruits', 'vegetables'],
#  'garlic pickle': ['pickle', 'garlic'],
#  'garlic powder': ['garlic', 'powder'],
#  'garlic sausage': ['garlic', 'sausage'],
#  'ginger powder': ['ginger', 'powder'],
#  'ginger slices': ['ginger', 'slices'],
#  'gingerbread': ['gingerbread'],
#  'ginseng powder': ['ginseng', 'powder'],
#  'gluten free bread': ['bread', 'gluten'],
#  'gnocchi': ['gnocchi'],
#  'goat cheese made from raw milk': ['goat', 'cheese', 'raw milk'],
#  'goat cheese': ['goat', 'cheese'],
#  'goat meat': ['goat', 'meat'],
#  'goat milk': ['goat', 'milk'],
#  'goji berries': ['goji', 'berries'],
#  'golden enoki mushrooms': ['enoki', 'mushrooms', 'golden'],
#  'golden raisins/sultanas': ['golden'],
#  'gorgonzola cheese': ['gorgonzola', 'cheese'],
#  'gouda cheese': ['gouda', 'cheese'],
#  'gouda': ['gouda'],
#  'granola': ['granola'],
#  'grapes': ['grapes'],
#  'grated cheese mixture': ['grate', 'grated', 'cheese', 'mixture'],
#  'grated cheese': ['grated', 'cheese'],
#  'grated coconut': ['coconut', 'grated'],
#  'gravy granules': ['gravy', 'granules'],
#  'gravy mix': ['gravy'],
#  'green basil pesto': ['pesto', 'basil'],
#  'green bean': ['green', 'green bean', 'bean'],
#  'green pesto basil sauce': ['pesto', 'basil', 'green'],
#  'green pesto': ['green', 'pesto'],
#  'green raisins': ['raisin', 'green'],
#  'green tea': ['green', 'tea'],
#  'grilled seasoned chicken plate': ['seasoned', 'chicken', 'grilled', 'plate'],
#  'grissini breadsticks': ['grissini'],
#  'ground almonds': ['almonds', 'almond'],
#  'ground beef meat': ['beef', 'meat'],
#  'ground beef': ['beef'],
#  'ground black pepper': ['black pepper', 'ground'],
#  'ground hot pepper': ['hot', 'pepper'],
#  'ground turmeric': ['turmeric'],
#  'guacamole': ['guacamole'],
#  'halloumi cheese': ['halloumi', 'cheese'],
#  'halva': ['halva'],
#  'ham slices': ['ham', 'slices'],
#  'ham': ['ham'],
#  'hard cheese': ['hard cheese', 'cheese'],
#  'hazelnuts': ['hazelnuts'],
#  'hemp oil': ['hemp', 'oil'],
#  'hemp protein powder': ['protein', 'hemp'],
#  'hemp tea': ['tea', 'hemp'],
#  'herbal premix': ['herbal', 'premix'],
#  'herbal tea': ['herbal', 'tea'],
#  'herbs': ['herbs'],
#  'herring': ['herring'],
#  'high protein bars': ['high', 'protein', 'bars'],
#  'honey': ['honey'],
#  'honeycomb': ['honeycomb'],
#  'horseradish in jars': ['horseradish', 'jars'],
#  'horses': ['horses'],
#  'hot chicken wings': ['hot', 'chicken', 'wings'],
#  'hot chilli and hot chilli products': ['hot', 'chilli'],
#  'hot dog sausages': ['hot', 'dog', 'sausages'],
#  'hot dogs': ['hot', 'dog'],
#  'ice cream': ['ice cream'],
#  'ice sticks': ['stick', 'ice'],
#  'iced tea': ['iced tea', 'tea'],
#  'ices and desserts': ['desserts', 'ices'],
#  'indian curry': ['indian', 'curry'],
#  'infant formula': ['infant', 'formula'],
#  'instant cereal': ['cereal'],
#  'instant coffee': ['coffee', 'instant coffee'],
#  'instant drink/drinking powder': ['instant', 'powder'],
#  'instant noodles': ['instant', 'noodle', 'noodles'],
#  'jam': ['jam'],
#  'jellies': ['jellies'],
#  'jerky products': ['jerky'],
#  'juice drink': ['drink', 'juice'],
#  'juices': ['juice', 'juices'],
#  'kale': ['kale'],
#  'ketchup': ['ketchup'],
#  'lamb': ['lamb'],
#  'lasagne': ['lasagne'],
#  'lemon juice': ['lemon', 'juice'],
#  'lemonade (lemon soda)': ['lemonade', 'lemon', 'soda'],
#  'lemons': ['lemons'],
#  'lentils stew': ['lentils', 'stew'],
#  'lentils': ['lentils'],
#  'lettuce': ['lettuce'],
#  'lime': ['lime'],
#  'limes': ['lime', 'limes'],
#  'liquid egg white': ['egg', 'egg white'],
#  'liquid food supplement': ['liquid', 'supplement'],
#  'liquorice': ['liquorice'],
#  'lobster': ['lobster'],
#  'lollipops': ['lollipop', 'lollipops'],
#  'long grain rice': ['rice', 'grain'],
#  'loose smoked whole chickens': ['chicken', 'loose', 'whole'],
#  'luncheon meat': ['luncheon', 'meat'],
#  'lupin seeds': ['lupin', 'seeds'],
#  'macadamia nuts': ['macadamia', 'nuts'],
#  'mackerel': ['mackerel'],
#  'maize': ['maize'],
#  'mango': ['mango'],
#  'margarine': ['margarine'],
#  'marinated chicken meat': ['chicken', 'meat', 'marinated'],
#  'marzipan': ['marzipan'],
#  'masala spice mix': ['masala', 'spice'],
#  'mashed chickpeas (hummus)': ['chickpeas'],
#  'massala spice mixture': ['spice', 'mixture'],
#  'mayonnaise': ['mayonnaise'],
#  'meal replacement': ['meal', 'replacement'],
#  'meat and meat products (other than poultry)': ['meat'],
#  'meat broth': ['meat', 'broth'],
#  'meat loaf': ['meat', 'loaf'],
#  'meat preparations': ['preparations', 'meat'],
#  'meat samosas, vegetable samosas, chicken samosas and meat spring rolls': ['meat',
#   'vegetable',
#   'chicken',
#   'spring',
#   'roll'],
#  'meat, egg and dairy products': ['meat', 'egg', 'dairy products'],
#  'meatloaf': ['meatloaf'],
#  'mechanically separated chicken meat': ['chicken', 'separated', 'meat'],
#  'melon seeds': ['melon', 'seeds'],
#  'melons': ['melon'],
#  'milk and milk products': ['milk'],
#  'milk chocolate covered raisins': ['milk chocolate', 'raisins', 'chocolate'],
#  'milk chocolates': ['milk', 'chocolate'],
#  'milk drink': ['milk', 'drink'],
#  'milk powder': ['milk', 'powder'],
#  'milk products': ['milk'],
#  'milk proteins': ['milk', 'proteins'],
#  'milk': ['milk'],
#  'millet porridge': ['millet', 'porridge'],
#  'millet': ['millet'],
#  'minced beef meat': ['minced', 'beef', 'meat'],
#  'minced beef': ['minced', 'beef'],
#  'minced chicken': ['minced', 'chicken'],
#  'minced pork': ['minced pork', 'pork'],
#  'mineral water': ['mineral', 'water'],
#  'mineral waters': ['mineral waters', 'waters', 'water', 'mineral'],
#  'mint chocolate': ['mint', 'chocolate'],
#  'mitragyna speciosa (kratom)': ['kratom'],
#  'mix of nuts': ['nuts'],
#  'mixed nuts': ['nuts'],
#  'mixed salad': ['salad'],
#  'mixed spices': ['spices'],
#  'mixed vegetables': ['vegetables'],
#  'moussaka': ['moussaka'],
#  'mozzarella cheese': ['mozzarella', 'cheese'],
#  'mozzarella': ['mozzarella'],
#  'muesli': ['muesli'],
#  'muffins': ['muffin', 'muffins'],
#  'multi vitamin food supplement': ['vitamin', 'supplement'],
#  'mung bean sprouts': ['bean sprouts', 'sprouts'],
#  'mushrooms': ['mushrooms'],
#  'mussels': ['mussels'],
#  'mustard sauce': ['mustard', 'sauce'],
#  'mustard': ['mustard'],
#  'nacho chips': ['nacho', 'chips'],
#  'natural honey': ['natural', 'honey'],
#  'non-alcoholic beer': ['beer'],
#  'noodle soup': ['noodle', 'soup'],
#  'noodle': ['noodle'],
#  'noodles': ['noodles'],
#  'nougat': ['nougat'],
#  'nut and fruit mixture': ['nut', 'fruit'],
#  'nut and raisin mix': ['nut', 'raisin'],
#  'nut bars': ['nut', 'bars'],
#  'nut mix': ['nut'],
#  'nut mixture': ['nut', 'mixture'],
#  'nut-almond mixture': ['mixture'],
#  'nutmeg': ['nutmeg'],
#  'nutrition shake': ['nutrition', 'shake'],
#  'nuts and nuts products': ['nuts'],
#  'nuts mix': ['nuts'],
#  'nuts, nut products and seeds': ['nut', 'nuts', 'seeds'],
#  'nuts': ['nuts'],
#  'oats': ['oats'],
#  'olive oil': ['olive oil'],
#  'olives': ['olives'],
#  'onions': ['onion', 'onions'],
#  'orange juice': ['orange', 'juice'],
#  'orange peppers': ['peppers', 'orange'],
#  'orange sugar paste': ['sugar', 'orange'],
#  'oregano': ['oregano'],
#  'organic chlorella powder': ['chlorella', 'organic'],
#  'organic coconut flour': ['coconut', 'organic'],
#  'organic coconut oil': ['organic', 'coconut oil'],
#  'organic dates': ['organic', 'dates'],
#  'organic figs': ['figs', 'organic'],
#  'organic tea': ['tea', 'organic'],
#  'organic tofu': ['organic', 'tofu'],
#  'other dairy products': ['dairy product', 'dairy products'],
#  'other fruit and vegetable juice products': ['fruit', 'vegetable', 'juice'],
#  'other not classified meat products': ['meat'],
#  'other types of meat': ['meat', 'types'],
#  'other water-based drinks': ['drinks', 'drink'],
#  'oyster sauce': ['oyster sauce', 'oyster', 'sauce'],
#  'oysters': ['oysters'],
#  'paella': ['paella'],
#  'palm oil': ['palm oil'],
#  'pancakes': ['pancake', 'pancakes'],
#  'papaya': ['papaya'],
#  'paprika': ['paprika'],
#  'parmesan cheese grated': ['parmesan', 'cheese', 'grated'],
#  'parmesan cheese': ['parmesan', 'cheese'],
#  'parsnip': ['parsnip'],
#  'pasta products': ['pasta'],
#  'pasta salad': ['pasta', 'salad'],
#  'pasta sauce': ['pasta sauce', 'sauce'],
#  'pasta': ['pasta'],
#  'pasteurized cow milk cheese': ['pasteurized', 'cheese', 'milk'],
#  'pasteurized milk': ['pasteurized', 'milk'],
#  'pastry products': ['pastry'],
#  'pastry tartlets': ['pastry', 'tartlets'],
#  'pastry': ['pastry'],
#  'pea shoots': ['pea', 'shoots'],
#  'peaches': ['peaches'],
#  'peanuts': ['peanuts'],
#  'pear juice': ['pear', 'juice'],
#  'pears': ['pears'],
#  'peas': ['peas'],
#  'pecorino cheese': ['pecorino cheese', 'cheese'],
#  'peppermint': ['peppermint'],
#  'pepperoni': ['pepperoni'],
#  'peppers': ['peppers'],
#  'pesto sauce (pesto verde)': ['pesto', 'verde', 'sauce'],
#  'pesto': ['pesto'],
#  'pet feed': ['pet'],
#  'pickled beetroot': ['pickled', 'beetroot'],
#  'pickled cucumber': ['pickled', 'cucumber'],
#  'pickled figs, cherries, pears and walnuts': ['walnuts',
#   'cherries',
#   'pears',
#   'pickled'],
#  'pickled gherkins in glass jar': ['pickle', 'gherkin', 'jar'],
#  'pickled ginger': ['pickled', 'ginger'],
#  'pickled grape leaves': ['grape', 'leaves', 'pickled'],
#  'pickled peppers': ['peppers', 'pickled'],
#  'pickled radish': ['radish', 'pickled'],
#  'pig meat - pork': ['pig', 'pork', 'meat'],
#  'pine nuts': ['pine nuts'],
#  'pistachio nuts': ['pistachio', 'nuts'],
#  'pizza': ['pizza'],
#  'plastics': ['plastics'],
#  'plum bread &amp  butter pudding': ['plum', 'bread', 'pudding', 'butter'],
#  'plums': ['plums'],
#  'pomegranate': ['pomegranate'],
#  'pop corn': ['corn'],
#  'porcine lard': ['porcine', 'lard'],
#  'pork and beef sausages': ['beef', 'pork'],
#  'pork belly': ['pork belly'],
#  'pork carcass(es)': ['pork'],
#  'pork fillets': ['pork', 'fillets'],
#  'pork loins - frozen': ['pork loins', 'frozen'],
#  'pork meat': ['meat', 'pork'],
#  'pork pie': ['pork', 'pie'],
#  'pork preparation': ['pork', 'preparation'],
#  'pork sausage': ['pork', 'sausage'],
#  'pork shoulder - fresh': ['fresh', 'pork shoulder'],
#  'pork shoulder': ['pork', 'shoulder'],
#  'potato chips': ['potato', 'chips'],
#  'potato croquettes': ['potato', 'croquettes'],
#  'potato salad': ['potato', 'salad'],
#  'potatoes': ['potatoes'],
#  'poultry meat and poultry meat products': ['poultry meat', 'poultry', 'meat'],
#  'poultry meat': ['poultry meat', 'meat', 'poultry'],
#  'poultry': ['poultry'],
#  'powder seasoning': ['powder'],
#  'prawn crackers': ['prawn',
#   'prawn cracker',
#   'prawn crackers',
#   'cracker',
#   'crackers'],
#  'prawns': ['prawns', 'prawn'],
#  'prebaked apple pies': ['prebaked', 'apple', 'pie'],
#  'precooked cooked beef meat products': ['cooked', 'beef'],
#  'prepacked salad': ['salad'],
#  'prepared dish containing prawns': ['prawn', 'prawns', 'prepared', 'dish'],
#  'prepared dish with chicken': ['dish', 'chicken'],
#  'prepared dish': ['prepared', 'dish'],
#  'prepared dishes and snacks': ['prepared', 'dishes', 'snacks'],
#  'prepared dishes': ['prepared', 'dishes'],
#  'prepared salads': ['salads', 'prepared'],
#  'preserved red bean curd': ['preserved', 'red', 'bean', 'curd'],
#  'pretzel stick': ['stick', 'pretzel'],
#  'pretzels': ['pretzel', 'pretzels'],
#  'probiotic food supplement': ['probiotic', 'supplement'],
#  'prosciutto': ['prosciutto'],
#  'protein balls': ['protein', 'balls'],
#  'protein bar': ['protein', 'bar'],
#  'protein bars': ['protein bars', 'bars'],
#  'protein drink': ['protein', 'drink'],
#  'protein powder': ['protein', 'powder'],
#  'protein supplements': ['protein', 'supplements'],
#  'pudding': ['pudding'],
#  'puffed rice': ['puffed', 'rice'],
#  'pumpkin seeds': ['pumpkin', 'seeds'],
#  'pâté': ['pâté'],
#  'quinoa': ['quinoa'],
#  'quorn preparation': ['quorn'],
#  'radish': ['radish'],
#  'raisins': ['raisin', 'raisins'],
#  'ramen noodles': ['ramen', 'noodles', 'noodle'],
#  'raspberries': ['raspberries'],
#  'ravioli': ['ravioli'],
#  'raw beef meat and raw beef meat preparations': ['beef', 'meat', 'raw'],
#  'raw beef meat': ['beef', 'meat'],
#  "raw cow's milk cheese": ['cheese', 'cow', 'raw'],
#  'raw goat milk cheese': ['goat', 'raw', 'cheese'],
#  'raw milk cheese reblochon': ['cheese', 'raw', 'reblochon'],
#  'raw milk cheese': ['cheese', 'milk'],
#  "raw milk goat's cheese": ['cheese', 'goat', 'raw'],
#  'raw milk': ['milk', 'raw milk'],
#  'raw pork meat and raw pork meat preparations': ['pork', 'meat', 'raw'],
#  'ready cooked sliced chicken tikka breast': ['chicken', 'breast', 'tikka'],
#  'ready to eat - cook meals': ['cook', 'meal', 'meals', 'ready', 'eat'],
#  'ready to eat meat product': ['meat'],
#  'ready-to-eat seafood sticks': ['seafood', 'sticks'],
#  'red chili': ['red', 'chili'],
#  'red chilli': ['red', 'chilli'],
#  'red pesto': ['pesto', 'red'],
#  'refreshments': ['refreshment', 'refreshments'],
#  'rice balls': ['rice', 'rice ball', 'rice balls', 'ball'],
#  'rice cakes': ['rice', 'cake'],
#  'rice cereal for children': ['cereal', 'rice'],
#  'rice crackers': ['rice', 'crackers'],
#  'rice flakes': ['rice', 'flakes'],
#  'rice flour': ['rice', 'flour'],
#  'rice meal': ['rice', 'meal'],
#  'rice noodles': ['rice', 'noodle', 'noodles'],
#  'rice snack': ['rice', 'snack'],
#  'rice sticks': ['rice', 'sticks'],
#  'rice vermicelli': ['rice', 'vermicelli'],
#  'rice': ['rice'],
#  'ricotta and spinach tortelloni pasta': ['ricotta', 'spinach', 'tortelloni'],
#  'ricotta cheese': ['ricotta', 'cheese'],
#  'roasted and caramelized peanuts': ['peanuts', 'roasted'],
#  'roasted coffee': ['roasted', 'coffee'],
#  'roasted nuts': ['roasted', 'nuts'],
#  'rolls': ['rolls'],
#  'rum': ['rum'],
#  'saint marcelin cheese': ['saint', 'cheese'],
#  'salad dressing': ['salad'],
#  'salads': ['salads', 'salad'],
#  'salami sausage': ['salami', 'sausage'],
#  'salami sticks': ['salami', 'sticks'],
#  'salami': ['salami'],
#  'salmon': ['salmon'],
#  'salt': ['salt'],
#  'salted anchovies': ['salted', 'anchovies'],
#  'salted radish': ['radish', 'salted'],
#  'sandwich filling': ['sandwich'],
#  'sandwich spread': ['sandwich', 'spread'],
#  'sandwiches': ['sandwiches'],
#  'sardines': ['sardines'],
#  'sauce': ['sauce'],
#  'sauces': ['sauces'],
#  'sauerkraut meal': ['meal', 'sauerkraut'],
#  'sausage products': ['sausage'],
#  'sausage': ['sausage'],
#  'scallops': ['scallop'],
#  'scones': ['scones'],
#  'seafood cocktail': ['seafood'],
#  'seafood products': ['seafood'],
#  'seafood': ['seafood'],
#  'seasoned chicken': ['chicken', 'seasoned'],
#  'seasonings': ['seasonings'],
#  'seaweed preparations': ['preparations', 'seaweed'],
#  'seed mixe': ['seed'],
#  'seeds mix': ['seeds'],
#  'seeds mixture': ['seeds', 'mixture'],
#  'semi-hard cheeses': ['cheese', 'cheeses'],
#  'semolina and products therefor': ['semolina'],
#  'sesame confection': ['confection', 'sesame'],
#  'sesame oil': ['oil', 'sesame oil'],
#  'sesame paste': ['sesame paste'],
#  'sesame seed oil': ['oil', 'seed', 'sesame'],
#  'sesame seeds': ['seeds', 'sesame'],
#  'sesame': ['sesame'],
#  'shark': ['shark'],
#  'sheep cheese': ['sheep', 'cheese'],
#  'sheep milk cheese': ['cheese', 'sheep', 'milk'],
#  'shrimp snacks': ['shrimp', 'snacks'],
#  'shrimps': ['shrimps'],
#  'sichuan pepper': ['sichuan pepper'],
#  'sliced bread': ['slice', 'bread'],
#  'sliced ham': ['sliced', 'ham'],
#  'smoked sausage': ['smoked', 'sausage'],
#  'smoothie': ['smoothie'],
#  'snack crackers': ['crackers', 'snack'],
#  'snack mix': ['snack'],
#  'snack mixture': ['mixture', 'snack'],
#  'snacks (various)': ['snacks', 'various'],
#  'soda drink': ['soda', 'drink'],
#  'soft cheese (creams)': ['soft cheese'],
#  'soft cheese': ['cheese'],
#  'soft drinks': ['soft drinks', 'drinks'],
#  'soft ripened cheese': ['cheese', 'soft', 'ripened'],
#  'sorbets': ['sorbet', 'sorbets'],
#  'soup': ['soup'],
#  'soups, broths, sauces and condiments': ['condiments',
#   'sauces',
#   'broths',
#   'soups'],
#  'soups': ['soups'],
#  'soy bean paste': ['soy', 'bean', 'paste'],
#  'soy milk product': ['milk', 'soy'],
#  'soy products': ['soy products', 'soy'],
#  'soy sauce': ['soy sauce', 'sauce'],
#  'soy yoghurt': ['soy', 'yoghurt'],
#  'soya and products therefor': ['soya'],
#  'soya drink': ['soya', 'drink'],
#  'soya product': ['soya'],
#  'soybean': ['soybean'],
#  'spaghetti sauce': ['spaghetti', 'sauce'],
#  'sparkling beverages': ['sparkling'],
#  'spice marinade': ['spice', 'marinade'],
#  'spice mix': ['spice'],
#  'spice mixture': ['spice', 'mixture'],
#  'spices': ['spices'],
#  'spicy chicken skewers': ['spicy', 'chicken', 'skewers'],
#  'spicy sauce': ['sauce', 'spicy'],
#  'spicy tofu': ['spicy', 'tofu'],
#  'spicy tomato sauce': ['tomato', 'sauce'],
#  'spinach leaves': ['spinach', 'leaves'],
#  'spinach': ['spinach'],
#  'spirits': ['spirits'],
#  'sport drink': ['sport', 'drink'],
#  'spread': ['spread'],
#  'spreads': ['spread'],
#  'spring rolls': ['spring', 'roll', 'rolls'],
#  'spring water': ['spring', 'water'],
#  'sprinkle mix': ['sprinkle'],
#  'sprouts': ['sprouts'],
#  'squid': ['squid'],
#  'squids': ['squid', 'squids'],
#  'starch': ['starch'],
#  'structured/textured fish meat products or fish paste': ['fish', 'meat'],
#  'stuffed pastry': ['pastry', 'stuffed'],
#  'sugar confectionary': ['sugar', 'confectionary'],
#  'sugar': ['sugar'],
#  'sultanas': ['sultanas'],
#  'sunflower oil': ['sunflower oil', 'sunflower', 'oil'],
#  'sunflower seed': ['sunflower', 'seed'],
#  'sushi': ['sushi'],
#  'sweet nut snack': ['nut', 'sweet'],
#  'sweeteners': ['sweeteners'],
#  'sweets': ['sweet', 'sweets'],
#  'swiss rolls': ['swiss rolls', 'swiss roll', 'roll', 'rolls'],
#  'syrup': ['syrup'],
#  'table water and soda water': ['table water', 'soda water'],
#  'table water': ['table', 'water'],
#  'taco sauce': ['taco', 'sauce'],
#  'tahini (sesame paste)': ['tahini', 'sesame paste', 'sesame'],
#  'tahini': ['tahini'],
#  'tallegio (cheese)': ['cheese'],
#  'tapioca chips': ['tapioca', 'chips'],
#  'tarragon': ['tarragon'],
#  'tasty trio condiment selection': ['trio', 'condiment', 'selection'],
#  'tea bags': ['tea', 'bag'],
#  'tea drink': ['tea', 'drink'],
#  'tea': ['tea'],
#  'testosterone booster': ['testosterone', 'booster'],
#  'thermal processed beef meat': ['thermal', 'processed', 'beef'],
#  'thermal processed pork meat': ['thermal', 'processed', 'pork meat'],
#  'thyme': ['thyme'],
#  'tiger nuts': ['tiger', 'nuts'],
#  'tilapia': ['tilapia'],
#  'toffee': ['toffee'],
#  'tofu': ['tofu'],
#  'tomato sauce': ['tomato', 'sauce'],
#  'tomatoes': ['tomato', 'tomatoes'],
#  'tortilla chips cheese': ['cheese', 'tortilla chips'],
#  'tortilla chips': ['tortilla', 'chips', 'tortilla chip'],
#  'tortilla products': ['tortilla'],
#  'tortilla': ['tortilla'],
#  'trouts': ['trouts', 'trout'],
#  'tuna salad': ['tuna', 'salad'],
#  'tuna': ['tuna'],
#  'turbot flatfish (psetta maxima)': ['turbot', 'flatfish', 'psetta maxima'],
#  'turkey and turkey preparations': ['preparation', 'preparations', 'turkey'],
#  'turkey based products': ['turkey', 'based'],
#  'turkey sandwich': ['sandwich', 'turkey'],
#  'turkey': ['turkey'],
#  'turnip leaves in sunflower seed oil': ['turnip',
#   'leaves',
#   'sunflower seed oil'],
#  'turnips': ['turnip', 'turnips'],
#  'tzatziki sauce': ['tzatziki'],
#  'unpasteurised cheese': ['cheese'],
#  'unsalted organic crunchy peanut butter': ['peanut', 'butter', 'crunchy'],
#  'vacuum packed beef': ['beef', 'packed', 'vacuum'],
#  'vacuum packed marinated pork': ['marinated', 'pork'],
#  'vacuum packed pork ear roll': ['pork', 'vacuum', 'packed', 'ear'],
#  'vacuum packed sliced ham': ['ham', 'sliced', 'vacuum', 'pack'],
#  'vanilla drink': ['vanilla', 'drink'],
#  'vanilla powder': ['vanilla', 'powder'],
#  'various bakery products': ['bakery'],
#  'various beef products': ['beef products', 'various'],
#  'various cheeses': ['cheese', 'cheeses'],
#  'various chicken meat products': ['chicken', 'meat'],
#  'various chilled or frozen pork products': ['pork', 'frozen'],
#  'various fish products': ['fish'],
#  'various meat products': ['meat'],
#  'various pasta products': ['various', 'pasta'],
#  'various poultry meat': ['various', 'poultry', 'meat'],
#  'various prepared dishes': ['various', 'dishes'],
#  'various ready-to-eat meat products': ['various', 'meat'],
#  'various snacks': ['snacks', 'snack'],
#  'various vegetable preparations': ['various', 'vegetable', 'preparations'],
#  'varnishes and coatings': ['varnishes', 'coatings'],
#  'veal meat and offals': ['veal', 'meat', 'offal'],
#  'veal meat': ['veal', 'meat'],
#  'veal': ['veal'],
#  'vegan sausages': ['sausages', 'vegan'],
#  'vegetable based products': ['vegetable', 'based'],
#  'vegetable broth': ['vegetable', 'broth'],
#  'vegetable burger': ['burger', 'vegetable'],
#  'vegetable cheese': ['cheese'],
#  'vegetable mix': ['vegetable'],
#  'vegetable preparation': ['preparation', 'vegetable'],
#  'vegetable ready to eat meals': ['vegetable', 'meals', 'ready', 'eat'],
#  'vegetable snack': ['snack', 'vegetable'],
#  'vegetables': ['vegetables'],
#  'vinegar': ['vinegar'],
#  'vitamins supplement': ['vitamin', 'supplement'],
#  'vitamins': ['vitamin', 'vitamins'],
#  'vodka': ['vodka'],
#  'wafers': ['wafer', 'wafers'],
#  'waffles': ['waffle', 'waffles'],
#  'walnuts': ['walnuts', 'walnut'],
#  'water for human consumption': ['water', 'human', 'consumption'],
#  'water for infants': ['infants', 'water'],
#  'watermelons': ['watermelon', 'watermelons'],
#  'weight loss coffee': ['coffee'],
#  'wheat snack': ['wheat', 'snack'],
#  'wheat': ['wheat'],
#  'whey protein': ['protein', 'whey'],
#  'whisky': ['whisky'],
#  'white beans': ['beans'],
#  'white bread flour': ['bread', 'flour'],
#  'white cheese': ['cheese', 'white cheese'],
#  'white chocolate': ['chocolate', 'white chocolate'],
#  'white lasagna sauce': ['lasagna'],
#  'white mould cheese': ['cheese', 'mould'],
#  'white mustard seeds': ['mustard', 'seeds'],
#  'whole chicken': ['chicken'],
#  'wine': ['wine'],
#  'yellow peas': ['peas', 'yellow'],
#  'yoghurt': ['yoghurt'],
#  'yogurt raisins': ['raisin', 'yogurt']}

# %%
# Convert product and hazard keywords to ConceptNet URIs
product_true_uris = {cat: [f"/c/en/{kw.replace(' ', '_').lower()}" for kw in kws] for cat, kws in products_true.items()}

max_distance = 5

# Generate subgraphs for products and hazards
product_true_subgraphs = {cat: multi_source_bfs(G, uris, max_distance) for cat, uris in product_true_uris.items()}
# Out:
# Warning: Start node /c/en/baking_mix not in graph.
# Warning: Start node /c/en/raw_milk not in graph.
# Warning: Start node /c/en/smoked_ham not in graph.
# Warning: Start node /c/en/fortified_foods not in graph.
# Warning: Start node /c/en/dipping_sauce not in graph.
# Warning: Start node /c/en/dried_sausage not in graph.
# Warning: Start node /c/en/egg_products not in graph.
# Warning: Start node /c/en/protein_bars not in graph.
# Warning: Start node /c/en/pork_ribs not in graph.
# Warning: Start node /c/en/frozen_vegetables not in graph.
# Warning: Start node /c/en/raw_milk not in graph.
# Warning: Start node /c/en/minced_pork not in graph.
# Warning: Start node /c/en/pecorino_cheese not in graph.
# Warning: Start node /c/en/pork_shoulder not in graph.
# Warning: Start node /c/en/protein_bars not in graph.
# Warning: Start node /c/en/raw_milk not in graph.
# Warning: Start node /c/en/sesame_paste not in graph.
# Warning: Start node /c/en/soft_cheese not in graph.
# Warning: Start node /c/en/soy_products not in graph.
# Warning: Start node /c/en/sesame_paste not in graph.
# Warning: Start node /c/en/beef_products not in graph.

# %%
categories = product_true_subgraphs
classifications_products = classify_title_keywords(df, categories, G)

# %%
classifications_products
# Out:
# {'Vilis Lamb, Mint and Rosemary Pies 160g': 'chicken pie',
#  "'Jackpot Mix' brand of Mix of Pretzels, Sticks and Salted Biscuits recalled": 'biscuits',
#  '(Updated) Bradbury &amp  Son (Buxton) recalls Lo-Col because milk is not emphasised on the labelling': 'almond milk',
#  '*(Updated on 2 June 2020) Not to consume a batch of bottled apple juice drink contaminated with patulin': 'apple cake',
#  '*(Updated on 5 July 2022) Not to consume smoked salmon products with dill possibly contaminated with Listeria monocytogenes': 'Groupers (generic)',
#  '165368 C. Corporation Recalls Pork Products Due to Possible Listeria Contamination': 'Not classified pork meat',
#  '168 Express Ltd recalls various Jelly products because of a choking hazard': 'Dried pork meat',
#  '2006 - Consumer Alert: Listeria Contamination in Raw Milk': 'almond milk',
#  '2006 - Pinnacle Foods Corporation Issues Allergy Alert on Bakery-Style Chocolate Chip Muffin Mix': 'cereal bars with chocolate',
#  '2006 - Pinnacle Foods Group Inc. Issues Allergy Alert on Undeclared Egg in Frozen': 'baby foods',
#  '2006 - allergy alert on undeclared almonds in albertsons chocolate ice cream': 'almonds',
#  '2006 - pinnacle foods group inc. issues allergy alert on brownie mix': 'baby foods',
#  '2007 - Agriculture Department Warns Consumers of Tainted Raw Milk Sold by Butler County Dairy': 'almond milk',
#  '2007 - WholeSoy & Co. Expands National Allergy Alert on Undeclared Dairy in Blueberry and Mixed Berry Yogurt': 'yogurt raisins',
#  '2007 - Winn-Dixie Stores, Inc. Issues Allergy Alert on Mislabeled Prestige Chocolate Ice Cream': 'cereal bars with chocolate',
#  '2007 - private selection® ice cream recalled from ralphs and food 4 less stores in california': 'assorted bread roll selection',
#  '2008 - Barry Callebaut USA LLC Issues Allergen Alert on Undeclared Milk Protein in Kroger Value Semi Sweet Chocolate Chips': 'almond milk',
#  "2008 - dreyer's issues voluntary recall of slow churned® light caramel delight and butter pecan ice cream flavors for undeclared pecans": 'butter',
#  '2008 - limited number of aunt jemima pancake & waffle mix products recalled for possible health risk': 'apple cake',
#  "2008 - pierre's ice cream company issues allergy alert on its homestyle brand of dutch chocolate ice cream for undeclared peanut butter cup candies": 'candies',
#  '2008 - private selection ice cream recalled from kroger stores in twelve southeastern states': 'assorted bread roll selection',
#  '2009 - A Manufacturer From England, Cropwell Bishop Creamery Limited, is Conducting a Nationwide Recall on the Cheese Products Blue Stilton and Shropshire Blue Cheese Because of Possible Health Risk': 'blue cheese',
#  '2009 - Alexia Foods issues nationwide allergy alert and product recall on its Alexia Olive Oil, Sun-Dried Tomatoes & Pesto Oven Reds frozen potatoes due to undeclared pine nut allergen': 'Groupers (generic)',
#  '2009 - BIC Acquisition, LLC Recalls World Classic Trading Company Ultimate Chunk Ice Cream': 'ice sticks',
#  '2009 - Bliss Bros. Dairy, Inc. Recalls Ice Cream Products Because of Possible Health Risk': 'cream cheese',
#  '2009 - Boca Grande Foods Announces a Nationwide Recall of POCO PAC?, and GRANDE GOURMETT Peanut Butter Products Because of Possible Health Risk': 'butter',
#  "2009 - Braum's Ice Cream and Dairy Stores Announces Voluntary Recall of its Premium Ice Cream Flavor": 'ice cream',
#  '2009 - Bucks Ice Cream Recalls Ice Cream Nut Roll Because of Possible Health Risk': 'cream cheese',
#  '2009 - Fieldbrook Foods Corp. Announces Nationwide Voluntary Recall of Select Ice Cream Novelty Products Due to Possible Health Risk': 'almond milk',
#  '2009 - Fieldbrook Foods Corporation Adds Four Products to Nationwide Voluntary Recall of Select Ice Cream Novelty Products Due to Possible Health Risk': 'baby foods',
#  '2009 - Frito-Lay Issues Nationwide Voluntary Recall of In-Shell Pistachio Nuts Due to Possible Health Risk': 'macadamia nuts',
#  '2009 - Garden-Fresh Foods Issues Allergy Alert On Undeclared Milk in 16-Ounce Archer Farms Potato Salad': 'almond milk',
#  '2009 - Glutenfreeda Foods, Inc. Recalls Peanut Envy Frozen Cookie Dough Because of Possible Health Risk': 'chicken products - frozen',
#  '2009 - Hershey Creamery Announces Voluntary Recall of Goo Goo Peanut Butter Ice Cream Because of Possible Health Risk': 'butter',
#  '2009 - House of Flavors Issues Allergy Alert for Undeclared Walnuts in Hanniford Chocolate Chip Ice Cream Sold at Sweetbay Supermarkets in Florida': 'cereal bars with chocolate',
#  '2009 - Ice Cream Specialties Announces Nationwide Recall of Ice Cream Novelties Because of Possible Health Risk': 'apple cake',
#  '2009 - Kanan Enterprises Conducts Nationwide Voluntary Recall of Red Pistachios and Garlic Onion Pistachios': 'dried garlic',
#  '2009 - Kroger Recalls Additional Select Ice Cream Product Due to Possible Health Risk': 'Groupers (generic)',
#  '2009 - Kroger Recalls Select Ice Cream Products Due to Possible Health Risk': 'almond milk',
#  '2009 - Kroger Recalls Super Kids Enriched White Sandwich Bread Due to Undeclared Milk in the Product': 'almond milk',
#  '2009 - L A WEIGHT LOSS RECALLS LA HOT DRINKS CAF� AU LAIT BECAUSE OF POSSIBLE HEALTH RISK': 'chocolate drinks',
#  '2009 - Landies Candies Co. Inc Expands Voluntary Recall to Include Select Organic Peanut Clusters Due to Possible Health Risk': 'organic chlorella powder',
#  "2009 - Michaelene's, Inc./ Michaelene's Gourmet GranolaT Initiates Voluntary Nationwide Granola Recall Because of Possible Risk to Health": 'granola',
#  "2009 - Mooresville Ice Cream Co. Conducts Carolinas Recall of Half Gallon and Three Gallon containers of 'Chocolate Peanut Butter Delight' flavor of DeLuxe Ice Cream Because Of Possible Health Risk": 'cereal bars with chocolate',
#  '2009 - NOW Foods Issues Voluntary Recall of Pistachios': 'all purpose seasoning',
#  "2009 - Natural Selection Recalls Aunt Patty's Cascade Trail Mix Because Of Possible Health Risk": 'feed materials',
#  '2009 - Nature Kist Snacks Issues Nationwide Voluntary Recall of In-Shell Pistachio Nuts Due to Possible Health Risk': 'cheese flavoured snacks',
#  '2009 - Ocean Spray Announces Nationwide Voluntary Recall of 1.75 oz and 48 oz Fruit and Nut Trail Mix Products': 'dried fruit in jars',
#  "2009 - Perry's Ice Cream Company Adds Products to Voluntary Recall of Select Peanut Butter Ice Cream Products as a result of PCA Expanded Recall": 'all purpose seasoning',
#  '2009 - Premier Packing Company Is Recalling Raw Redskin Peanuts, Raw Spanish Peanuts, Raw Blanched Redskin Peanuts, and Toasted Diced Peanuts Because of A Possible Health Risk': 'peanuts',
#  '2009 - Publix Issues Voluntary Recall on Publix Gourmet Peanut Mix Because of Possible Health Risk': 'unsalted organic crunchy peanut butter',
#  "2009 - Ralcorp Frozen Bakery Products Recalls Lofthouse Peanut Butter Cookies, Chuck's Chunky Peanut Butter Cookies And Pastries Plus Gourmet Cookies Nationwide Because Of Possible Health Risk": 'bakery products',
#  '2009 - Rich Products Corporation announces nationwide voluntary recall of Peanut Butter Blast Pie and Red Robin 10': 'butter',
#  '2009 - Shamrock Foods Company Issues Voluntary Recall on Nutty Sundae Cones': 'baby foods',
#  '2009 - Turner Holdings Recalls Peanut Butter Bars Because of Possible Health Risk': 'bars',
#  '2009 - Unilever Issues Allergy Alert on Wheat in a Limited Number of Tubs of Breyers Ice Cream': 'ice cream',
#  '2009 - Unilever United States, Inc. Conducts Nationwide Voluntary Recall Of Breyers Tin Roof Sundae Ice Cream Products with Peanuts Due to Possible Health Risk': 'peanuts',
#  '2009 - Velvet Ice Cream Pulling Cone Products': 'cream cheese',
#  '2009 - Whole Foods Market Issues Nationwide Voluntary Recall of In-Shell Pistachio Nuts Due to Possible Health Risk': 'apple cake',
#  '2009 - Willamette Shelling Recalls Shelled Hazelnuts Because of Possible Health Risk': 'chocolate spread with hazelnuts',
#  '2009 - aqua star issues allergy alert on undeclared peanut in shrimp appetizer': 'dried shrimp noodles',
#  '2009 - arco nut and candy llc recall of peanut products because of possible health risk': 'unsalted organic crunchy peanut butter',
#  '2009 - arya ice cream dist. co., inc. recalls california dream nut sundae because of possible health risk': 'nut and fruit mixture',
#  '2009 - austinuts wholesale, inc. announces voluntary recall of organic peanuts': 'organic chlorella powder',
#  '2009 - belfonte ice cream and dairy foods co. announces voluntary recall of ice cream due to possible health risk': 'ice cream',
#  '2009 - candies tolteca recalls two flavors of peanut snacks because of possible health risk': 'unsalted organic crunchy peanut butter',
#  '2009 - caribou coffee? participates in voluntary nationwide peanut product recall': 'coffee beans',
#  "2009 - casper's ice cream, inc. voluntarily recalls fat boy® casco® nut sundae on a stick and fat boy® casco® cherry cordial nut sundae on a stick products because of possible health risk": 'bovine fat',
#  '2009 - christie cookie recalls certain lots of peanut butter cookies due to expanded recall by peanut corporation of america': 'butter',
#  '2009 - country life natural foods conducts nationwide recall of peanut-containing candies because of possible health risk': 'baby foods',
#  '2009 - deluxe ice cream co. expands recall to include additional codes of tin roof sundae, goo goo cluster, and candy bar half gallon packaged ice cream product, 3 gallon tin roof sundae and qc 24 pack sundae cone because of possible health risk': None,
#  '2009 - diamond foods issues voluntary recall of in-shell pistachio item': 'baby foods',
#  '2009 - edaleen dairy recalls tin roof sundae ice cream and chocolate peanut butter nut ice cream because of possible health risk': 'butter',
#  '2009 - energy club conducts nationwide voluntary recall of in-shell pistachio nuts due to possible health risk': 'pistachio nuts',
#  '2009 - euphoria chocolate company of eugene announces voluntary recall of individually wrapped milk and dark chocolate peanut clusters due to possible health risk': 'cereal bars with chocolate',
#  "2009 - foodscience corporation recalls kid's multivitamin for label error": 'bilberry extract used in a food supplement',
#  '2009 - frontera produce recalls one lot of cilantro because of possible health risk': 'almond milk',
#  "2009 - garber's ice cream company issues voluntary recall on half gallon tin roof sundae ice cream and nutty cones due to expanded peanut recall by peanut corporation of america (pca)": 'unsalted organic crunchy peanut butter',
#  '2009 - gel spice co. recalls small chop granules peanutsbecause of possible health risk': 'gravy granules',
#  '2009 - golden chocolate issues allergy alert on undeclared walnuts in brighton beach candy': 'cereal bars with chocolate',
#  "2009 - grand rapids popcorn recalls pca's 30# cases of medium chop granulated peanuts sold in michigan and florida because of possible health risk": 'peanuts',
#  '2009 - h-e-b issues precautionary and voluntary recall for creamy creations peanut brittle ice cream': 'ice cream',
#  '2009 - haifa smoked fish, inc is voluntarily recalling haifa smoked fish brand cold smoked whitefish sold between december 7, 2008 and june 18, 2009 because of possible health risk': 'canned fish products',
#  '2009 - harry and david initiates nationwide recall of pistachio nut food items: caramels and clusters, ksar pistachios, and marrakesh pistachios, due to the expanded recall by setton pistachio of terra bella, inc.': 'caramel bites',
#  '2009 - harry and david recalls olympia delight trail mix because of possible health risk': 'apple cake',
#  '2009 - hiland dairy foods company, llc announces recallof ice cream because of possible health risk': 'cream cheese',
#  '2009 - hiland-roberts ice cream announces voluntary nationwide recall of specific lot numbers of espo brand and natures promise brand sorbettos due to containing undeclared milk': 'almond milk',
#  '2009 - house of flavors expands voluntary recall of ice creamdue to possible health risk': 'apple cake',
#  '2009 - house of flavors issues voluntary recall in eastern united states due to possible health risk': 'apple cake',
#  '2009 - hp hood llc recalls ice cream products': 'almond milk',
#  '2009 - ifs announces a nationwide recall of pistachios due to possible salmonella contamination': 'feed materials',
#  '2009 - iovate health sciences u.s.a., inc. adds hydroxycut-branded product universal product codes to its voluntary nationwide recall': 'Groupers (generic)',
#  '2009 - k-fat inc. issues alert on uneviscerated mackerel fish': 'canned fish products',
#  '2009 - kar nut products conducts nationwide recall of pistachio products because of possible risk to health': 'nut and fruit mixture',
#  '2009 - kerry ingredients & flavours announces voluntary recall of choco fudge peanut ingredient following expanded fda investigation of peanut corporation of america': 'flavours',
#  "2009 - kerry ingredients & flavours announces voluntary recall of jana's peanut butter cookie following expanded fda investigation of peanut corporation of america": 'unsalted organic crunchy peanut butter',
#  '2009 - kerry, inc. expands voluntary recall of peanut products following expanded fda investigation of peanut corporation of america': 'unsalted organic crunchy peanut butter',
#  "2009 - klein's naturals conducts nationwide voluntary recall of various pistachio products due to possible health risk": 'natural honey',
#  '2009 - kroger expands recall of shelled pistachios due to possible health risk': 'pistachio nuts',
#  '2009 - maeco foods recalls peanut meal because of possible health risk': 'unsalted organic crunchy peanut butter',
#  '2009 - manufacturer for publix brand greenwise vanilla & chocolate flavored whey proteins issues an allergen alert for undeclared milk allergen': 'almond milk',
#  '2009 - multiple brands of tin roof sundae ice cream recalled as part of nationwide peanut corporation of america recall': 'ice cream',
#  '2009 - nassau candy is voluntarily recalling various pistachio products': 'pistachio nuts',
#  '2009 - peanut corporation of america expands nationwide recall of peanut butter': 'unsalted organic crunchy peanut butter',
#  '2009 - peanut corporation of america expands nationwide recall of peanut products': 'unsalted organic crunchy peanut butter',
#  '2009 - pecan deluxe candy company announces nationwide voluntary recall of certain peanut containing products': 'unsalted organic crunchy peanut butter',
#  "2009 - pierre's ice cream company issues voluntary recall on its pierre's brand sundae-cone style products due to expanded peanut recall by peanut corporation of america (pca)": 'ice cream',
#  '2009 - prairie farms dairy announces voluntary nationwide recall because of possible health risk': 'animal by-products',
#  '2009 - premier packing company is recalling dry roasted unsalted peanuts, dry roasted salted peanuts, fiesta mix, toasted diced peanuts, honey roasted peanuts, and roca toffee because of a possible health risk': None,
#  '2009 - ralcorp frozen bakery products recalls food lion bake shop peanut butter cookies nationwide because of possible health risk': 'bakery products',
#  '2009 - ramsey popcorn co. recalls camp masters chocolatey peanut clusters sold in maryland, mississippi and texas because of possible risk to health': 'unsalted organic crunchy peanut butter',
#  "2009 - rich ice cream company expands precautionary voluntary multi-state recall to include rich's candy bar avalanche": 'protein bar',
#  "2009 - rich ice cream company, inc. issues multi-state voluntary recall of rich's nutty sundae cone because of possible health risk": 'all purpose seasoning',
#  '2009 - roman meal company initiates nationwide recall of whole grain & fruit dark chocolate peanut butter snack bars because of possible health risk': 'bars',
#  '2009 - safeway recalls selected peanut products sold at 66 stores with nut kiosks': 'unsalted organic crunchy peanut butter',
#  '2009 - seoul shik poom inc. issues allergy alert on undeclared sulfites in honey jujube teas': 'honey',
#  "2009 - smith dairy announces voluntary recall on smith's tea with lemon in gallon size only": 'green tea',
#  '2009 - spanish: torres hillsdale country cheese llc expands the recall of asadero and oaxaca cheeses due to possible listeria contamination': 'blue cheese',
#  '2009 - super store industries announces voluntary recall of select ice cream products due to possible health risk': 'apple cake',
#  '2009 - the swiss colony, inc. recalls certain products containing in-shell pistachios due to possible health risk': 'pistachio nuts',
#  '2009 - torres hillsdale country cheese llc announces the recall of all lots of soft mexican cheeses due to possible listeria contamination': 'blue cheese',
#  '2009 - tri-union seafoods issues precautionary recall of select 5-ounce solid light tuna in olive oil': 'olive oil',
#  '2009 - turkey hill dairy expands voluntary ice cream recall to include': 'cream cheese',
#  '2009 - umpqua dairy issues voluntary recall on its tin roof sundae ice cream products due to expanded peanut recall by peanut corporation of america (pca)': 'unsalted organic crunchy peanut butter',
#  '2009 - undeclared sulfites in': 'Groupers (generic)',
#  '2009 - unilever conducts nationwide voluntary recall of slim-fast� ready-to-drink products in cans due to possible health risk': 'apple cake',
#  '2009 - update: schwan expands voluntary recall of ice cream, citing possible health risk': 'cream cheese',
#  '2009 - vitamin cottage natural food markets inc. fresh-ground peanut citing possible health risk': 'multi vitamin food supplement',
#  '2009 - walgreens recalls cafe w brand trail mix containing peanuts': 'peanuts',
#  '2009 - walgreens recalls deerfield farms mediterranean fruit and nut blend': 'dried fruit in jars',
#  '2009 - werner gourmet meat snacks inc. initiates nationwide recall of garlic flavored pistachio and jalapeno flavored pistachio items because of possible health risk': 'cheese flavoured snacks',
#  '2009 - whole foods market stores in southern california, nevada, arizona and hawaii voluntarily recall peanut grinder products': 'baby foods',
#  '2009 - wonder ice cream company announces nationwide voluntary recall of candy blast 10oz cups because of possible health risk': 'all purpose seasoning',
#  '2009 - zenobia company conducts nationwide voluntary recall of california pistachios because of possible health risk': 'pistachio nuts',
#  '2010 - Azteca Linda Corp. Recalls QUESO FRESCO and QUESO HEBRA Because of Possible Risk of Health': 'apple cake',
#  "2010 - Brinkman Turkey Farms Inc. Issues Allergy Alert On Undeclared Soy And Milk In “Brinkman's Gourmet Barbecue Sauce”.": 'almond milk',
#  '2010 - Del Bueno Recalls Cheese Because Of Possible Health Risk': 'blue cheese',
#  '2010 - Del Bueno Recalls Queso Fresco Because of Possible Health Risk': 'apple cake',
#  '2010 - Frontier Natural Products Co-op Initiates Voluntary Recall Due to Possible Health Risk from Nutmeg': 'natural honey',
#  '2010 - Moark, LLC, of Fontana, California, Recalls Shell Eggs Supplied From Hillandale Farms of Iowa Because of Possible Health Risk': 'chocolate eggs',
#  '2010 - NuCal Foods Conducts Recall of Shell Eggs Supplied from Hillandale Farms of Iowa Because of Possible Health Risk': 'chocolate eggs',
#  '2010 - Quaker Snack Mix Baked Cheddar Voluntarily Recalled Due to Possible Health Risk': 'bean snack',
#  '2010 - Sirob Imports Issues Alert on Undeclared Sulfites in Strawberry Farms Sun Dried Tomatoes': 'Dried pork meat',
#  '2010 - Whole Foods Market Announces Cheese Recall For Products In Three Western States And Washington, D.C. Because Of Possible Health Risk': 'baby foods',
#  '2010 - cardenas market brand label included in wright county egg recall': 'egg products',
#  '2010 - del bueno amends recall of queso fresco cheese because of possible health risk': 'blue cheese',
#  '2010 - deluxe ice cream issues allergy alert on undeclared peanuts in western family maple nut ice cream': 'peanuts',
#  '2010 - dpi specialty foods recalls mauri brand gorgonzola because of possible health risk': 'gorgonzola cheese',
#  '2010 - golden pacific foods, inc. issues allergy alert for undeclared milk and soy in marco polo brand shrimp snacks': 'almond milk',
#  '2010 - gorgonzola cheese sold at costco recalled due to contamination with e.coli o157:h7': 'gorgonzola cheese',
#  '2010 - harry london candies, inc. announces a voluntary and limited recall of harry london chocolate pecan caramel stars due to an undeclared allergen': 'caramel bites',
#  '2010 - hillandale farms of iowa conducts nationwide voluntary recall of shell eggs because of possible health risk': 'egg products',
#  "2010 - kellogg company voluntarily recalls select packages of kellogg's® corn pops®, kellogg's® honey smacks®, kellogg's® froot loops® and kellogg's® apple jacks®": 'canned corn',
#  '2010 - kroger amends code date on recalled seasoning blend garlic powder': 'almond powder',
#  '2010 - minnesota firm issues recall due to undeclared dairy allergen in certain sunflower seeds': 'blue poppy seeds',
#  '2010 - olde westport spice announces a voluntary recall of garden harvest special blend seasoning': 'Veggie Burger',
#  '2010 - oregon ice cream company issues allergy alert on undeclared peanuts in denali bear claw ice cream': 'peanuts',
#  '2010 - p&g joins industry ingredient recall by voluntarily recalling two flavors of pringles® in the united states in response to fda industry guidance': 'cheese dip',
#  '2010 - queseria bendita recalls queso fresco, panela, and requeson because of possible health risk': 'apple cake',
#  '2010 - queseria chipilo recalls cheese products because of possible health risk': 'blue cheese',
#  '2010 - ready pac foods, inc. announces voluntary product recall because of possible health risk': 'Groupers (generic)',
#  '2010 - so shing hing (usa) trading co ltd issues an alert on undeclared sulfites in dried melon': 'Dried pork meat',
#  '2010 - spice barn, inc. voluntarily recalls two lots of black pepper': 'black pepper',
#  '2010 - turkey hill dairy issues recall on chocolate marshmallow ice cream that may contain undeclared treenuts (almonds)': 'almonds',
#  '2010 - whole foods market voluntarily recalls frozen whole catch yellow fin tuna steaks due to possible health risks': 'baby foods',
#  '2010 - wholesome spice recalls 25 lb. boxes of crushed red pepper because of possible health risk': 'black pepper',
#  '2010 - wright county egg expands nationwide voluntary recall of shell eggs because of possible health risk': 'chocolate eggs',
#  '2011 - Barry Callebaut USA LLC Issues Allergen Alert on Potential Undeclared Milk Protein in Kroger Value Semi Sweet Chocolate Chips': 'almond milk',
#  '2012 - ***UPDATED CONSUMER ALERT*** Listeria Contamination in Certain Mexicali Cheese Corp. Products': 'blue cheese',
#  '2012 - BI-LO Issues Voluntary Recall on Daniella Brand Mangoes Due to Possible Health Risk': 'apple cake',
#  '2012 - Banner Mountain Sprouts Voluntarily Recalls Organic Sprouts Because of Possible Health Risks': 'alfalfa sprouts',
#  '2012 - Belfonte Ice Cream and Dairy Foods Company Announces Voluntary Recall of Ice Cream Due to Possible Health Risk': 'ice cream',
#  '2012 - Botanical Laboratories Inc. Recalls Wellesse Digestive 3 in 1 Health® Because of Possible Health Risk': 'apple cake',
#  '2012 - Boulder Ice Cream Announces a Voluntary Limited Recall of Ice Cream and Gelato Products Due to Possible Health Risk': 'ice cream',
#  '2012 - Bucks Ice Cream Recalls Iskream Brand Peanut Butter and Jelly No Sugar Added Ice Cream Because of Possible Health Risk': 'ice cream',
#  '2012 - Caribe Produce, LTD CO. Recalls Papaya Maradol, Caribena Brand Because Of Possible Health Risk': 'papaya',
#  '2012 - Cass-Clay Creamery Issues Allergy Alert On Undeclared Allergens In Ice Cream': 'ice cream',
#  '2012 - Clemmys is Voluntarily Recalling Peanut Butter Chocolate Chip Ice Cream Due to Possible Health Risks': 'butter',
#  '2012 - Forever Cheese Announces an Expanded Recall of Marte brand Ricotta Salata Frescolina for Possible Health Risk': 'blue cheese',
#  '2012 - Forever Cheese to stop importing and selling all Fattorie Chiarappa products': 'blue cheese',
#  '2012 - Harris Teeter is Recalling 5 Flavors of Sorbet Due to Possible Undeclared Milk Allergen': 'almond milk',
#  '2012 - Meadow Gold Dairy Conducts Voluntary Recall of Western Family® Brand "Creamery Select (Premium Ice Cream) Peanut Butter Cup" Ice Cream in 1.5 Quarts Size Due to Potential Health Risk Posed by Nationwide Sunland, Inc. Peanut Butter Recall': 'cream cheese',
#  '2012 - Minnesota Firm Issues Recall Due to Undeclared Soy Allergen in Certain Sunflower Seeds': 'blue poppy seeds',
#  '2012 - Nina International Recalls Ground Hot Pepper Because Of Possible Health Risk': 'black pepper',
#  '2012 - Ocean Beauty Seafoods LLC Recalls “Nathan’s Brand Cold Smoked Atlantic Salmon 3 oz” and “LASCCO Cold Smoked Atlantic Salmon 4 oz”': 'cured smoked ham',
#  '2012 - Oregon Ice Cream Manufacturing is Voluntarily Recalling Aldens Organic Brand Peanut Butter n Chip Ice Cream and Cascade Glacier Brand Chocolate Peanut Butter Ice Cream Due to Possible Health Risks': 'butter',
#  '2012 - Pacific International Marketing Voluntarily Recalls 19 Cases of Bulk Romaine Lettuce Sold At Vons And Pavilions Stores In California And Nevada Due To Possible Salmonella Contamination': 'lettuce',
#  '2012 - Pinnacle Foods Group LLC Issues Allergy Alert On Undeclared Soy Protein In Aunt Jemima Frozen Pancakes': 'all purpose seasoning',
#  '2012 - Price Chopper Supermarkets Recalls Central Market Classic Cinnamon Coffee Cake Purchased At Mountain Road Store In Worcester, MA': 'apple cake',
#  '2012 - Publix Issues Voluntary Recall For Publix Premium Frozen Tempura Shrimp': 'chicken products - frozen',
#  '2012 - Publix Issues Voluntary Recall Multiple Cake Products': 'apple cake',
#  '2012 - Rich Products Corporation Announces Nationwide Voluntary Recall of Jon Donaire Peanut Butter Cup Ice Cream Cake and TCBY Peanut Buttery Fudge Deep Dish Frozen Yogurt Pie': 'apple cake',
#  '2012 - Select Containers of Kroger Deluxe French Vanilla Ice Cream': 'vanilla drink',
#  '2012 - Summit Import Corporation Issues Allergy Alert on Undeclared Eggs in Bin Bin Snow Rice Cracker 5.3oz Pack and Bin Bin Rice Cracker 15.8oz Bulk Pack': 'brown rice',
#  '2012 - Super Store Industries Recalls Lovin’ Scoopful Ice Cream - Super Duper Peanut Butter Cup Because Of Possible Health Risk': 'butter',
#  '2012 - Toft Dairy Issues Immediate Voluntary Recall of Buckeye Bites Ice Cream 48 oz Cartons and 3 Gallon Tubs': 'ice cream',
#  '2012 - Tomales Bay Foods, Inc. Issues A Voluntary Recall of Two Cheeses Because of Possible Health Risk': 'baby foods',
#  '2012 - Tri-union Seafoods Issues Voluntary Recall On Select 7-ounce Solid White Albacore Tuna In Water': 'bottled water',
#  '2012 - UPDATE: Whole Foods Market recalls cheese because of possible health risk': 'blue cheese',
#  "2012 - Unilever Issues Allergy Alert On Pints Of Ben & Jerry's Chocolate Nougat Crunch Ice Cream:Sweet Cream Ice Cream with Fudge Covered Wafer Cookies & a Chocolate Nougat Swirl": 'cereal bars with chocolate',
#  '2012 - University Creamery Recalling Ice Cream': 'cream cheese',
#  '2012 - Updated - Berres Brothers Coffee Roasters Issues Allergy Alert On Possible Nut Flavoring In Coffee': 'coffee beans',
#  '2012 - Velvet Ice Cream Voluntarily Recalls Some Ice Cream Containing Peanut Products': 'ice cream',
#  '2012 - Whole Foods Market Voluntarily Recalls Variety Of Peanut Butter Cookies In Four States Due To Possible Health Risk': 'baby foods',
#  '2012 - Whole Foods Market recalls carrot cake cupcakes for undeclared walnuts in Northern California': 'apple cake',
#  '2012 - Whole Foods Market recalls cheese in 21 states and Washington, D.C. because of possible health risk': 'baby foods',
#  "2012 - smith dairy announces voluntary recall on smith's and ruggles brand peanut butter crunch ice cream and acme brand peanut butter twist ice cream": 'almond milk',
#  '2013 - 2013 Recall for Barry Callebaut USA LLC': 'feed materials',
#  '2013 - ANDY CAPP’S HOT FRIES RECALLED DUE TO UNDECLARED SOY ALLERGEN': 'ground hot pepper',
#  '2013 - Allergy Alert On Undelcared Eggs In Lotte Waffles': 'chocolate eggs',
#  '2013 - Anhing Corporation Announces a Voluntary Recall of Chili Powder Due to Possible Health Risk': 'apple cake',
#  '2013 - Blooming Import Inc. Issues an Alert on Undeclared Sulfites in Golden Lion Brand Dried Ziziphus Jujuba Mill (Dried Dates)': 'Dried pork meat',
#  '2013 - Blue Bunny Premium Bordeaux Cherry Chocolate Ice Cream Recalled for Undeclared Allergen': 'cereal bars with chocolate',
#  '2013 - Brunkow Cheese Issues Allergy Alert On Undeclared Soy In Jalapeno Pepper Raw Milk Cheddar Cold Pack Cheese': 'almond milk',
#  '2013 - Chocolate Decadence Issues Allergy Alert on Undeclared Milk in Multiple Lines of Chocolate Products': 'almond milk',
#  '2013 - Consumer Alert - Undeclared Sulfites In Dried Dates': 'Dried pork meat',
#  '2013 - DZH Import & Export Inc. Issues an Alert on Undeclared Sulfites in Mountains Dried Mushroom': 'Dried pork meat',
#  '2013 - DZH Import & Export Inc. issues an alert on undeclared sulfites in Curiosity of Dashan Dried Mushroom': 'dried shitake mushrooms (lentinula edodes)',
#  '2013 - Daesang Issues Allergy Alert on Undeclared Peanuts in Mixed Soy Bean Paste (Sesame and Garlic)': 'dried garlic',
#  '2013 - Dairy Fresh Conducts Voluntary Recall of IGA Brand “Vanilla & Chocolate” 1.75 Quart Ice Cream Because Package May Contain Undeclared Allergens (Almonds, Coconut, Soy)': 'almonds',
#  '2013 - Del Bueno Recalls Queso Fresco Casero Cheese Because of Possible Health Risk': 'blue cheese',
#  '2013 - Domega NY International CO., LTD. Issues An Alert On Undeclared Sulfites In Green Day Brand Dried Coconut': 'Dried pork meat',
#  '2013 - Domega NY International Co., Ltd Issues an Alert on Undeclared Sulfites in Green Day Brand Dried Coconut': 'Dried pork meat',
#  '2013 - Domega Ny International Co Ltd Issues Allergy Alert On Undecleared Eggs In Brilliant Cake With Filling Milk (biscuits)': 'almond milk',
#  '2013 - Euphoria Fancy Food Inc. Issues An Alert On Uneviscerated Fish': 'canned fish products',
#  '2013 - Fresh Express Announces Precautionary Recall of a Limited Number of Cases of 9 oz. Bag Spinach Due to Possible Health Risk from Salmonella': 'baby spinach',
#  '2013 - General Mills Voluntarily Recalls Single-Serve Reduced-Sugar Cinnamon Toast Crunch Bowlpak sold in Foodservice Establishments': 'cinnamon rolls',
#  '2013 - Gold Standard Baking Issues Allergy Alert on Undeclared Walnuts in Sweet P’s Bake Shop Branded Caramel Apple Danish Coffee Cake': 'apple cake',
#  '2013 - Gold Star Smoked Fish Corp. Issues an Alert on Listeria in Baltic Treasures, Norwegian Style Matjes, Marinella': 'canned fish products',
#  '2013 - Gold Star Smoked Fish Corp. Issues an Alert on Listeria in Rybacka Wies Brand Herring Fillets in Oil': 'anchovies in oil',
#  '2013 - Great Feeling Foods, LLC Recalls Groove Gluten-Free Ice Cream Cookie Sandwiches Because of Possible Health Risk': 'baby foods',
#  '2013 - Gromex Inc. Issues Allergy Alert on Undeclared Sulfites in Camaron Entero (Dried Whole Shrimp)': 'Dried pork meat',
#  '2013 - Health Matters America Inc. Issues Allergy Alert on Undeclared Milk in Organic Traditions Brand Dark Chocolate Golden Berries and Dark Chocolate Sacha Inchi Seeds': 'almond milk',
#  '2013 - Ice Cream Specialties Issues Allergy Alert On Undeclared Peanut Allergen In Dairy Rich Chocolate Ice Cream': 'cereal bars with chocolate',
#  '2013 - Limited Number Of Lightlife Farmerâ€™s Market Veggie Burgers Recalled Due To Undeclared Milk Allergen': 'Veggie Burger',
#  '2013 - Lion Pavilion Issues Alert on Undeclared Sulfites in Grassplot Ginger Slices': 'chicken slices',
#  '2013 - Louie Foods International Voluntarily Recalls Certain Sprouts': 'alfalfa sprouts',
#  '2013 - Maple View Farm Recalls Three Flavors of Ice Cream Because of Undeclared Allergens': 'ice cream',
#  '2013 - Mondelēz Global LLC Conducts Nationwide Voluntary Recall of belVita Breakfast Biscuit Apple Cinnamon and Chocolate Varieties in the U.S. and Puerto Rico': 'apple cake',
#  '2013 - Nishimoto Trading Co., LTD Issues Allergy Alert on Undeclared Milk in Kameda Brand 4.37 oz Packages of Rice Cracker': 'almond milk',
#  '2013 - Olam Tomato Processors, Inc. Announces Voluntary Recall of Mild and Medium Chunky Salsa Because It May Contain Large Glass Pieces': 'boletus mushrooms, stems and pieces',
#  '2013 - Orville Redenbacher’s® Classic Kettle Korn Ready-to-eat Popcorn Recalled Due to Undeclared Milk Allergen': 'almond milk',
#  '2013 - Oskri Recalls “Coconut Bar Dark Chocolate”, “Coconut Bar Dark Chocolate Minis”, “Fig Dark Chocolate Bars” and “Almond Dark Chocolate Bars” Because of Undeclared Milk': 'almond kernels',
#  '2013 - Product Recall of Kroger’s Break ‘n Bake Chocolate Chip Cookie Dough Due to Peanut Butter Cup Cookie Dough Mispacked Into Chocolate Chip Cookie Dough Packages': 'fresh dough',
#  '2013 - Product Recall: Fair Oaks Dairy Issues Voluntary Recall For Fair Oak Royal Blue Cheese Because Of Possible Health Risk To Listeria Monocytogenes Contamination': 'almond milk',
#  '2013 - Salmonella Illnesses Linked To Organic Eggs Consumers, Food Preparers Reminded to Cook Eggs Thoroughly': 'Precooked cooked pork meat products',
#  '2013 - Sherman Produce Recalls Bulk and Packaged Walnuts Due to Possible Health Risk': 'pickled figs, cherries, pears and walnuts',
#  '2013 - Snoqualmie Gourmet Ice Cream, Inc. Voluntarily Recalls Ice Cream, Gelato, Custard and Sorbet Because of Possible Health Risk': 'cream cheese',
#  '2013 - Southwest Ice Cream Specialties Conducts Voluntary Recall of ShurFine® Brand “Creamery Select Premium Ice Cream Dulce de Leche” 1.75 Quarts Ice Cream Because Package May Contain Praline Pecan Ice Cream Which May Contain Undeclared Allergens (Wheat, Soy and Pecans)': 'cream cheese',
#  "2013 - Specific Lots of P.F. Chang's Home Menu Pork and Leek Dumpling Frozen Appetizers Recalled Due to Undeclared Allergen": 'Not classified pork meat',
#  '2013 - Stone Independent Research, Inc. Issues Allergy Alert on Undeclared Milk in EnhanceRx Dietary Supplement': 'almond milk',
#  '2013 - Stone Independent Research, Inc. Issues Allergy Alert on Undeclared Milk in One Lot of Zanocap Capsules': 'almond milk',
#  '2013 - Sunburst Foods Recalls Products Because Of Possible Health Risk': 'apple cake',
#  '2013 - Surma Distributors LLC, Issues Alert On Undeclared Sulfites In Haque Brand Golden Raisins': 'golden enoki mushrooms',
#  '2013 - Texas Firm Recalls Ready-to-eat Products For Possible Listeria Contamination': 'almond milk',
#  '2013 - The Muffin "Mam", Inc. Issues a Recall on Undeclared Whole Egg in The Muffin "Mam", Inc.™ 24oz Strawberry Créme Cake': 'apple cake',
#  '2013 - UPDATE-Salmolux Voluntarily Recalls Cold Smoked Salmon Products Because of Possible Health Risk': 'cured smoked ham',
#  '2013 - Undeclared Eggs in “Halal Plain” & “Halal Fruit Cake”': 'apple cake',
#  '2013 - Unilever Announces Recall of Skippy® Reduced Fat Peanut Butter Spread Due to Possible Health Risk Limited Recall of 6 Best-If-Used-By Dates': 'bovine fat',
#  '2013 - Vermont Common Foods Issues Allergy Alert on Undeclared Peanuts': 'baby foods',
#  '2013 - Whole Foods Market Recalls Cheese Because of Possible Health Risk': 'blue cheese',
#  '2013 - Winn-Dixie Issues Voluntary Recall On Winn-Dixie Organic 100% Apple Juice': 'apple cake',
#  '2013 - Woodstock® Announces a Voluntary Recall for One Code Date of Mislabeled Woodstock Tamari Almonds Due to Undeclared Soy Allergen': 'almonds',
#  '2015 - American Pure Whey Issues Allergy Alert on Undeclared Milk and Soy in Whey Protein Products.': 'almond milk',
#  '2015 - Arthur Schuman issues Allergy Alert on Undeclared Egg in Grated Parmesan Cheese': 'blue cheese',
#  "2015 - Barrel O' Fun Snack Foods Co. Issues Allergy Alert On Undeclared Milk In Vic's Original Popcorn (1-1/8oz)": 'almond milk',
#  '2015 - Best Foods Inc. Issues Allergy Alert on Undeclared Peanuts in Deer Cumin Powder 7 Ounce and Deer Cumin Powder 14 Ounce': 'almond powder',
#  '2015 - Blue Bell Ice Cream Recalls 3 oz. Institutional/Food Service Ice Cream Cups – Chocolate, Strawberry, Vanilla (Tab Lid) – Because of Possible Health Risk': 'cereal bars with chocolate',
#  '2015 - Chetak New York L.L.C. Recalls 14.1 oz. Jar of': 'dried fruit in jars',
#  '2015 - Dairy Recall': 'feed materials',
#  '2015 - Fatima Brothers Issues Alert On Undeclared Sulfites In Shad Raisins': 'green raisins',
#  '2015 - Freeland Foods Voluntarily Recalls Spicy Seed Due To Potential Health Risk': 'frozen spicy chicken wings',
#  '2015 - Gilster - Mary Lee Corp. Issues an Allergen Alert for Undeclared Almonds in Market Pantry Honey & Oat Mixers Ready to Eat Cereal': 'almonds',
#  '2015 - Hines Nut Company, Dallas, TX Announces Voluntary Recall of Walnut Halves and Pieces Due to Possible Health Risk': 'walnuts',
#  '2015 - House of Spices (India) Inc. Issues Alert on Undeclared Sulfites in': 'mixed spices',
#  '2015 - Kanan Enterprises Conducts Nationwide Voluntary Recall of Macadamia Nuts': 'feed materials',
#  "2015 - Notice of Voluntary Recall of Certain Martinelli's 8.4 oz. Sparkling Beverages Due to Potential for Glass Fragments": 'sparkling beverages',
#  "2015 - Sweet Sam's Baking Company Issues Allergy Alert on Undeclared Milk in Starbucks Black & White Mini Cookies": 'almond milk',
#  '2015 - Texas Star Nut and Food Co. Inc. Natural Macadamia Nuts Are Being Voluntarily Recalled Due To Possible Salmonella Contamination': 'natural honey',
#  '2015 - Tristar Food Wholesale Co. Inc. Issues Allergy Alert On Undeclared Sulfites In Heng Cheong Loong Co. Golden Raisins': 'golden enoki mushrooms',
#  '2015 - Truco Enterprises Recalls 18oz Cafe Style Tortilla Chips Due To The Possible Presence Of Undeclared Milk Allergen': 'almond milk',
#  '2015 - UPC Correction: David Trail Mix Sweet & Salty Voluntarily Recalled Due To Undeclared Dairy Allergen': 'sweet nut snack',
#  '2015 - Whole Foods Market Voluntarily Recalls Packaged Raw Macadamia Nuts Due To Possible Health Risk': 'raw beef meat and raw beef meat preparations',
#  '2015 - Whole Foods Market’s Southwest Region Recalls Chocolate Cake For Two Due To Undeclared Egg': 'egg products',
#  '2015 - updated press release for korean food co. recalls soybean sprout because of possible health risk': 'bean sprouts',
#  '21st Century Snack Foods is Voluntarily Recalling Dark Chocolate Almonds Due to Possible Undeclared Milk Allergen': 'almond milk',
#  '3-D Meats, LLC Recalls Ready-To-Eat Beef Snack Stick Products due to Misbranding and Undeclared Allergens': 'Dried pork meat',
#  '3D Trading recalls Cheetos Cheddar Jalapeno Crunchy Cheese Flavoured Snacks due to incorrect labelling of milk as an allergen': 'almond milk',
#  '3d trading extends recall of cheetos snacks due to incorrect labelling of milk as an allergen': 'almond milk',
#  '4C Foods Corp. Voluntarily Recalls 4C Grated Cheese, Homestyle Grated Cheese, and Cento Grated Cheese Brands NET WT. 6 OZ Glass Jars Because of Possible Health Risk': 'baby foods',
#  '502 Boundary Blvd. Recalls Black Forest Ham Products Due To Possible Foreign Matter Contamination': 'black caviar',
#  '7-Eleven Stores Pty Ltd — 7-Eleven Australian Full Cream Milk 2L': 'almond milk',
#  '7-Eleven brand Subs recalled due to Listeria monocytogenes': 'apple cake',
#  '88 Soy & Fish brand Pre-Fried Cuttlefish Flavoured Fish Cake recalled due to undeclared egg': 'canned fish products',
#  '888 Food Company Issues Allergy Alert On Undeclared Egg In Various Ho King and Giai Phat Products': 'egg products',
#  '9NINE Brand Foods Ltd recalls its Super Seeds Breakfast Apricot &amp  Strawberry Bar because of undeclared peanuts': 'blue poppy seeds',
#  'A G Specialty Foods Inc. Issues Voluntary Recall of Food Products Containing Jif and Smuckers Peanut Butter Due to the Potential Salmonella Contamination': 'Dried pork meat',
#  'A La Carte Foods Properties, LLC Recalls Meat and Poultry Products Containing Meat Produced without Benefit of Inspection': 'Dried pork meat',
#  'A&E Corrales LLC Recalls Saladitos Dried Salted Plums with Chili Because of Possible Health Risk': 'Dried pork meat',
#  'A&M Farms Initiates a Recall Of Specific Little Bear Brand Whole Vidalia Onions Sold By The Pound at Retail Because of Possible Health Risk': 'frozen whole fish',
#  'A. Clouet Pty Ltd—Ayam Thai Massaman Curry, Cooking Sauce': 'barbecue sauce',
#  'A.S.K. Foods, Inc. Issues Allergy Alert On Undeclared Egg In Taste Of Inspirations Classic Red Skin Potato Salad Net. Weight 16 Oz. (454g)': 'chilled ready to eat salad and side dishes',
#  'A.S.K. Foods, Inc. Recalls Herb Stuffing with Pork and Veal Product Due to Misbranding and an Undeclared Allergen': 'Not classified pork meat',
#  'AA Poultry Processing, LLC Recalls Chicken and Turkey Products Due to Use of Unapproved Substance': 'canned chicken',
#  'AC Creamery Inc. Recalls': 'almond milk',
#  'ADM Animal Nutrition Recalls Mintrate® 36-15 Breed Right Cattle Tub - A specific lot of product may contain elevated levels of non-protein nitrogen, could harm cattle': 'animal by-products',
#  'ADM Animal Nutrition Recalls MoorMan’s® ShowTec® Lamb Creep DC': 'animal by-products',
#  'ADM Milling Expands Recall of Baker’s Corner All Purpose Flour 5lb Bags Packaged for ALDI in Select States': 'tea bags',
#  'ADM Milling Recalling Baker’s Corner All Purpose Flour 5lb bags Packaged for ALDI': 'apple cake',
#  'ADM brand baking mixes recalled due to pieces of metal': 'boletus mushrooms, stems and pieces',
#  'AKI brand Chum Salmon Caviar recalled due to potential presence of dangerous bacteria': 'salmon',
#  'AKM Foods Limited recalls Zaiqa International Mini Fruit Jelly because of a choking hazard.': 'baby foods',
#  'ALDI Voluntarily Recalls Assorted Peaches from Wawona Packing Company LLC Due to Possible Salmonella Enteritidis Contamination': 'peaches',
#  'AMKO Foods recalls Pork Dripping with Jelly': 'Not classified pork meat',
#  'ASK Italian recalls Christmas Crackers because of undeclared allergens': 'crackers',
#  'AWERS, Inc. Recalls Grained Salmon Caviar 95g Because of Possible Health Risk': 'black caviar',
#  'Aaron’s Gourmet Smoked Fish Recalls Smoked Fish Products Produced Without Licensure and Regulatory Oversight': 'canned fish products',
#  'Abbott Nutrition recalls two batches of its PaediaSure Plus because the product in some bottles may not have received sufficient sterilisation (Revised)': 'nutrition shake',
#  'Abbyland Foods, Inc. Recalls Beef Stick Product Due to Misbranding and Undeclared Allergens': 'angus beef',
#  'Abdallah Candies Issues Allergy Alert on Undeclared Almond in Lund’s and Byerly’s 16 Oz. Sea Salt Caramels': 'almond kernels',
#  'Aberdeen and Black Tie brand ChaoZhou style fish balls recalled due to undeclared soy': 'canned fish products',
#  'Able Groupe Recalling Products Labeled as Infant Formula Formulas Have Insufficient Iron Levels as Per Requirements for Infant Formula in The U.S., and Products Do Not Meet Other FDA Requirements': 'infant formula',
#  'Abo Anwar brand Namoura recalled due to undeclared sesame, cashews and wheat': 'sesame confection',
#  'Accord United Pty Ltd—Glico Collon Strawberry and Chocolate Biscuits': 'biscuit mix',
#  "Accra Super Market Issues Allergy Alert On Undeclared Peanuts In 'Suya Barbecue Seasoning'": 'barbecue sauce',
#  "Acquilla Bulk Trading—Sasso Pasta D'acciughe Linea Mare anchovies paste": 'dried anchovies',
#  'Ada Valley Gourmet Foods, Inc. Recalls Beef Products Due to Possible Foreign Matter Contamination': 'angus beef',
#  'Adams Brothers brand Cauliflower recalled due to E. coli O157:H7': 'cauliflower',
#  'Adams Farm Slaughterhouse Recalls Beef, Veal, And Bison Products Due To Possible E. Coli O157:H7 Adulteration': 'angus beef',
#  'Additional Quaker Quinoa Granola Bars Recalled as a Result of Expanded Sunflower Kernel Contamination by SunOpta': 'apricot kernels',
#  'Ades Limited products handled and packaged in an unapproved establishment': 'almond milk',
#  'Advance Pierre Foods Recalls Ready-to-Eat Ground Beef Products Due to Possible Foreign Matter Contamination': 'angus beef',
#  'Advance Pierre Foods, Inc. Recalls Chicken Tenders and Breaded Dark Meat Chicken Products Due to Misbranding and Undeclared Allergens': 'Dried pork meat',
#  'AdvancePierre Foods, Inc. Recalls Frozen Beef Patties due to Possible Foreign Matter Contamination': 'angus beef',
#  'Advancepierre Foods Recalls Pork Products Due to Misbranding and Undeclared Allergen': 'Not classified pork meat',
#  'Advocare Issues Allergy Alert in Select Bottles of Muscle Strength and Nighttime Recovery Product Because of Undeclared Milk Allergen on The Label': 'almond milk',
#  'Affco Usa Recalls Frozen Raw Lamb Products Imported Without Benefit Of Import Inspection': 'chicken products - frozen',
#  'After Dinner Mints withdrawn by Poundland Ltd because they contain milk': 'after dinner mints',
#  'Agave Dream Recalls Cappuccino Ice Cream Because of Possible Health Risk': 'apple cake',
#  'Agave Dream Recalls Several Flavors Of Ice Creams In Pint Size Containers Because Of Possible Health Risk': 'ice cream',
#  'Agri Star Meat And Poultry LLC Recalls Beef Pastrami Products due to Possible Processing Deviation': 'Dried pork meat',
#  'Agropur Import Collection brand Firm Ripened Comté Cheese recalled due to Listeria monocytogenes': 'blue cheese',
#  'Agropur Signature - Oka brand Oka Cheese Fondue recalled due to undeclared milk and wheat': 'almond milk',
#  'Ainsley Harriott Amazing Grains Lentil Dahl Recall': 'assorted bread roll selection',
#  'Ajinomoto Foods North America, Inc. Recalls Chicken Fried Rice Products Due To Possible Foreign Matter Contamination': 'brown rice',
#  'Ajinomoto Windsor, Inc. Recalls Frozen Ready-To-Eat Beef Products Due To Possible Foreign Matter Contamination': 'angus beef',
#  'Ajinomoto Windsor, Inc. Recalls Meat and Poultry Products Due to Possible Listeria Contamination': 'Dried pork meat',
#  'Al Mina — Almond Baklava Triangle 250g & Four Finger Baklava 200g': 'almond kernels',
#  'Al Shabrawy Incorporated Recalls Meat and Poultry Products Due To Misbranding and Undeclared Allergens': 'Dried pork meat',
#  'Al Shabrawy Meat Incorporated Recalls Meat and Poultry Products Due To Misbranding and Undeclared Allergens': 'Dried pork meat',
#  'Al-Rabih brand Halva / Halawa and Tahini recalled due to Salmonella': 'halva',
#  'Al-Rabih brand Halva\xa0/ Halawa and Tahini recalled due to Salmonella': 'halva',
#  'Alabama Firm Recalls Bbq Chicken Wing Products Due To Misbranding And Undeclared Allergen': 'canned chicken',
#  'Alabama Firm Recalls Beef Jerky Products Due to Misbranding and Undeclared Allergen': 'angus beef',
#  'Alabama Firm Recalls Corn Dog Products Due to Misbranding and Undeclared Allergen': 'canned corn',
#  'Alamgeer Foods recalls Alamgeer Bassar Curry Powder because of incorrect allergen labelling': 'cardamom seeds',
#  'Alasko brand IQF Whole Raspberries recalled due to norovirus - Recalls, advisories and safety alerts – Canada.ca': 'frozen whole fish',
#  'Alba Cheese—Shredded Mozzarella': 'blue cheese',
#  'Alba Gelati': 'ice cream',
#  'Albertsons Companies Voluntarily Recalls Select ReadyMeals Seafood Products Due to Undeclared Allergens': 'frozen seafood',
#  'Albertsons Companies, in Cooperation with The J. M. Smucker Co., Voluntarily Recalls Select Store-Prepared Items Containing Peanut Butter Due to Possible Salmonella Contamination': 'chocolate spread',
#  "Albertsons, Safeway, Vons and Pak N’ Save Stores in Eight States Revise Product Lists for Recall of Vegetable Trays and Cups in Cooperation with Mann Packing's Voluntary Recall Due to Possible Listeria monocytogenes Contamination": 'meat samosas, vegetable samosas, chicken samosas and meat spring rolls',
#  'Aldi GB recalls Harvest Morn Crisp Rice because it contains pieces of plastic': 'boletus mushrooms, stems and pieces',
#  'Aldi Stores (a Limited Partnership) — Berg Deli Prosciutto Sliced 100g': 'frozen sliced coconut',
#  'Aldi Stores (a Limited Partnership) — Farmdale Full Cream Milk 3L': 'almond milk',
#  'Aldi Stores (a Limited Partnership) — Inner Goodness Regular UHT Soy Milk 1L': 'almond milk',
# ...
#  'Carriage House Creations Recalls Carriage House Various Bourbon Basting Sauces and Hot Barbecue Sauce due to Undeclared Soy and Peanuts': 'ground hot pepper',
#  'Casa Dairy Products—Marinated Feta': 'feta cheese',
#  'Casa Di Trevi Recalls Meat Pasta Products Produced Without Benefit Of Inspection And Due To Misbranding And Undeclared Allergens': 'Dried pork meat',
#  'Casa Italia brand Soppressata Piccante Salami recalled due to possible spoilage': 'salami sausage',
#  'Casa Madaio brand Burrata cheese recalled due to generic E. coli and S. aureus': 'Groupers (generic)',
#  'Casa Sanchez Foods Recalls': 'baby foods',
#  'Casbah brand Quinoa & Ancient Grains recalled due to presence of insects': 'quinoa',
#  'Castel Regio brand Taleggio DOP recalled due to Listeria monocytogenes': 'cheese (taleggio capriolo)',
#  'Cavendish Farms Issues Allergy Alert on Undeclared Wheat in Original Hash Brown Patties': 'brown beans',
#  'Cay Thi Queentrees Food USA Recalls Poultry Products Produced Without Benefit of Import Inspection': 'fresh poultry and poultry prepations',
#  "Cebu's Dried Fish brand Dried Silver Fish (Bol S Dilis) recalled due to histamine - Recalls, advisories and safety alerts – Canada.ca": 'Dried pork meat',
#  'Cedar brand spreads recalled due to undeclared sesame and soy': 'sesame confection',
#  'Cedar’s Mediterranean Foods Issues Allergy Alert on Undeclared Pine Nut in 10 Oz. Organic Mediterranean Hommus': 'organic chlorella powder',
#  'Celebrate Health Pty Ltd—Flaxseed with Cocoa and Berries': 'dried elder berries',
#  'Celebrate Health Superfoods Flaxseed with Coco and Berries': 'dried elder berries',
#  'Celebrate Today Issues a Nationwide Recall of One Lot of Red Mammoth Due to the Presence of Undeclared Ingredients': 'Precooked cooked pork meat products',
#  'Celebrate brand frozen profiteroles and  eclairs recalled due to Salmonella': 'chicken products - frozen',
#  'Censea, Inc. Recalls Shrimp Product Because of Possible Health Risk': 'dried shrimp noodles',
#  'Centennial Foodservice brand and Good Boucher brand ground beef products recalled due to pieces of plastic': 'angus beef',
#  "Cerebos (Australia) Ltd—Foster Clark's Snak Pack (various flavours) and Custard Cups": 'custard',
#  'Ceren—Halva (Middle Eastern Sweet)': 'sweet nut snack',
#  'Certain $10 Chicken Fries recalled due to Salmonella': 'canned chicken',
#  'Certain Abbott brand powdered infant formula products recalled due to Cronobacter sakazakii and Salmonella - Recalls, advisories and safety alerts – Canada.ca': 'infant formula',
#  'Certain Black River Juice brand Organic Sweet Apple Cider may contain patulin': 'organic chlorella powder',
#  'Certain Celebrate brand  frozen profiteroles and eclairs recalled due to Salmonella': 'chicken products - frozen',
#  'Certain Coaticook brand Cheddar cheese recalled due to Listeria monocytogenes': 'cheddar cheese',
#  'Certain Coco Polo brand Dark Cocoa Bars recalled due to undeclared milk': 'almond milk',
#  'Certain Compliments brand and Levitts brand deli meat products recalled due to Listeria monocytogenes': 'Dried pork meat',
#  'Certain Deli Chef brand Sandwiches recalled due to Listeria monocytogenes': 'sandwiches',
#  "Certain Dole and President's Choice brand salad products recalled due to Listeria monocytogenes - Recalls, advisories and safety alerts – Canada.ca": 'chilled ready to eat salad and side dishes',
#  "Certain Duke's brand Dry Apple Cider may contain quality/spoilage": 'dried fruits',
#  'Certain Dwarf Stars brand Pumpkin Seed Butter Cups Dark Chocolate recalled due to undeclared milk': 'almond milk',
#  'Certain Enjoy Life brand bakery products recalled due to possible presence of pieces of plastic - Recalls, advisories and safety alerts – Canada.ca': 'bakery products',
#  'Certain Four Seasons Marketplace brand refrigerated packaged smoked salmon products may be unsafe due to potential presence of dangerous bacteria': 'salmon',
#  'Certain GINGER BEEF CHOICE brand READY-TO-EAT SPECIAL COMBO may contain Listeria monocytogenes': 'angus beef',
#  'Certain Gatorade Perform G brand Thirst Quencher (orange) is being recalled due to a labelling issue': 'all purpose seasoning',
#  'Certain Gatorade brand products are being recalled due to a microbiological issue': 'all purpose seasoning',
#  'Certain Goodfood brand Roasted Sweet Potato Power Bowls recalled due to undeclared almonds, pecans, wheat and gluten': 'almonds',
#  'Certain Greenbelt Microgreens brand microgreens recalled due to Listeria monocytogenes': 'apple cake',
#  'Certain Gusto brand and Olli brand ready-to-eat meat products recalled due to Listeria monocytogenes': 'Dried pork meat',
#  'Certain Happy Veggie World, Hearts Choices, and Vegefarm brand vegan and vegetarian products recalled due to undeclared egg': 'Veggie Burger',
#  'Certain Igor brand Gorgonzola Cheese may contain Listeria monocytogenes': 'blue cheese',
#  'Certain Il Villaggio brand Gorgonzola Dolce Cheese may contain Listeria monocytogenes': 'gorgonzola cheese',
#  'Certain Isagenix brand Isalean Bars may be unsafe due to over fortification of vitamins': 'bars',
#  'Certain Jif brand Peanut Butters recalled due to Salmonella - Recalls, advisories and safety alerts – Canada.ca': 'butter',
#  'Certain Kawartha Dairy brand ice cream products recalled due to possible presence of pieces of metal': 'Groupers (generic)',
#  'Certain Kinder brand chocolate products recalled due to possible Salmonella - Recalls, advisories and safety alerts – Canada.ca': 'cereal bars with chocolate',
#  'Certain Kirkland Signature brand Organic Lean Ground Beef, Product of USA, may contain pathogenic E. coli bacteria': 'angus beef',
#  'Certain Les Huîtres Cadoret – La Perle Noire brand #4 oysters recalled due to norovirus': 'oyster sauce',
#  'Certain Manila clams may be unsafe due to a marine biotoxin which causes Paralytic Shellfish Poisoning': 'clams',
#  'Certain Metro brand products recalled due to Salmonella': 'almond milk',
#  "Certain Miss Vickie's brand Kettle Cooked Potato Chips recalled due to possible presence of pieces of glass": 'boletus mushrooms, stems and pieces',
#  'Certain Mr. Sub brand Spicy Chicken Bites may contain Salmonella or Campylobacter bacteria due to undercooking': 'canned chicken',
#  'Certain Nestle brand Chocolate Peanut Butter Ice Cream may contain Salmonella bacteria': 'butter',
#  'Certain Nestle brand Chocolate Peanut Butter Ice Cream may contain Salmonella': 'butter',
#  "Certain Nora's brand Dairy-Free Frozen Desserts recalled due to undeclared milk": 'almond milk',
#  'Certain Organic Traditions brand dark chocolate nut products recalled due to undeclared milk and hazelnut - Recalls, advisories and safety alerts – Canada.ca': 'almond milk',
#  'Certain Ottogi brand noodle products recalled due to undeclared egg': 'chicken noodle soup',
#  'Certain Pacific Oysters recalled due to a marine biotoxin which causes Paralytic Shellfish Poisoning (PSP)': 'oyster sauce',
#  'Certain Pacific Oysters recalled due to norovirus - Recalls, advisories and safety alerts – Canada.ca': 'oyster sauce',
#  "Certain President's Choice brand Powdered Infant Formula": 'infant formula',
#  'Certain RXBAR brand Protein Bars recalled due to undeclared peanut': 'bars',
#  'Certain Real Deal Meats brand pork products recalled due to E. coli O157:H7': 'Dried pork meat',
#  'Certain Revive Superfoods brand Smoothies and Oats recalled due to possible norovirus contamination of raspberries used in these products - Recalls, advisories and safety alerts – Canada.ca': None,
#  'Certain Rico ‘n Lalo brand and Mini Lalo brand frozen bars recalled due to undeclared milk and sulphites - Recalls, advisories and safety alerts – Canada.ca': 'almond milk',
#  'Certain Sandwiches recalled due to Listeria monocytogenes': 'sandwiches',
#  'Certain Smith Snacks brand products recalled due to Listeria monocytogenes': 'almond milk',
#  'Certain Smoked Rainbow Trout products manufactured by Tarini Brothers Meat and Fish Market recalled due to potential presence of dangerous bacteria': 'canned fish products',
#  'Certain Sobeys brand packaged vegetable products recalled due to Listeria monocytogenes': 'meat samosas, vegetable samosas, chicken samosas and meat spring rolls',
#  'Certain Stella Artois brand Beer may be unsafe due to possible presence of glass particles': 'beer',
#  'Certain Stellar Bay Shellfish brand Chef Creek Oysters recalled due to norovirus - Recalls, advisories and safety alerts – Canada.ca': 'oyster sauce',
#  'Certain Sweet Spot Chocolate Shop brand peanut butter-containing chocolates recalled due to Salmonella - Recalls, advisories and safety alerts – Canada.ca': 'cereal bars with chocolate',
#  "Certain TRADER JOE'S brand NUT BUTTERS may contain Salmonella bacteria": 'nut and fruit mixture',
#  'Certain Taylor Shellfish Canada ULC brand Oysters recalled due to norovirus - Recalls, advisories and safety alerts – Canada.ca': 'oyster sauce',
#  "Certain That's it. brand Dark Chocolate Truffles recalled due to undeclared milk - Recalls, advisories and safety alerts – Canada.ca": 'almond milk',
#  'Certain The Big Carrot brand juice products may be unsafe due to pieces of glass': 'apple juice',
#  'Certain Tri-Star Seafood Supply Ltd. brand Live Spot Prawns recalled due to norovirus - Recalls, advisories and safety alerts – Canada.ca': 'frozen seafood',
#  'Certain Trinity Bakeshop Ltd. brand  bakery products recalled due to Salmonella': 'bakery products',
#  'Certain Union Bay Seafood Ltd. brand Pacific Oysters recalled due to norovirus - Recalls, advisories and safety alerts – Canada.ca': 'frozen seafood',
#  'Certain Union Bay Seafood Ltd. brand Pacific Oysters recalled due to norovirus': 'frozen seafood',
#  'Certain Vegetarian Spring Rolls recalled due to monosodium glutamate (MSG)': 'cinnamon rolls',
#  'Certain breaded meat products from Toscana Meat Distributors recalled due to undeclared allergens - Recalls, advisories and safety alerts – Canada.ca': 'Dried pork meat',
#  'Certain broccoli-containing deli products recalled due to Listeria monocytogenes': 'Precooked cooked pork meat products',
#  'Certain cauliflower florettes and stir fry/veg medley produced by Leonard Fruit & Vegetable Wholesale Inc. recalled due to E. coli O157:H7': 'cauliflower',
#  'Certain cauliflower, red leaf lettuce and green leaf lettuce produced by Adam Bros Farming Inc. recalled due to E.\xa0coli\xa0O157:H7': 'green bean',
#  'Certain extra lean ground beef products recalled due to E. coli O157': 'angus beef',
#  'Certain fish cake products recalled by Korea Food Trading Ltd. due to undeclared egg': 'apple cake',
#  'Certain milk products may be unsafe due to presence of sanitizer': 'almond milk',
#  'Certain no name brand Chicken Burgers recalled due to Salmonella': 'canned chicken',
#  'Certain organic poppy seeds recalled due to Salmonella - Recalls, advisories and safety alerts – Canada.ca': 'organic chlorella powder',
#  'Certain pork products recalled due to E. coli O157:H7': 'Not classified pork meat',
#  'Certain pork products sold in Alberta recalled due to E. coli O157:H7': 'Not classified pork meat',
#  'Certain pre-packaged Cooked Shrimp (56/65 Shrimp per lb.) recalled due to potential presence of harmful bacteria': 'dried shrimp noodles',
#  'Certain products containing diced chicken recalled due to Listeria monocytogenes': 'animal by-products',
#  'Certain sandwiches and in-store made chicken salads recalled due to Listeria monocytogenes': 'sandwiches',
#  'Certain vegetarian fried prawn products recalled due to undeclared egg': 'egg products',
#  'Cesina Sausage Company Recalls Pork Product Due To Misbranding': 'Not classified pork meat',
#  'Chai Supreme Dark Chocolate': 'cereal bars with chocolate',
#  'Challenge Meats Pty Ltd—Country Lite Ham Steaks': 'Dried pork meat',
#  'Channel Fish Processing Co., Inc. Recalls Siluriformes Fish Products Due To Misbranding and Undeclared Allergens': 'canned fish products',
#  'Chapel Foods Ltd recalls Genius Gluten Free Denby Dale Steak Pies': 'baby foods',
#  'Chapel Hill Creamery Recalls Cheese Products Because of Possible Health Risk': 'blue cheese',
#  'Charcuterie Fortin brand Salami recalled due to undeclared wheat': 'salami sausage',
#  'Charkas Middle East Foods—Al-Rabih Brand Tahineh': 'baby foods',
#  'Charkas Middle Eastern Foods—Al-Ribah Halawa Plain and Pistachio': 'baby foods',
#  'Charlesworth Nuts': 'macadamia nuts',
#  'Cheap As Chips—Snickers Bar, Mars Bar, Bounty Bar and Twix Bar': 'protein bar',
#  'Cheese On The Wey recalls Blue Millie cheese because of contamination with Listeria monocytogenes': 'blue cheese',
#  'Chef Destinations, Frankly Fresh Salads and Fresh St. brands Fresh Guacamole and 7 Layer Dip recalled due to Listeria monocytogenes': 'cheese dip',
#  'Chef Destinations, Frankly Fresh Salads and Fresh St. brands Fresh Guacamole recalled due to Listeria monocytogenes': 'animal by-products',
#  'Chef’s Kitchen Limited withdraws its Premium Quality Style Port and Premium Quality Style Madeira': 'Dried pork meat',
#  'Chelsea Food Services Issues Allergy Alert On Undeclared Egg In Product': 'egg products',
#  'Chemist Warehouse Group — INC Shred Max Raspberry Coconut Flavour 60g': 'coconut drink',
#  'Cher-Make Sausage Company Recalls Fully Cooked Meat Sausage Products Due to Misbranding and an Undeclared Allergen': 'Dried pork meat',
#  'Cherry Tree Home Bakery recalls various products because of incorrect allergen labelling (N Ireland only)': 'bakery products',
#  'Cherry Valley Marketplace Issues Allergy Alert on Undeclared Milk Allergens in “Cherry Valley Vanilla Cupcakes” and “Cherry Valley Chocolate Cupcakes”': 'almond milk',
#  'Chetak Melbourne Pty Ltd — Deep Coriander Chutney': 'coriander',
#  'Chicago Firm Recalls Pork Roll Products Due To Misbranding and Undeclared Allergen': 'Not classified pork meat',
#  'Chicago Indoor Garden Voluntarily Recalls Clover Sprouts and Products Containing Clover Sprouts Due To Possible Health Risk': 'alfalfa sprouts',
#  'Chicharrones J&J Recalls Rendered Animal Fat (Pork Lard) Products Due To Misbranding and an Undeclared Allergen': 'Not classified pork meat',
#  'Chilli Sauce': 'barbecue sauce',
#  'Chip’n Dipped Issues Allergy Alert on Undeclared Milk in': 'almond milk',
#  'Chip’n Dipped Voluntarily Expands Recall to Include 7 More of it’s Dark Chocolate Bars Due to Possible Presence of Undeclared Milk': 'almond milk',
#  'Chiquo Dried Apricots Whole recall': 'Dried pork meat',
#  'Choco Creation Fruit Mix recalled due to undeclared peanut ingredient': 'dried fruit in jars',
#  'Choice Canning Company, Inc. Recalls Chicken Fried Rice Products Due to Misbranding and Undeclared Allergens': 'brown rice',
#  'Choice Products USA, LLC Issues an Allergy Alert on Undeclared Milk in Premier Choice 3 lb. Tub Peanut Butter Cookie Dough Ordered Through Online Ordering': 'almond milk',
#  'ChoripDong brand Frozen Par Fried Fish Cake recalled due to undeclared egg': 'apple cake',
#  "Chris' Homestyle Plant Based Dips 200g": 'chicken based products',
#  'Christie brand Honey Teddy Grahams recalled due to rancidity': 'honey',
#  'Chris’s Cookies Recalls Chocolate Chip Cookies Due to Undeclared Peanuts': 'cereal bars with chocolate',
#  'Chukar brand Amaretto Rainiers Cherries recalled due to undeclared milk': 'almond milk',
#  'Chun Yuen Trading Co. Issues Allergy Alert On Undeclared Milk': 'almond milk',
#  'Chunwei, Inc. Recalls Meat and Poultry Products Due to Misbranding and Undeclared Allergens and Monosodium Glutamate': 'Dried pork meat',
#  'Cicada Artisan Chocolate': 'cereal bars with chocolate',
#  'Ciolo Foods Issues Allergy Alert for Undeclared Tree Nuts in': 'cheese tray',
#  'Circle K Favourites brand Dark Chocolate Covered Almonds recalled due to undeclared milk': 'almond milk',
#  'Clair D. Thompson & Sons, Inc. Recalls Ground Beef Products Due To Possible E. Coli O157:H7 Contamination': 'feed materials',
#  'Clayton Park recalls Twin Packed Cream Cakes due to incorrect date marking': 'cakes',
#  'Cleanfit Plant Protein Bar Chocolate Brownie': 'cereal bars with chocolate',
#  ...}

# %%
# Prepare the predictions
formatted_products = prepare_predictions(classifications_products)
formatted_products = sanitize_predictions(formatted_products)


print(formatted_products)
len(formatted_products)
# Out:
# {'Vilis Lamb, Mint and Rosemary Pies 160g': 'chicken pie', "'Jackpot Mix' brand of Mix of Pretzels, Sticks and Salted Biscuits recalled": 'biscuits', '(Updated) Bradbury &amp  Son (Buxton) recalls Lo-Col because milk is not emphasised on the labelling': 'almond milk', '*(Updated on 2 June 2020) Not to consume a batch of bottled apple juice drink contaminated with patulin': 'apple cake', '*(Updated on 5 July 2022) Not to consume smoked salmon products with dill possibly contaminated with Listeria monocytogenes': 'Groupers (generic)', '165368 C. Corporation Recalls Pork Products Due to Possible Listeria Contamination': 'Not classified pork meat', '168 Express Ltd recalls various Jelly products because of a choking hazard': 'Dried pork meat', '2006 - Consumer Alert: Listeria Contamination in Raw Milk': 'almond milk', '2006 - Pinnacle Foods Corporation Issues Allergy Alert on Bakery-Style Chocolate Chip Muffin Mix': 'cereal bars with chocolate', '2006 - Pinnacle Foods Group Inc. Issues Allergy Alert on Undeclared Egg in Frozen': 'baby foods', '2006 - allergy alert on undeclared almonds in albertsons chocolate ice cream': 'almonds', '2006 - pinnacle foods group inc. issues allergy alert on brownie mix': 'baby foods', '2007 - Agriculture Department Warns Consumers of Tainted Raw Milk Sold by Butler County Dairy': 'almond milk', '2007 - WholeSoy & Co. Expands National Allergy Alert on Undeclared Dairy in Blueberry and Mixed Berry Yogurt': 'yogurt raisins', '2007 - Winn-Dixie Stores, Inc. Issues Allergy Alert on Mislabeled Prestige Chocolate Ice Cream': 'cereal bars with chocolate', '2007 - private selection® ice cream recalled from ralphs and food 4 less stores in california': 'assorted bread roll selection', '2008 - Barry Callebaut USA LLC Issues Allergen Alert on Undeclared Milk Protein in Kroger Value Semi Sweet Chocolate Chips': 'almond milk', "2008 - dreyer's issues voluntary recall of slow churned® light caramel delight and butter pecan ice cream flavors for undeclared pecans": 'butter', '2008 - limited number of aunt jemima pancake & waffle mix products recalled for possible health risk': 'apple cake', "2008 - pierre's ice cream company issues allergy alert on its homestyle brand of dutch chocolate ice cream for undeclared peanut butter cup candies": 'candies', '2008 - private selection ice cream recalled from kroger stores in twelve southeastern states': 'assorted bread roll selection', '2009 - A Manufacturer From England, Cropwell Bishop Creamery Limited, is Conducting a Nationwide Recall on the Cheese Products Blue Stilton and Shropshire Blue Cheese Because of Possible Health Risk': 'blue cheese', '2009 - Alexia Foods issues nationwide allergy alert and product recall on its Alexia Olive Oil, Sun-Dried Tomatoes & Pesto Oven Reds frozen potatoes due to undeclared pine nut allergen': 'Groupers (generic)', '2009 - BIC Acquisition, LLC Recalls World Classic Trading Company Ultimate Chunk Ice Cream': 'ice sticks', '2009 - Bliss Bros. Dairy, Inc. Recalls Ice Cream Products Because of Possible Health Risk': 'cream cheese', '2009 - Boca Grande Foods Announces a Nationwide Recall of POCO PAC?, and GRANDE GOURMETT Peanut Butter Products Because of Possible Health Risk': 'butter', "2009 - Braum's Ice Cream and Dairy Stores Announces Voluntary Recall of its Premium Ice Cream Flavor": 'ice cream', '2009 - Bucks Ice Cream Recalls Ice Cream Nut Roll Because of Possible Health Risk': 'cream cheese', '2009 - Fieldbrook Foods Corp. Announces Nationwide Voluntary Recall of Select Ice Cream Novelty Products Due to Possible Health Risk': 'almond milk', '2009 - Fieldbrook Foods Corporation Adds Four Products to Nationwide Voluntary Recall of Select Ice Cream Novelty Products Due to Possible Health Risk': 'baby foods', '2009 - Frito-Lay Issues Nationwide Voluntary Recall of In-Shell Pistachio Nuts Due to Possible Health Risk': 'macadamia nuts', '2009 - Garden-Fresh Foods Issues Allergy Alert On Undeclared Milk in 16-Ounce Archer Farms Potato Sala ...
# 4943

# %%
dataset_path = "/content/food-hazard-detection-semeval-2025.github.io/data/incidents_train.csv"

evaluate_predictions(dataset_path, formatted_products, 'product')
# Out:
# Evaluation of Product Predictions:
#                                                                         precision    recall  f1-score   support
#
#                                                 Catfishes (freshwater)       0.40      0.18      0.25        11
#                                                        Dried pork meat       0.00      1.00      0.01         1
#                                                  Fishes not identified       0.00      0.00      0.00        34
#                                                     Groupers (generic)       0.00      0.00      0.00         1
#                                               Not classified pork meat       0.06      0.82      0.11        11
#                                             Pangas catfishes (generic)       0.00      0.00      0.00         3
#                                    Precooked cooked pork meat products       0.00      0.00      0.00         9
#                                     Torpedo-shaped catfishes (generic)       0.00      0.00      0.00         1
#                                                                Unknown       0.00      0.00      0.00         0
#                                                          Veggie Burger       0.17      0.80      0.29         5
#                                                        adobo seasoning       1.00      1.00      1.00         1
#                                                     after dinner mints       0.25      1.00      0.40         1
#                                                    alcoholic beverages       0.25      0.25      0.25         4
#                                                        alfalfa sprouts       0.45      1.00      0.62        10
#                                                                  algae       0.00      0.00      0.00         6
#                                                  all purpose seasoning       0.03      0.33      0.06         3
#                                                               allspice       0.50      1.00      0.67         1
#                                                         almond kernels       0.02      1.00      0.03         1
#                                                            almond milk       0.00      0.33      0.00         3
#                                                          almond powder       0.00      0.00      0.00         2
#                                                        almond products       0.00      0.00      0.00         8
#                                                                almonds       0.17      0.60      0.27        10
#                                                               amaranth       1.00      1.00      1.00         1
#                                                       anchovies in oil       0.05      1.00      0.09         2
#                                                          anchovy paste       0.00      0.00      0.00         1
#                                                             angus beef       0.00      0.50      0.01         2
#                                                     animal by-products       0.00      0.00      0.00         1
#                                                             appetizers       0.00      0.00      0.00         1
#                                                             apple cake       0.01      1.00      0.01         1
#                                                            apple juice       0.05      0.10      0.06        10
#                                                                 apples       0.00      0.00      0.00         2
#                                                        apricot kernels       0.29      0.67      0.40         9
#                                                               apricots       0.00      0.00      0.00         1
#                                                              asparagus       0.00      0.00      0.00         1
#                                          assorted bread roll selection       0.01      0.50      0.03         2
#                                        assortment of filled chocolates       0.00      0.00      0.00         1
#                                                              baby food       0.00      0.00      0.00        17
#                                                      baby food pouches       0.03      1.00      0.05         1
#                                                             baby foods       0.01      1.00      0.01         1
#                                                           baby spinach       0.00      0.00      0.00         9
#                                                                 bagels       1.00      1.00      1.00         3
#                                                              baguettes       0.50      1.00      0.67         2
#                                                        bakery products       0.17      0.35      0.23        17
#                                                             baking mix       0.00      0.00      0.00         6
#                                                                baklava       1.00      0.50      0.67         2
#                                                               balsamic       0.50      1.00      0.67         1
#                                                                 bamboo       0.00      0.00      0.00         1
#                                                          bamboo shoots       0.25      1.00      0.40         1
#                                                                bananas       0.00      0.00      0.00         1
#                                                         barbecue sauce       0.06      0.60      0.11         5
#                                                                   bars       0.08      0.18      0.11        11
#                                                                  basil       0.00      0.00      0.00         4
#                                                      basil pesto sauce       0.29      0.73      0.41        11
#                                                             batter mix       0.00      0.00      0.00         1
#                                                             bean paste       0.05      0.50      0.09         2
#                                                             bean sauce       0.00      0.00      0.00         3
#                                                             bean snack       0.06      1.00      0.12         2
#                                                           bean sprouts       0.40      0.67      0.50         3
#                                                                  beans       0.10      0.33      0.15         3
#                                                                   beef       0.00      0.00      0.00        24
#                                                           beef burrito       0.00      0.00      0.00         1
#                                                              beef meat       0.00      0.00      0.00         3
#                                                          beef products       0.00      0.00      0.00        27
#                                                            beef stewed       0.00      0.00      0.00         1
#                                                            beef tallow       0.00      0.00      0.00         1
#                                                   beef tenderloin cuts       0.00      0.00      0.00         1
#                                                            beef tongue       0.00      0.00      0.00         1
#                                                         beef trimmings       1.00      0.25      0.40         4
#                                                                   beer       0.81      0.52      0.63        25
#                                                              beetroots       0.33      1.00      0.50         1
#                                                               beverage       0.00      0.00      0.00         3
#                              beverage base of non-fruit origin, liquid       0.00      0.00      0.00         1
#                             bilberry extract used in a food supplement       0.17      1.00      0.29         1
#                                                            biscuit mix       0.00      0.00      0.00         1
#                                                               biscuits       1.00      0.08      0.15        48
#                                                 bitter apricot kernels       0.00      0.00      0.00         3
#                                                           black caviar       0.05      1.00      0.10         1
#                                                           black pepper       0.08      0.33      0.13         3
#                                                           blackberries       1.00      1.00      1.00         2
#                                         blackcurrant drink concentrate       0.10      1.00      0.18         1
#                                               bloody mary beverage mix       0.50      0.50      0.50         2
#                                                            blue cheese       0.05      0.53      0.09        15
#                                                       blue poppy seeds       0.00      0.00      0.00         1
#                                                            blueberries       1.00      0.75      0.86         4
#                                                                   boar       0.00      0.00      0.00         2
#                                    boletus mushrooms, stems and pieces       0.00      0.00      0.00         1
#                                                        bolognese sauce       0.00      0.00      0.00         1
#                                                          boneless beef       0.00      0.00      0.00         2
#                                                  bottled mineral water       0.33      1.00      0.50         3
#                                                          bottled water       0.14      0.33      0.20         9
#                                                             bovine fat       0.00      0.00      0.00         1
#                                                  bovine meat and offal       0.00      0.00      0.00         1
#                                                            brazil nuts       1.00      0.20      0.33         5
#                                                                  bread       0.00      0.00      0.00        31
#                                            bread and products therefor       0.00      0.00      0.00         9
#                                                            bread crumb       0.00      0.00      0.00         2
#                                                              bread mix       0.00      0.00      0.00         2
#                                                      breakfast cereals       0.00      0.00      0.00        14
#                                breakfast cereals and products therefor       0.00      0.00      0.00         1
#                                           breakfast cereals for babies       0.00      0.00      0.00         1
#                                                         brewer's yeast       1.00      1.00      1.00         2
#                                                            brie cheese       0.67      0.33      0.44         6
#                                                                brioche       0.50      1.00      0.67         1
#                                                               broccoli       0.00      0.00      0.00        10
#                                                           broccoli mix       0.00      0.00      0.00         1
#                                                                 broths       0.00      0.00      0.00         1
#                                                            brown beans       0.00      0.00      0.00         1
#                                                        brown mushrooms       0.00      0.00      0.00         1
#                                                             brown rice       0.03      0.50      0.06         2
#                                                               brownies       0.20      0.40      0.27         5
#                                                        brussel sprouts       0.00      0.00      0.00         1
#                                         buffalo milk mozzarella cheese       0.00      0.00      0.00         1
#                                                                   buns       0.60      0.27      0.38        11
#                                                                burrata       0.00      0.00      0.00         2
#                                                 burrito (ready to eat)       0.00      0.00      0.00         5
#                                                                 butter       0.12      0.67      0.20         6
#                                                                cabbage       0.00      0.00      0.00         3
#                                                        cake decoration       0.00      0.00      0.00         3
#                                                                  cakes       0.67      0.07      0.12        92
#                                                              camembert       1.00      0.50      0.67         2
#                                                                candies       0.00      0.00      0.00        32
#                                                canned artichoke hearts       1.00      1.00      1.00         1
#                                                     canned black beans       0.00      0.00      0.00         1
#                                                         canned chicken       0.01      1.00      0.02         2
#                                                            canned corn       0.00      0.00      0.00         3
#                                              canned crab meat in brine       0.20      1.00      0.33         1
#                                                   canned fish products       0.00      0.00      0.00         1
#                                                       canned meat stew       0.50      1.00      0.67         1
#                                                         canned mussels       0.00      0.00      0.00         1
#                                                         canned spinach       0.00      0.00      0.00         1
#                                                     cantaloupe (fresh)       0.50      1.00      0.67         1
#                                                          caramel bites       0.10      0.67      0.17         3
#                                                      carbonated  water       0.00      0.00      0.00         1
#                                                    carbonated beverage       0.00      0.00      0.00         5
#                                             carbonated/sparkling water       0.00      0.00      0.00         1
#                                                      carcasses of veal       0.10      1.00      0.18         1
#                                                         cardamom seeds       0.00      0.00      0.00         1
#                                                         cardamon seeds       0.00      0.00      0.00         1
#                                     carps, barbels and other cyprinids       0.00      0.00      0.00         1
#                                                                 cashew       0.25      0.25      0.25         8
#         cattle from which the milk was used to produce raw milk cheese       0.00      0.00      0.00         1
#                                                            cauliflower       1.00      0.40      0.57         5
#                                                                cbd oil       0.00      0.00      0.00         3
#                                                           cbd products       0.00      0.00      0.00         5
#                                                                 cereal       0.00      0.00      0.00         8
#                                                            cereal bars       0.00      0.00      0.00        11
#                                             cereal bars with chocolate       0.01      1.00      0.02         1
#                                                           cereal drink       0.00      0.00      0.00         2
#                                                                cereals       0.00      0.00      0.00         3
#                                            cereals and bakery products       0.00      0.00      0.00         1
#                                                         cheddar cheese       0.64      0.64      0.64        11
#                                                                 cheese       0.00      0.00      0.00        74
#                                             cheese (taleggio capriolo)       0.50      1.00      0.67         1
#                                            cheese - made from raw milk       0.00      0.00      0.00         1
#                                                        cheese - melted       0.00      0.00      0.00         1
#                                                         cheese burgers       0.00      0.00      0.00         1
#                                                             cheese dip       0.00      0.00      0.00         3
#                                                cheese flavoured snacks       0.00      0.00      0.00         1
#                                                        cheese products       0.00      0.00      0.00         6
#                                                        cheese sausages       0.00      0.00      0.00         0
#                                                          cheese spread       0.00      0.00      0.00         6
#                                                        cheese tortilla       0.00      0.00      0.00         1
#                                                            cheese tray       0.00      0.00      0.00         1
#                                                         cheesy spirals       1.00      1.00      1.00         1
#                                                               cherries       0.00      0.00      0.00         1
#                                                             chia seeds       0.50      0.29      0.36         7
#                                                                chicken       0.00      0.00      0.00        24
#                                       chicken and chicken preparations       0.00      0.00      0.00         3
#                                                 chicken based products       0.00      0.00      0.00       134
#                                                         chicken breast       0.00      0.00      0.00        27
#                                                          chicken broth       0.00      0.00      0.00         3
#                                                        chicken dippers       0.00      0.00      0.00         4
#                                                     chicken drumsticks       0.00      0.00      0.00         1
#                                                        chicken fillets       0.00      0.00      0.00         1
#                                                      chicken meat meal       0.00      0.00      0.00         2
#                                                  chicken meat products       0.00      0.00      0.00         4
#                                                    chicken noodle soup       0.00      0.00      0.00         6
#                                                            chicken pie       0.00      0.00      0.00         4
#                                                   chicken preparations       0.00      0.00      0.00        23
#                                              chicken products - frozen       0.00      0.00      0.00         8
#                                                         chicken slices       0.00      0.00      0.00         1
#                                             chicken steak without bone       0.00      0.00      0.00         1
#                                                              chickpeas       0.00      0.00      0.00         1
#                                                           chilled beef       0.00      0.00      0.00         1
#                                              chilled beef preparations       0.00      0.00      0.00         1
#                                              chilled bengali cod curry       0.11      1.00      0.20         1
#                                             chilled boneless pork meat       0.00      0.00      0.00         1
#                                                        chilled chicken       0.00      0.00      0.00         2
#                                                  chilled chicken parts       0.00      0.00      0.00         3
#                                                 chilled chicken thighs       0.00      0.00      0.00         1
#                                                  chilled chicken wings       0.00      0.00      0.00         1
#                                            chilled dumplings with meat       0.00      0.00      0.00         1
#                                                        chilled lasagne       0.25      1.00      0.40         1
#                                                           chilled pork       0.00      0.00      0.00         1
#                                                      chilled pork ribs       0.00      0.00      0.00         1
#                                                  chilled pork sausages       0.00      0.00      0.00         2
#                             chilled ready to eat salad and side dishes       0.00      0.00      0.00         1
#                                                         chilled salads       0.00      0.00      0.00         6
#                                                     chilled smoked ham       0.00      0.00      0.00         1
#                                             chilled vacuum packed beef       0.00      0.00      0.00         1
#                                                                 chilli       0.00      0.00      0.00         1
#                                                             chilli oil       0.00      0.00      0.00         1
#                                                           chilli paste       0.00      0.00      0.00         2
#                                                         chilli peppers       0.00      0.00      0.00         1
#                                                          chilli pickle       0.00      0.00      0.00         1
#                                                          chilli powder       0.00      0.00      0.00         5
#                                                           chilli sauce       0.00      0.00      0.00         7
#                                                               chillies       0.00      0.00      0.00         1
#                                                              chocolate       0.00      0.00      0.00        18
#                                       chocolate and chocolate products       0.00      0.00      0.00         3
#                                          chocolate and hazelnut spread       0.14      0.50      0.22         2
#                                        chocolate and products therefor       0.00      0.00      0.00         2
#                        chocolate and strawberry flavoured cyclone milk       0.00      0.00      0.00         1
#                                                         chocolate bars       1.00      0.07      0.13        29
#                                                        chocolate chips       0.00      0.00      0.00         6
#                                                chocolate confectionery       0.00      0.00      0.00         2
#                                                      chocolate dessert       0.00      0.00      0.00         1
#                                                 chocolate drink powder       0.00      0.00      0.00         2
#                                                       chocolate drinks       0.00      0.00      0.00         1
#                                     chocolate easter eggs with filling       0.00      0.00      0.00         1
#                                                         chocolate eggs       0.04      0.09      0.05        11
#                                            chocolate flavoured cereals       0.00      0.00      0.00         1
#                                          chocolate flavoured meringues       0.00      0.00      0.00         1
#                                                 chocolate mini muffins       0.00      0.00      0.00         1
#                                                       chocolate mousse       0.00      0.00      0.00         1
#                                                     chocolate products       0.00      0.00      0.00        29
#                                                  chocolate spelt balls       0.00      0.00      0.00         1
#                                                       chocolate spread       0.00      0.00      0.00         2
#                                        chocolate spread with hazelnuts       0.00      0.00      0.00         1
#                                                     chocolate truffles       0.00      0.00      0.00         2
#                                                       chocolate wafers       0.00      0.00      0.00         3
#                                                             chocolates       0.00      0.00      0.00         9
#                                                                chorizo       0.00      0.00      0.00        10
#                                                        chorizo sausage       0.05      0.67      0.09         3
#                                                                  cider       1.00      0.62      0.77         8
#                                                               cinnamon       0.00      0.00      0.00         3
#                                                         cinnamon rolls       0.00      0.00      0.00         2
#                                                                  clams       1.00      0.25      0.40         4
#                                                         clams (canned)       0.33      0.33      0.33         3
#                                                 cocktail sausage rolls       0.00      0.00      0.00         1
#                                                          coconut drink       0.00      0.00      0.00         3
#                                                          coconut juice       0.00      0.00      0.00        10
#                                                           coconut milk       0.00      0.00      0.00         6
#                                                     coconut milk drink       0.00      0.00      0.00         4
#                                                            coconut oil       1.00      0.33      0.50         3
#                                                          coconut sugar       0.00      0.00      0.00         1
#                                                               coconuts       0.00      0.00      0.00        25
#                                                                    cod       0.00      0.00      0.00         3
#                                                            cod fillets       0.00      0.00      0.00         1
#                                                           coffee beans       0.30      0.43      0.35         7
#                                                           coffee drink       0.00      0.00      0.00         3
#                                                             cola drink       0.00      0.00      0.00         1
#                                                                colours       0.00      0.00      0.00         1
#                                                    concentrated apples       0.00      0.00      0.00         2
#                                                          confectionery       0.00      0.00      0.00         9
#                                           confectionery for decoration       0.00      0.00      0.00         2
#                                                         cooked chicken       0.00      0.00      0.00        16
#                                                  cooked chicken skewer       0.00      0.00      0.00         1
#                                                             cooked ham       0.00      0.00      0.00         4
#                                                   cooked meat products       0.00      0.00      0.00         1
#                                                        cooked sausages       0.00      0.00      0.00         4
#                                                                cookies       0.00      0.00      0.00        77
#                                                          cooking sauce       0.00      0.00      0.00         3
#                                                              coriander       0.33      0.12      0.18         8
#                                                                   corn       0.00      0.00      0.00        24
#                                                         cottage cheese       1.00      1.00      1.00         2
#                                                            cottage pie       0.00      0.00      0.00         1
#                                                             courgettes       0.00      0.00      0.00         2
#                                                              cous cous       0.00      0.00      0.00         2
#                                                        cow milk cheese       0.00      0.00      0.00         8
#                                                                  crabs       0.00      0.00      0.00         6
#                                                               crackers       0.75      0.30      0.43        20
#                                                          cranberry jam       0.14      1.00      0.25         1
#                                                        cranberry juice       0.00      0.00      0.00         1
#                                                           cream cheese       0.00      0.00      0.00         6
#                                                    cream chocolate pie       0.00      0.00      0.00         2
#                                                              crepe mix       0.50      1.00      0.67         1
#                                                     crisp cheese snack       0.00      0.00      0.00         2
#                                                             crispbread       1.00      0.50      0.67         2
#                                                                 crisps       1.00      0.33      0.50         6
#                                                             croissants       0.00      0.00      0.00         4
#                                                     crushed red pepper       0.00      0.00      0.00         1
#                                       crustaceans and products thereof       0.00      0.00      0.00         2
#                                                       cultivated fungi       0.00      0.00      0.00         2
#                                                           cumin powder       0.00      0.00      0.00         4
#                                                               cupcakes       0.00      0.00      0.00         6
#                                                            curd cheese       0.00      0.00      0.00         1
#                                                             cured loin       0.00      0.00      0.00         1
#                                                        cured pork meat       0.00      0.00      0.00         3
#                                                       cured smoked ham       0.00      0.00      0.00         1
#                                                                  curry       0.00      0.00      0.00        12
#                                                            curry paste       0.00      0.00      0.00         2
#                                                           curry sauces       0.00      0.00      0.00         2
#                                                                custard       1.00      0.67      0.80         3
#                                                             cuttlefish       0.00      0.00      0.00         1
#                                          dark chocolate coated almonds       0.00      0.00      0.00         6
#                                                        dark chocolates       0.00      0.00      0.00        30
#                                                                  dates       0.50      0.50      0.50        12
#                                                 deboned chicken thighs       0.00      0.00      0.00         1
#                                                               desserts       1.00      0.09      0.16        23
#                                                             diced beef       0.00      0.00      0.00         2
#                                                       dietary capsules       1.00      1.00      1.00         2
#                                                     dietary supplement       0.00      0.00      0.00        22
#                      dietetic foods, food supplements, fortified foods       0.50      0.33      0.40         3
#                                                              dip-sauce       0.00      0.00      0.00        11
#                                                          dipping sauce       0.00      0.00      0.00         1
#                                                                 donuts       1.00      0.60      0.75         5
#                                                               dressing       0.00      0.00      0.00         7
#                                                        dressing sauces       0.00      0.00      0.00         3
#                                                          dried almonds       0.00      0.00      0.00         1
#                                                        dried anchovies       0.00      0.00      0.00         2
#                                                           dried apples       0.00      0.00      0.00         2
#                                                         dried apricots       0.00      0.00      0.00        14
#                                                            dried beans       0.00      0.00      0.00         1
#                                                        dried beef meat       0.00      0.00      0.00        25
#                                                      dried brown beans       0.00      0.00      0.00         1
#                                                   dried chilli peppers       0.00      0.00      0.00         2
#                                                          dried coconut       0.00      0.00      0.00         4
#                                                      dried cranberries       1.00      0.33      0.50         3
#                                                    dried elder berries       0.00      0.00      0.00         1
#                                                             dried figs       0.33      0.25      0.29         4
#                                                    dried fruit in jars       0.00      0.00      0.00         1
#                                                        dried fruit mix       0.00      0.00      0.00         2
#                                                           dried fruits       0.05      0.50      0.09         2
#                                            dried fruits with chocolate       0.00      0.00      0.00         2
#                                                           dried garlic       0.17      1.00      0.29         1
#                     dried herb powder ashwagandha (withania somnifera)       0.00      0.00      0.00         1
#                                                           dried lilies       0.00      0.00      0.00         1
#                                                        dried mushrooms       0.00      0.00      0.00         7
#                                                          dried pangash       0.00      0.00      0.00         1
#                                                            dried plums       0.33      0.14      0.20         7
#                                                    dried pork sausages       0.00      0.00      0.00         1
#                                                          dried sausage       0.00      0.00      0.00         1
#                             dried shitake mushrooms (lentinula edodes)       0.00      0.00      0.00         1
#                                                   dried shrimp noodles       0.12      1.00      0.22         2
#                                                     dried strawberries       1.00      1.00      1.00         1
#                                                           drink powder       0.00      0.00      0.00         1
#                                              drinking chocolate powder       0.00      0.00      0.00         2
#                                                                dry ham       0.00      0.00      0.00         1
#                                                            dry sausage       0.00      0.00      0.00         2
#                                                                   duck       0.33      0.17      0.22         6
#                                                              dumplings       0.00      0.00      0.00        17
#                                                            edam cheese       0.00      0.00      0.00         1
#                                                           egg products       0.00      0.00      0.00         1
#                                                              egg rolls       0.00      0.00      0.00         2
#                                                     egg salad with ham       1.00      1.00      1.00         1
#                                                              eggplants       0.00      0.00      0.00         1
#                                                                   eggs       0.00      0.00      0.00        26
#                                                  eggs and egg products       0.00      0.00      0.00         1
#                emulsifiers, stabilizers, thickeners and gelling agents       0.00      0.00      0.00         3
#                                                energy and protein bars       0.07      0.25      0.11         4
#                                                           energy drink       0.00      0.00      0.00         3
#                                                            fajita meal       0.00      0.00      0.00         2
#                                                          fats and oils       0.00      0.00      0.00         1
#                                                         feed materials       0.00      0.00      0.00         5
#                                                           fennel seeds       1.00      0.33      0.50         3
#                                                    fermented beef meat       0.00      0.00      0.00         4
#                                                 fermented milk product       0.00      0.00      0.00         1
#                                                            feta cheese       0.33      0.12      0.18         8
#                                                       filled chocolate       0.00      0.00      0.00         1
#                                                 fish and fish products       0.00      0.00      0.00         4
#                                                          fish products       0.00      0.00      0.00         7
#                                                               fish roe       0.00      0.00      0.00         5
#                                                             fish sauce       0.00      0.00      0.00         1
#                                                       flavoured drinks       0.00      0.00      0.00         1
#                               flavoured fresh and creamy cheese spread       0.00      0.00      0.00         1
#                                                         flavoured milk       0.00      0.00      0.00         1
#                                                 flavoured potato chips       0.11      0.50      0.18         2
#                                                   flavoured soft drink       0.00      0.00      0.00         1
#                                    flavoured whey protein preparations       1.00      0.50      0.67         2
#                                                               flavours       0.00      0.00      0.00         2
#                                                               flaxseed       1.00      0.25      0.40         4
#                                             flounders, halibuts, soles       0.00      0.00      0.00         1
#                                                                  flour       0.73      0.59      0.65        27
#                                                              foie gras       0.00      0.00      0.00         2
#                                                        food supplement       0.00      0.00      0.00        17
#                                             french beans / green beans       0.00      0.00      0.00         1
#                                                           french toast       0.00      0.00      0.00         2
#                                                           fresh apples       0.00      0.00      0.00         2
#                                                             fresh beef       0.00      0.00      0.00         1
#                                                        fresh beef meat       0.00      0.00      0.00         1
#                                                         fresh broccoli       0.00      0.00      0.00         1
#                                                           fresh cheese       0.00      0.00      0.00         4
#                                                   fresh cut vegetables       0.00      0.00      0.00         2
#                                                            fresh dough       0.00      0.00      0.00         1
#                                                      fresh goat cheese       0.00      0.00      0.00         1
#                                                          fresh lychees       0.00      0.00      0.00         1
#                                                        fresh mushrooms       0.00      0.00      0.00        23
#                                                          fresh parsley       0.00      0.00      0.00         2
#                                                             fresh pork       0.00      0.00      0.00         1
#                                                         fresh pork leg       0.00      0.00      0.00         1
#                                                        fresh pork loin       0.00      0.00      0.00         1
#                                   fresh poultry and poultry prepations       0.05      1.00      0.09         1
#                                     fresh processed beef meat products       0.00      0.00      0.00         5
#                                                       fresh vegetables       0.00      0.00      0.00         6
#                                                            frozen beef       0.00      0.00      0.00         5
#                                                    frozen beef lasagne       0.00      0.00      0.00         1
#                                                    frozen beef patties       0.00      0.00      0.00        11
#                                                   frozen beef products       0.00      0.00      0.00         6
#                                                     frozen beef tongue       0.00      0.00      0.00         2
#                                                  frozen beef trimmings       0.00      0.00      0.00         2
#                                                     frozen berries mix       0.00      0.00      0.00         1
#                                                   frozen boneless beef       0.00      0.00      0.00         2
#                                                    frozen bourbon ribs       0.00      0.00      0.00         1
#                                                  frozen breaded turkey       0.06      1.00      0.12         1
#                                                        frozen broccoli       0.00      0.00      0.00         5
#                                                     frozen burger buns       0.00      0.00      0.00         1
#                                                         frozen burgers       0.00      0.00      0.00         2
#                                                         frozen chicken       0.00      0.00      0.00         2
#                                     frozen chicken strips with tendons       0.00      0.00      0.00         1
#                                                   frozen chicken wings       0.00      0.00      0.00         3
#                                                     frozen cod fillets       0.00      0.00      0.00         1
#                                             frozen cooked lobster meat       0.00      0.00      0.00         1
#                                             frozen diced chicken roast       0.00      0.00      0.00         1
#                                             frozen dumplings with pork       0.00      0.00      0.00         3
#                                                    frozen fish burgers       0.00      0.00      0.00         1
#                                                    frozen fish fillets       0.00      0.00      0.00         5
#                                                   frozen fish products       0.00      0.00      0.00         1
#                                                      frozen fried rice       0.00      0.00      0.00         1
#                                                  frozen grated coconut       0.00      0.00      0.00         1
#                                                     frozen green beans       0.00      0.00      0.00         1
#                                                      frozen hamburgers       0.00      0.00      0.00         2
#                                                     frozen hash browns       1.00      0.25      0.40         4
#                                                            frozen leek       1.00      1.00      1.00         1
#                                                         frozen lobster       0.00      0.00      0.00         2
#                                                  frozen marinated beef       0.00      0.00      0.00         2
#                                               frozen marinated chicken       0.00      0.00      0.00         1
# ...
#                                                           soya product       0.00      0.00      0.00         1
#                                                                soybean       0.00      0.00      0.00         2
#                                                        spaghetti sauce       0.00      0.00      0.00         1
#                                                    sparkling beverages       1.00      1.00      1.00         1
#                                                         spice marinade       1.00      1.00      1.00         1
#                                                              spice mix       0.00      0.00      0.00         3
#                                                          spice mixture       0.00      0.00      0.00         2
#                                                                 spices       0.00      0.00      0.00         3
#                                                  spicy chicken skewers       0.00      0.00      0.00         1
#                                                            spicy sauce       0.00      0.00      0.00         1
#                                                             spicy tofu       0.00      0.00      0.00         1
#                                                     spicy tomato sauce       0.00      0.00      0.00         1
#                                                                spinach       0.00      0.00      0.00         1
#                                                         spinach leaves       0.00      0.00      0.00         1
#                                                                spirits       0.00      0.00      0.00         4
#                                                            sport drink       0.00      0.00      0.00         5
#                                                                 spread       0.00      0.00      0.00         5
#                                                                spreads       0.00      0.00      0.00         3
#                                                           spring rolls       0.00      0.00      0.00        13
#                                                           spring water       0.00      0.00      0.00         4
#                                                           sprinkle mix       0.00      0.00      0.00         1
#                                                              sprinkles       0.00      0.00      0.00         2
#                                                                sprouts       0.00      0.00      0.00         8
#                                                                  squid       1.00      0.50      0.67         2
#                                                                 squids       0.00      0.00      0.00         1
#                                                                 starch       0.00      0.00      0.00         1
#                   structured/textured fish meat products or fish paste       0.00      0.00      0.00         1
#                                                         stuffed pastry       0.00      0.00      0.00         3
#                                                                  sugar       0.00      0.00      0.00         3
#                                                    sugar confectionary       0.00      0.00      0.00         2
#                                                               sultanas       0.00      0.00      0.00         1
#                                                          sunflower oil       0.00      0.00      0.00         1
#                                                         sunflower seed       0.00      0.00      0.00        25
#                                                                  sushi       1.00      0.50      0.67         2
#                                                        sweet nut snack       0.00      0.00      0.00         1
#                                                             sweeteners       0.00      0.00      0.00         2
#                                                                 sweets       0.00      0.00      0.00         2
#                                                            swiss rolls       0.00      0.00      0.00         2
#                                                                  syrup       0.00      0.00      0.00         1
#                                                            table water       0.00      0.00      0.00         1
#                                             table water and soda water       0.00      0.00      0.00         1
#                                                             taco sauce       0.00      0.00      0.00         1
#                                                                 tahini       0.00      0.00      0.00        21
#                                                  tahini (sesame paste)       0.00      0.00      0.00         4
#                                                      tallegio (cheese)       0.00      0.00      0.00         1
#                                                          tapioca chips       0.00      0.00      0.00         1
#                                                               tarragon       0.00      0.00      0.00         1
#                                         tasty trio condiment selection       0.00      0.00      0.00         1
#                                                                    tea       0.00      0.00      0.00         7
#                                                               tea bags       0.00      0.00      0.00         1
#                                                              tea drink       0.00      0.00      0.00         2
#                                                   testosterone booster       0.00      0.00      0.00         1
#                                            thermal processed beef meat       0.00      0.00      0.00        19
#                                            thermal processed pork meat       0.00      0.00      0.00        43
#                                                                  thyme       1.00      1.00      1.00         1
#                                                             tiger nuts       0.00      0.00      0.00         2
#                                                                tilapia       1.00      0.50      0.67         2
#                                                                 toffee       0.67      0.50      0.57         4
#                                                                   tofu       0.00      0.00      0.00         8
#                                                           tomato sauce       0.00      0.00      0.00         5
#                                                               tomatoes       0.00      0.00      0.00         2
#                                                               tortilla       0.00      0.00      0.00         2
#                                                         tortilla chips       0.00      0.00      0.00         6
#                                                  tortilla chips cheese       0.00      0.00      0.00         1
#                                                      tortilla products       0.00      0.00      0.00         1
#                                                                 trouts       0.00      0.00      0.00         4
#                                                                   tuna       0.00      0.00      0.00        13
#                                                             tuna salad       0.00      0.00      0.00         1
#                                        turbot flatfish (psetta maxima)       0.00      0.00      0.00         1
#                                                                 turkey       0.00      0.00      0.00         3
#                                         turkey and turkey preparations       0.00      0.00      0.00        23
#                                                  turkey based products       0.00      0.00      0.00         5
#                                                        turkey sandwich       0.00      0.00      0.00         2
#                                    turnip leaves in sunflower seed oil       0.00      0.00      0.00         1
#                                                                turnips       0.00      0.00      0.00         1
#                                                         tzatziki sauce       0.00      0.00      0.00         4
#                                                   unpasteurised cheese       0.00      0.00      0.00         1
#                                 unsalted organic crunchy peanut butter       0.00      0.00      0.00         1
#                                                     vacuum packed beef       0.00      0.00      0.00         1
#                                           vacuum packed marinated pork       0.00      0.00      0.00         1
#                                            vacuum packed pork ear roll       0.00      0.00      0.00         1
#                                               vacuum packed sliced ham       0.00      0.00      0.00         1
#                                                          vanilla drink       0.00      0.00      0.00         1
#                                                         vanilla powder       0.00      0.00      0.00         1
#                                                various bakery products       0.00      0.00      0.00         3
#                                                  various beef products       0.00      0.00      0.00         2
#                                                        various cheeses       0.00      0.00      0.00         3
#                                          various chicken meat products       0.00      0.00      0.00         1
#                                various chilled or frozen pork products       0.00      0.00      0.00         1
#                                                  various fish products       0.00      0.00      0.00         1
#                                                  various meat products       0.00      0.00      0.00         3
#                                                 various pasta products       0.00      0.00      0.00         3
#                                                   various poultry meat       0.00      0.00      0.00         1
#                                                various prepared dishes       0.00      0.00      0.00         2
#                                     various ready-to-eat meat products       0.00      0.00      0.00         1
#                                                         various snacks       0.00      0.00      0.00         1
#                                         various vegetable preparations       0.00      0.00      0.00         1
#                                                 varnishes and coatings       0.00      0.00      0.00         1
#                                                                   veal       0.00      0.00      0.00         7
#                                                              veal meat       0.00      0.00      0.00         2
#                                                   veal meat and offals       0.00      0.00      0.00         1
#                                                         vegan sausages       0.00      0.00      0.00         3
#                                               vegetable based products       0.00      0.00      0.00         2
#                                                        vegetable broth       0.00      0.00      0.00         1
#                                                       vegetable burger       0.00      0.00      0.00         1
#                                                   vegetable crispbakes       0.00      0.00      0.00         1
#                                                          vegetable mix       0.00      0.00      0.00         4
#                                                  vegetable preparation       0.00      0.00      0.00         2
#                                           vegetable ready to eat meals       0.00      0.00      0.00         3
#                                                      vegetable samosas       0.00      0.00      0.00         4
#                                                             vegetables       0.00      0.00      0.00         2
#                                                                vinegar       1.00      1.00      1.00         1
#                                                               vitamins       0.00      0.00      0.00         1
#                                                    vitamins supplement       0.00      0.00      0.00         2
#                                                                  vodka       0.00      0.00      0.00         2
#                                                                 wafers       0.00      0.00      0.00         4
#                                                                waffles       1.00      0.17      0.29         6
#                                                                walnuts       1.00      0.14      0.25         7
#                                            water for human consumption       0.00      0.00      0.00         3
#                                                      water for infants       0.00      0.00      0.00         1
#                                                            watermelons       0.00      0.00      0.00         1
#                                                               waxberry       0.00      0.00      0.00         1
#                                                     weight loss coffee       0.00      0.00      0.00         1
#                                                                  wheat       0.00      0.00      0.00         2
#                                                            wheat snack       0.00      0.00      0.00         1
#                                                           whey protein       0.00      0.00      0.00         5
#                                                                 whisky       1.00      1.00      1.00         1
#                                                            white beans       0.00      0.00      0.00         1
#                                                           white cheese       0.00      0.00      0.00         2
#                                                        white chocolate       0.00      0.00      0.00         2
#                                                    white lasagna sauce       0.00      0.00      0.00         2
#                                                     white mould cheese       0.00      0.00      0.00         2
#                                                    white mustard seeds       0.00      0.00      0.00         1
#                                                          whole chicken       0.00      0.00      0.00         1
#                                                                   wine       1.00      0.33      0.50        12
#                                                                  wraps       0.00      0.00      0.00        15
#                                                            yellow peas       0.00      0.00      0.00         1
#                                                                yoghurt       0.00      0.00      0.00        29
#                                                         yogurt raisins       0.00      0.00      0.00         2
#
#                                                               accuracy                           0.10      5008
#                                                              macro avg       0.11      0.12      0.09      5008
#                                                           weighted avg       0.19      0.10      0.10      5008
#
#
# Full results saved to 'predictions_vs_truth_product.csv'

# %% [markdown]
# # Random Sh

# %%
import gzip

# Define the target string
target = "/c/en/oils/"

file_name = "/content/conceptnet-lite.csv"

# Decompress and process line by line
output_file = "filtered_results.csv"
with gzip.open(file_name, "rt", encoding="utf-8") as f_in, open(output_file, "w", encoding="utf-8") as f_out:
    for line in f_in:
        if target in line:
            f_out.write(line)  # Write matching lines to a new CSV file

print(f"Filtered lines containing '{target}' are saved to {output_file}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-221-9ad260157798> in <cell line: 10>()
#       8 # Decompress and process line by line
#       9 output_file = "filtered_results.csv"
# ---> 10 with gzip.open(file_name, "rt", encoding="utf-8") as f_in, open(output_file, "w", encoding="utf-8") as f_out:
#      11     for line in f_in:
#      12         if target in line:
#
# /usr/lib/python3.10/gzip.py in open(filename, mode, compresslevel, encoding, errors, newline)
#      56     gz_mode = mode.replace("t", "")
#      57     if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 58         binary_file = GzipFile(filename, gz_mode, compresslevel)
#      59     elif hasattr(filename, "read") or hasattr(filename, "write"):
#      60         binary_file = GzipFile(None, gz_mode, compresslevel, filename)
#
# /usr/lib/python3.10/gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     172             mode += 'b'
#     173         if fileobj is None:
# --> 174             fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     175         if filename is None:
#     176             filename = getattr(fileobj, 'name', '')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/conceptnet-lite.csv'

# %%
file_name = "/content/conceptnet-lite.csv"

# !grep '/c/en/oils/' /content/conceptnet-lite.csv
